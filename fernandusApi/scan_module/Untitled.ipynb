# %%
from flask import Flask,jsonify
import pandas as pd
from sqlalchemy import create_engine

oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()

limit=10
offset=5
query=f'''SELECT * FROM 
     (SELECT o.*, ROW_NUMBER() OVER (ORDER BY 0) Row_Num FROM OTS1.SCANMEACHINE o)
     WHERE Row_Num BETWEEN {offset} and {limit+offset}'''

dataframe=pd.read_sql(query.replace("\n",""),oracleConn)
oracleConn.close()
x=dataframe.to_dict('records')
x
# Out:
# [{'machinetag': 23,
#   'machinename': 'VOLUSON-E6',
#   'machineid': 'M0000024',
#   'locid': None,
#   'locnm': 'JUBLIEE HILLS',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 5},
#  {'machinetag': 14,
#   'machinename': 'VOLUSON E8',
#   'machineid': 'M0000015',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 6},
#  {'machinetag': 16,
#   'machinename': 'VENUE 40 (HG)',
#   'machineid': 'M0000017',
#   'locid': 'Loc00004',
#   'locnm': 'HYDERGUDA',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 7},
#  {'machinetag': 18,
#   'machinename': 'VOLUSON S6',
#   'machineid': 'M0000019',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 8},
#  {'machinetag': 19,
#   'machinename': 'LOGIC-P3(HG)',
#   'machineid': 'M0000020',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 9},
#  {'machinetag': 20,
#   'machinename': 'K Room',
#   'machineid': 'M0000021',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 1.0,
#   'a': None,
#   'usernm': '1040LAL',
#   'userid': 'IU000386',
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': 'Cub00022',
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 10},
#  {'machinetag': 10,
#   'machinename': 'J Room',
#   'machineid': 'M0000011',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 1.0,
#   'a': None,
#   'usernm': '1040LAL',
#   'userid': 'IU000386',
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': 'Cub00025',
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 11},
#  {'machinetag': 1,
#   'machinename': 'HP Trial',
#   'machineid': 'M0000001',
#   'locid': 'Loc00003',
#   'locnm': 'SUPERDELUX',
#   'active': 0.0,
#   'a': None,
#   'usernm': '1040LAL',
#   'userid': 'IU000386',
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 12},
#  {'machinetag': 2,
#   'machinename': 'VOLUSON 2',
#   'machineid': 'M0000002',
#   'locid': None,
#   'locnm': None,
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 13},
#  {'machinetag': 3,
#   'machinename': 'VOLUSON',
#   'machineid': 'M0000005',
#   'locid': 'Loc00003',
#   'locnm': 'SUPERDELUX',
#   'active': nan,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 14},
#  {'machinetag': 4,
#   'machinename': 'LOGIC ',
#   'machineid': 'M0000004',
#   'locid': 'Loc00001',
#   'locnm': 'BOGULKUNTA',
#   'active': 1.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 15}]

# %%
from flask import Flask,jsonify,request
#from flask_cors import CORS
import pandas as pd
from sqlalchemy import create_engine


app=Flask(__name__)




@app.route("/")
def home():
    return "running"


@app.route("/SCANMEACHINE",methods=["POST"])
def scan():
    print("received request")
    clientData=request.form.to_dict()
    oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
    oracleConn = oracledb.connect()

    limit=int(clientData['limit'])
    offset=int(clientData['offset'])
    
    query=f'''SELECT * FROM 
         (SELECT o.*, ROW_NUMBER() OVER (ORDER BY 0) Row_Num FROM OTS1.SCANMEACHINE o)
         WHERE Row_Num BETWEEN {offset} and {limit+offset}'''

    dataframe=pd.read_sql(query.replace("\n",""),oracleConn)
    oracleConn.close()
    x=dataframe.to_dict('records')
    print(len(x))
    return x
    



if __name__=="__main__":
    app.run(host="192.168.8.173")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://192.168.8.173:5000
# Press CTRL+C to quit
# received request
# [2023-01-30 15:59:36,458] ERROR in app: Exception on /SCANMEACHINE [POST]
# Traceback (most recent call last):
#   File "C:\Python311\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\pavan\AppData\Local\Temp\ipykernel_5132\89442018.py", line 35, in scan
#     return jsonify(x)
#            ^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\json\__init__.py", line 342, in jsonify
#     return current_app.json.response(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\json\provider.py", line 309, in response
#     f"{self.dumps(obj, **dump_args)}\n", mimetype=mimetype
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\json\provider.py", line 230, in dumps
#     return json.dumps(obj, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\json\__init__.py", line 238, in dumps
#     **kw).encode(obj)
#           ^^^^^^^^^^^
#   File "C:\Python311\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\json\provider.py", line 111, in _default
#     return http_date(o)
#            ^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\werkzeug\http.py", line 968, in http_date
#     return email.utils.format_datetime(timestamp, usegmt=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\email\utils.py", line 162, in format_datetime
#     now = dt.timetuple()
#           ^^^^^^^^^^^^^^
#   File "pandas\_libs\tslibs\nattype.pyx", line 67, in pandas._libs.tslibs.nattype._make_error_func.f
# ValueError: NaTType does not support timetuple
# 192.168.8.173 - - [30/Jan/2023 15:59:36] "POST /SCANMEACHINE HTTP/1.1" 500 -
# 11

# %%
## LabParameterHeader

import pandas as pd
from sqlalchemy import create_engine

oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()

limit=10
offset=5
query=f'''SELECT DISTINCT t.DISPLAYPARAM ,t.SUBCOMPONENTNM ,t.SUBCOMPID,6776 AS Createdby ,
CASE WHEN (SELECT count(*) FROM DIAGNOTECH.MCDHNORMALVALUE1 v WHERE v.COMPID = t.SUBCOMPID) > 0 THEN 'numeric' ELSE 'text' END AS referenceoutput
 FROM DIAGNOTECH.TESTSUBCOMPONENTS t'''

dataframe=pd.read_sql(query.replace("\n",""),oracleConn)
oracleConn.close()
x=dataframe.to_dict('records')
dataframe.rename(columns={"displayparam":"DisplayName","subcomponentnm":"ParameterName","referenceoutput":"ReferenceOutput","subcompid":"SUBCOMPID","createdby":"CreatedBy"}, inplace=True)
dataframe['Active']=[True]*len(dataframe)
postgresdb=create_engine(r'postgresql+psycopg2://postgres:emr123@192.168.8.97/shivam_test_DB',echo=False)
postgresConn= postgresdb.connect()
dataframe.to_sql("LabParameterHeader",postgresConn,if_exists="append",index=False)
postgresConn.close()

# %%
dataframe.rename(columns={"displayparam":"DisplayName","subcomponentnm":"ParameterName","referenceoutput":"ReferenceOutput","subcompid":"SUBCOMPID","createdby":"CreatedBy"}, inplace=True)

# %%
dataframe['Active']=[True]*len(dataframe)

# %%
dataframe
# Out:
#                           DisplayName                ParameterName SUBCOMPID  \
# 0                              Hb `F`                       Hb `F`  SCMP0387
# 1                          Appearance  Appearance - Fluid Analysis  SCMP0395
# 2                           WBC Count            WBC Count - Fluid  SCMP0414
# 3                                CD3%           CD3% - HIV Monitor  SCMP0419
# 4                        Osmolality *       Blood for Osmolality *  SCMP0432
# ..                                ...                          ...       ...
# 914  HIV II (Antibody)      ( Tridot)  HIV II (Antibody) ( Tridot)  SCMP0940
# 915                   Insulin Fasting                      Fasting  SCMP0943
# 916                  Glucose 1st Hour                   1st Hour .  SCMP0946
# 917                  Glucose 2nd Hour                   2nd Hour .  SCMP0948
# 918                    Glucose 2 hour               Glucose 2 hour  SCMP0959
#
#      CreatedBy ReferenceOutput  Active
# 0         6776         numeric    True
# 1         6776         numeric    True
# 2         6776         numeric    True
# 3         6776         numeric    True
# 4         6776         numeric    True
# ..         ...             ...     ...
# 914       6776         numeric    True
# 915       6776         numeric    True
# 916       6776         numeric    True
# 917       6776         numeric    True
# 918       6776         numeric    True
#
# [919 rows x 6 columns]

# %%
postgresdb=create_engine(r'postgresql+psycopg2://postgres:emr123@192.168.8.97/shivam_test_DB',echo=False)
postgresConn= postgresdb.connect()
dataframe.to_sql("LabParameterHeader",postgresConn,if_exists="append",index=False)
postgresConn.close()

# %%
#LabParameterDetail

import pandas as pd
from sqlalchemy import create_engine

oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()



postgresdb=create_engine(r'postgresql+psycopg2://postgres:emr123@192.168.8.97/shivam_test_DB',echo=False)
postgresConn= postgresdb.connect()

ids=pd.read_sql(f'select  "LabParameterHeaderId","SUBCOMPID" from "LabParameterHeader" where "SUBCOMPID" is not null ',postgresConn)
ids=ids.to_dict('records')

for i in ids:
    try:
        print(i['LabParameterHeaderId'],i['SUBCOMPID'])

        records=pd.read_sql(f"SELECT DISTINCT INVORDER,DESC_R ,tp1,tp2,SEX,13 AS UnitId,REFRANGETO ,MAXRAFRANGE ,MINCRITVAL ,MAXCRITVAl,COMPID   FROM DIAGNOTECH.MCDHNORMALVALUE1 WHERE COMPID = '{i['SUBCOMPID']}' ",oracleConn)
        records['LabParameterHeaderId']=i['LabParameterHeaderId']*len(records)
        records.rename(columns={"desc_r":"RangeText","tp1":"FromAgeType","tp2":"ToAgeType",
                                "unitid":"UnitId","refrangeto":"MinValue","maxrafrange":"MaxValue",
                               "mincritval":"MinCriticalValue","maxcritval":"MaxCriticalValue",
                               "compid":"SUBCOMPID","invorder":"InvOrder","sex":"Gender","fromage":"FromAge","toage":"ToAge"
                               }, inplace=True)

        print(records.to_dict('records'))
        
        records.to_sql("LabParameterDetail",postgresConn,index=False,if_exists="append")
    except Exception as e:
        print(str(e))
# Out:
# 88 SCMP0387
# [{'InvOrder': 6, 'RangeText': '4 months : 9.4 - 29.0', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '9.4', 'MaxValue': '29.0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 5, 'RangeText': '3 months : 15 - 56', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '15', 'MaxValue': '56', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 2, 'RangeText': '12 months : 1.3 - 5.0', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1.3', 'MaxValue': '5.0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 1, 'RangeText': '0 - 30 days : 61 - 81', 'FromAgeType': 'Days', 'ToAgeType': 'Days', 'Gender': 'All', 'UnitId': 13, 'MinValue': '61', 'MaxValue': '81', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 10, 'RangeText': '10 months : 1.5 - 5.0', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1.5', 'MaxValue': '5.0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 4, 'RangeText': '2 months : 29 - 61', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '29', 'MaxValue': '61', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 3, 'RangeText': '1 month : 46 - 67', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '46', 'MaxValue': '67', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 9, 'RangeText': '8 months : 2.3 - 12.0', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '2.3', 'MaxValue': '12.0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 11, 'RangeText': 'Less than 2.0', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '2', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 7, 'RangeText': '5 months : 2.3 - 22.0', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '2.3', 'MaxValue': '22.0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}, {'InvOrder': 8, 'RangeText': '6 months : 2.7 - 13.0', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '2.7', 'MaxValue': '13.0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0387', 'LabParameterHeaderId': 968}]
# 89 SCMP0395
# [{'InvOrder': 1, 'RangeText': '<pre style="font: arial;">Transudates : Clear<br>Exudates    : Usually Cloudy</pre>', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0395', 'LabParameterHeaderId': 356}, {'InvOrder': 1, 'RangeText': 'Transudates : Clear<br>Exudates    : Usually Cloudy', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0395', 'LabParameterHeaderId': 356}, {'InvOrder': 1, 'RangeText': 'Transudates : ClearExudates    : Usually Cloudy', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0395', 'LabParameterHeaderId': 356}, {'InvOrder': 1, 'RangeText': 'Transudates : Clear<br>Exudates    : Usually Cloudy', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0395', 'LabParameterHeaderId': 356}]
# 90 SCMP0414
# [{'InvOrder': 1, 'RangeText': '0 - 30 ( Neonates )  0 - 5 ( Adults )', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': '0 - 30 (Neonates)<br>0 - 5   (Adults)', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': '<pre style="font: arial;">Transudates : Less than 1000  <br>Exudates    : More than 1000</pre>', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': '0 - 30 ( Neonates ) 0 - 5 ( Adults )', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': 'Transudates : Less than 1000  <br>Exudates    : More than 1000', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}]
# (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "."
# LINE 1: ...)  0 - 5 ( Adults )', 'Days', 'Years', 'All', 13, '.', '.', ...
#                                                              ^
#
# [SQL: INSERT INTO "LabParameterDetail" ("InvOrder", "RangeText", "FromAgeType", "ToAgeType", "Gender", "UnitId", "MinValue", "MaxValue", "MinCriticalValue", "MaxCriticalValue", "SUBCOMPID", "LabParameterHeaderId") VALUES (%(InvOrder)s, %(RangeText)s, %(FromAgeType)s, %(ToAgeType)s, %(Gender)s, %(UnitId)s, %(MinValue)s, %(MaxValue)s, %(MinCriticalValue)s, %(MaxCriticalValue)s, %(SUBCOMPID)s, %(LabParameterHeaderId)s)]
# [parameters: ({'InvOrder': 1, 'RangeText': '0 - 30 ( Neonates )  0 - 5 ( Adults )', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': '0 - 30 (Neonates)<br>0 - 5   (Adults)', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': '<pre style="font: arial;">Transudates : Less than 1000  <br>Exudates    : More than 1000</pre>', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': '0 - 30 ( Neonates ) 0 - 5 ( Adults )', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': 'Transudates : Less than 1000  <br>Exudates    : More than 1000', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0414', 'LabParameterHeaderId': 720})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# 91 SCMP0419
# [{'InvOrder': 1, 'RangeText': '<pre style="font: arial;"></pre>', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '60', 'MaxValue': '85', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0419', 'LabParameterHeaderId': 91}]
# 92 SCMP0432
# [{'InvOrder': 1, 'RangeText': ' 275 - 295', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '275', 'MaxValue': '295', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0432', 'LabParameterHeaderId': 276}, {'InvOrder': 1, 'RangeText': '275 - 295', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '275', 'MaxValue': '295', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0432', 'LabParameterHeaderId': 276}, {'InvOrder': 1, 'RangeText': '275 - 295', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '275', 'MaxValue': '295', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0432', 'LabParameterHeaderId': 276}]
# 93 SCMP0036
# []
# 94 SCMP0037
# [{'InvOrder': 1, 'RangeText': '7 - 9 AM : 4.3  - 22.43 - 5 PM : 3.09 - 16.66', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '4.3', 'MaxValue': '22.4', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0037', 'LabParameterHeaderId': 282}, {'InvOrder': 1, 'RangeText': '<pre style="font: arial;">7 - 9 AM : 4.3  - 22.4<br>3 - 5 PM : 3.09 - 16.66</pre>', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '4.3', 'MaxValue': '22.4', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0037', 'LabParameterHeaderId': 282}, {'InvOrder': 1, 'RangeText': '7 - 9 AM : 4.3  - 22.4<br>3 - 5 PM : 3.09 - 16.66', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '4.3', 'MaxValue': '22.4', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0037', 'LabParameterHeaderId': 282}]
# 95 SCMP0444
# [{'InvOrder': 1, 'RangeText': 'Negative', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0444', 'LabParameterHeaderId': 95}]
# 96 SCMP0445
# [{'InvOrder': 1, 'RangeText': 'Negative', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0445', 'LabParameterHeaderId': 96}]
# 97 SCMP0446
# [{'InvOrder': 1, 'RangeText': '4.8 - 19.8', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '4.8', 'MaxValue': '19.8', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0446', 'LabParameterHeaderId': 291}, {'InvOrder': 1, 'RangeText': '0.4 - 2.0 mmol/l', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0.4', 'MaxValue': '2.0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0446', 'LabParameterHeaderId': 291}, {'InvOrder': 1, 'RangeText': '0.4 - 2.0', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0.4', 'MaxValue': '2.0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0446', 'LabParameterHeaderId': 291}]
# 98 SCMP0448
# [{'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0448', 'LabParameterHeaderId': 196}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0448', 'LabParameterHeaderId': 196}]
# 99 SCMP0459
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '70', 'MaxValue': '120', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0459', 'LabParameterHeaderId': 99}]
# 100 SCMP0462
# [{'InvOrder': 1, 'RangeText': 'Negative', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0462', 'LabParameterHeaderId': 100}]
# 101 SCMP0467
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0467', 'LabParameterHeaderId': 101}]
# 102 SCMP0469
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0469', 'LabParameterHeaderId': 102}]
# 103 SCMP0470
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0470', 'LabParameterHeaderId': 103}]
# 104 SCMP0472
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0472', 'LabParameterHeaderId': 104}]
# 105 SCMP0473
# [{'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0473', 'LabParameterHeaderId': 105}]
# 106 SCMP0474
# [{'InvOrder': 1, 'RangeText': 'Normal : Less than 40<br>Suspect : 40 - 60<br>Positive : &gt; 60', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '40', 'MaxValue': '60', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0474', 'LabParameterHeaderId': 106}]
# 107 SCMP0475
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0475', 'LabParameterHeaderId': 107}]
# 108 SCMP0482
# [{'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0482', 'LabParameterHeaderId': 432}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0482', 'LabParameterHeaderId': 432}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0482', 'LabParameterHeaderId': 432}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0482', 'LabParameterHeaderId': 432}]
# (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "."
# LINE 1: ...rId") VALUES (1, ' ', 'Days', 'Years', 'All', 13, '.', '.', ...
#                                                              ^
#
# [SQL: INSERT INTO "LabParameterDetail" ("InvOrder", "RangeText", "FromAgeType", "ToAgeType", "Gender", "UnitId", "MinValue", "MaxValue", "MinCriticalValue", "MaxCriticalValue", "SUBCOMPID", "LabParameterHeaderId") VALUES (%(InvOrder)s, %(RangeText)s, %(FromAgeType)s, %(ToAgeType)s, %(Gender)s, %(UnitId)s, %(MinValue)s, %(MaxValue)s, %(MinCriticalValue)s, %(MaxCriticalValue)s, %(SUBCOMPID)s, %(LabParameterHeaderId)s)]
# [parameters: ({'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0482', 'LabParameterHeaderId': 432}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0482', 'LabParameterHeaderId': 432}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0482', 'LabParameterHeaderId': 432}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0482', 'LabParameterHeaderId': 432})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# 268 SCMP0312
# [{'InvOrder': 2, 'RangeText': 'Female: 4.44 - 13.56', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '4.44', 'MaxValue': '13.56', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0312', 'LabParameterHeaderId': 536}, {'InvOrder': 1, 'RangeText': 'Male: 5.46 - 16.20', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'Male', 'UnitId': 13, 'MinValue': '5.46', 'MaxValue': '16.20', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0312', 'LabParameterHeaderId': 536}]
# 109 SCMP0493
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0493', 'LabParameterHeaderId': 109}]
# 110 SCMP0501
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0501', 'LabParameterHeaderId': 110}]
# 111 SCMP0502
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0502', 'LabParameterHeaderId': 111}]
# 112 SCMP0503
# [{'InvOrder': 1, 'RangeText': 'Non-Reactive', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0503', 'LabParameterHeaderId': 112}]
# 113 SCMP0528
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'Male', 'UnitId': 13, 'MinValue': '59', 'MaxValue': '84', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0528', 'LabParameterHeaderId': 226}, {'InvOrder': 2, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '61', 'MaxValue': '88', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0528', 'LabParameterHeaderId': 226}]
# 114 SCMP0527
# [{'InvOrder': 1, 'RangeText': 'Risk Cut Off Less than 1 : 50', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0527', 'LabParameterHeaderId': 114}]
# 115 SCMP0026
# [{'InvOrder': 3, 'RangeText': 'Up to 1 Month: 210 - 500', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '210', 'MaxValue': '500', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 6, 'RangeText': '2 - 6 Months : 1.5 - 5.0 Lakhs/cumm', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1.5', 'MaxValue': '5.0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 3, 'RangeText': '1.5 - 5.0', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1.5', 'MaxValue': '5.0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 9, 'RangeText': '2 Months: 210 - 650', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '210', 'MaxValue': '650', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 7, 'RangeText': 'Up to 1 Month: 210 - 500', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '210', 'MaxValue': '500', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 6, 'RangeText': '1.5 - 4.5', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '1.5', 'MaxValue': '4.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 1, 'RangeText': '1.0 - 4.5', 'FromAgeType': 'Days', 'ToAgeType': 'Days', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1.0', 'MaxValue': '4.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 2, 'RangeText': 'Adult: 150 - 450', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '150', 'MaxValue': '450', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 4, 'RangeText': '2 Months: 210 - 650', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '210', 'MaxValue': '650', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 16, 'RangeText': '7 - 12 Yrs: 180 - 400', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '180', 'MaxValue': '400', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 6, 'RangeText': '250000 - 450000', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '250000', 'MaxValue': '450000', 'MinCriticalValue': 250000.0, 'MaxCriticalValue': 450000.0, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 8, 'RangeText': '1.0 - 4.5', 'FromAgeType': 'Days', 'ToAgeType': 'Days', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1.0', 'MaxValue': '4.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 3, 'RangeText': '1.5 - 5.5', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1.5', 'MaxValue': '5.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '150000', 'MaxValue': '410000', 'MinCriticalValue': 80000.0, 'MaxCriticalValue': 450000.0, 'SUBCOMPID': 'SCMP0026', 'LabParameterHeaderId': 6670}, {'InvOrder': 4, 'RangeText': '1.5 - 5.5', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1.5', 'MaxValue': '5.5', 'MinCriticalValue': na ...
# 116 SCMP0030
# [{'InvOrder': 1, 'RangeText': '0 - 6 %', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '6', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0030', 'LabParameterHeaderId': 464}, {'InvOrder': 1, 'RangeText': '0 - 6', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '6', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0030', 'LabParameterHeaderId': 464}, {'InvOrder': 1, 'RangeText': '0 - 5', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0030', 'LabParameterHeaderId': 464}, {'InvOrder': 1, 'RangeText': '1 - 6', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '1', 'MaxValue': '6', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 10.0, 'SUBCOMPID': 'SCMP0030', 'LabParameterHeaderId': 464}]
# 117 SCMP0031
# [{'InvOrder': 1, 'RangeText': '0 - 1', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '1', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0031', 'LabParameterHeaderId': 468}, {'InvOrder': 1, 'RangeText': '0 - 2', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '2', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0031', 'LabParameterHeaderId': 468}, {'InvOrder': 1, 'RangeText': '0 - 1', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '1', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 1.0, 'SUBCOMPID': 'SCMP0031', 'LabParameterHeaderId': 468}, {'InvOrder': 1, 'RangeText': '0 - 1 %', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '1', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0031', 'LabParameterHeaderId': 468}]
# 118 SCMP0539
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0539', 'LabParameterHeaderId': 118}]
# 119 SCMP0540
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0540', 'LabParameterHeaderId': 119}]
# 120 SCMP0541
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0541', 'LabParameterHeaderId': 120}]
# 121 SCMP0542
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0542', 'LabParameterHeaderId': 121}]
# 122 SCMP0550
# [{'InvOrder': 1, 'RangeText': 'Risk Cut Off 1 : 100', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0550', 'LabParameterHeaderId': 122}]
# 123 SCMP0552
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0552', 'LabParameterHeaderId': 123}]
# 124 SCMP0555
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0555', 'LabParameterHeaderId': 124}]
# 125 SCMP0562
# [{'InvOrder': 1, 'RangeText': '110 - 130', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '110', 'MaxValue': '130', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0562', 'LabParameterHeaderId': 875}, {'InvOrder': 2, 'RangeText': '118 - 130', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '118', 'MaxValue': '130', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0562', 'LabParameterHeaderId': 875}, {'InvOrder': 1, 'RangeText': '120 - 130', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '120', 'MaxValue': '130', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0562', 'LabParameterHeaderId': 875}, {'InvOrder': 1, 'RangeText': '110 - 130 mEq/L', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '110', 'MaxValue': '130', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0562', 'LabParameterHeaderId': 875}, {'InvOrder': 2, 'RangeText': '118 - 130 mEq/L', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '118', 'MaxValue': '130', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0562', 'LabParameterHeaderId': 875}, {'InvOrder': 1, 'RangeText': '110 - 130', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '110', 'MaxValue': '130', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0562', 'LabParameterHeaderId': 875}, {'InvOrder': 2, 'RangeText': '118 - 130', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '118', 'MaxValue': '130', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0562', 'LabParameterHeaderId': 875}]
# 126 SCMP0563
# [{'InvOrder': 1, 'RangeText': '0 - 6', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '6', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0563', 'LabParameterHeaderId': 126}]
# 127 SCMP0564
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0564', 'LabParameterHeaderId': 127}]
# 128 SCMP0021
# [{'InvOrder': 10, 'RangeText': '6 - 12 Years : 35 - 45', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '35', 'MaxValue': '45', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 4, 'RangeText': '36 - 51', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '36', 'MaxValue': '51', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 5, 'RangeText': '35 - 45', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '35', 'MaxValue': '45', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 2, 'RangeText': '34 - 50', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '34', 'MaxValue': '50', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 6, 'RangeText': '35 - 45 %', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '35', 'MaxValue': '45', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 2, 'RangeText': '42 - 66 %', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '42', 'MaxValue': '66', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 4, 'RangeText': '33 - 40', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '33', 'MaxValue': '40', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 3, 'RangeText': '42 - 66', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '42', 'MaxValue': '66', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '36', 'MaxValue': '46', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 3, 'RangeText': '39 - 54', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Male', 'UnitId': 13, 'MinValue': '39', 'MaxValue': '54', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 5, 'RangeText': '15 Days - 1 Months : 33 - 53', 'FromAgeType': 'Days', 'ToAgeType': 'Days', 'Gender': 'All', 'UnitId': 13, 'MinValue': '33', 'MaxValue': '53', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 7, 'RangeText': '33 - 40', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '33', 'MaxValue': '40', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 11, 'RangeText': 'Male : 41.5 - 50.4', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Male', 'UnitId': 13, 'MinValue': '41.5', 'MaxValue': '50.4', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 9, 'RangeText': '42 - 66', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '42', 'MaxValue': '66', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 5, 'RangeText': '33 - 42', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '33', 'MaxValue': '42', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0021', 'LabParameterHeaderId': 6400}, {'InvOrder': 9, 'RangeText': '34 - 50 %', 'FromAgeType' ...
# 129 SCMP0019
# []
# 130 SCMP0022
# [{'InvOrder': 1, 'RangeText': '88 - 126 /fl', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '88', 'MaxValue': '126', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 6, 'RangeText': '1 - 2 Months : 87 - 103', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '87', 'MaxValue': '103', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 3, 'RangeText': '70 - 86', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '70', 'MaxValue': '86', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 10, 'RangeText': '6 - 12 Years : 77 - 95', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '77', 'MaxValue': '95', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 1, 'RangeText': '83 - 101', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '83', 'MaxValue': '101', 'MinCriticalValue': 75.0, 'MaxCriticalValue': 100.0, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 1, 'RangeText': '77 - 95', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '77', 'MaxValue': '95', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 2, 'RangeText': '77 - 97', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '77', 'MaxValue': '97', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 4, 'RangeText': '75 - 87 /fl', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '75', 'MaxValue': '87', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 2, 'RangeText': '77 - 115', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '77', 'MaxValue': '115', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 6, 'RangeText': '78 - 95', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '78', 'MaxValue': '95', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 1, 'RangeText': '77 - 95', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '77', 'MaxValue': '95', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 9, 'RangeText': '83 - 101', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '83', 'MaxValue': '101', 'MinCriticalValue': 75.0, 'MaxCriticalValue': 100.0, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 7, 'RangeText': '75 - 87', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '75', 'MaxValue': '87', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 8, 'RangeText': '88 - 126', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '88', 'MaxValue': '126', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 7, 'RangeText': '77 - 97 /fl', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '77', 'MaxValue': '97', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0022', 'LabParameterHeaderId': 6500}, {'InvOrder': 5, 'RangeText': '77 - 95  ...
# 131 SCMP0027
# [{'InvOrder': 9, 'RangeText': '35 - 75 %', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Male', 'UnitId': 13, 'MinValue': '35', 'MaxValue': '75', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 9, 'RangeText': '40 - 80', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '40', 'MaxValue': '80', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 80.0, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 1, 'RangeText': '30 - 68', 'FromAgeType': 'Days', 'ToAgeType': 'Days', 'Gender': 'All', 'UnitId': 13, 'MinValue': '30', 'MaxValue': '68', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 1, 'RangeText': '40 - 80', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '40', 'MaxValue': '80', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 80.0, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 4, 'RangeText': 'Child (2 - 14 Y): 35 - 60', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '25', 'MaxValue': '60', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 3, 'RangeText': 'Child (2 M - 2 Y): 25 - 40', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '25', 'MaxValue': '40', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 8, 'RangeText': '43 - 53', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '43', 'MaxValue': '53', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 4, 'RangeText': '43 - 53', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '43', 'MaxValue': '53', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 3, 'RangeText': '35 - 50', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '35', 'MaxValue': '50', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 4, 'RangeText': '34 - 64', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '34', 'MaxValue': '64', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 6, 'RangeText': '35 - 75', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Male', 'UnitId': 13, 'MinValue': '35', 'MaxValue': '75', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 1, 'RangeText': '&gt; 14 Y: 40 - 70', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '40', 'MaxValue': '70', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 2, 'RangeText': '20 - 50', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '20', 'MaxValue': '50', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 5, 'RangeText': '40 - 60', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '40', 'MaxValue': '60', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 2, 'RangeText': '20 - 50 %', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '20', 'MaxValue': '50', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0027', 'LabParameterHeaderId': 5240}, {'InvOrder': 7, 'RangeText': '35 - 70', 'FromAgeT ...
# 132 SCMP0016
# [{'InvOrder': 7, 'RangeText': '14.0 - 21.0', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '14.0', 'MaxValue': '21.0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 4, 'RangeText': '10 - 14 Days : 16.1 - 16.9', 'FromAgeType': 'Days', 'ToAgeType': 'Days', 'Gender': 'All', 'UnitId': 13, 'MinValue': '16.1', 'MaxValue': '16.9', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 9, 'RangeText': '6 - 12 Years : 11.5 - 15.5', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '11.5', 'MaxValue': '15.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 6, 'RangeText': '11.5 15.5 gm/dl', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '11.5', 'MaxValue': '15.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 5, 'RangeText': '10.5 - 13.5', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '10.5', 'MaxValue': '13.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 11, 'RangeText': 'Female : 12.3 - 15.3', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '12.3', 'MaxValue': '15.3', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 6, 'RangeText': '10.5 - 13.5', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '10.5', 'MaxValue': '13.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 3, 'RangeText': '14.5 - 22.5', 'FromAgeType': 'Days', 'ToAgeType': 'Days', 'Gender': 'All', 'UnitId': 13, 'MinValue': '14.5', 'MaxValue': '22.5', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 1, 'RangeText': '9.0 - 14.0', 'FromAgeType': 'Months', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '9.0', 'MaxValue': '14.0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 9, 'RangeText': '12.0 - 15.0', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '12.0', 'MaxValue': '15.0', 'MinCriticalValue': 9.0, 'MaxCriticalValue': 20.0, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 5, 'RangeText': '10.5 - 13.5 gm/dl', 'FromAgeType': 'Months', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '10.5', 'MaxValue': '13.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 1, 'RangeText': '1 Day : 14.0 - 22.0', 'FromAgeType': 'Days', 'ToAgeType': 'Days', 'Gender': 'All', 'UnitId': 13, 'MinValue': '14.0', 'MaxValue': '22.0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 1, 'RangeText': '11.5 - 16.5', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'Female', 'UnitId': 13, 'MinValue': '11.5', 'MaxValue': '16.5', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 1, 'RangeText': '11.0-14.0 gm/dl', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '11.0', 'MaxValue': '14.0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0016', 'LabParameterHeaderId': 6732}, {'InvOrder': 6, 'RangeText': '1 - 2 Months : 9.4 - 13.0', 'FromAgeType': 'Days', 'ToAgeType': 'Months', 'Gender': 'All', 'UnitId': 13, 'MinValue': '9.4', 'MaxValue': '13.0', 'MinCriticalValue' ...
# 133 SCMP0033
# ...
# 986 SCMP0849
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0849', 'LabParameterHeaderId': 2958}, {'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0849', 'LabParameterHeaderId': 2958}, {'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0849', 'LabParameterHeaderId': 2958}]
# 987 SCMP0853
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0853', 'LabParameterHeaderId': 1974}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0853', 'LabParameterHeaderId': 1974}]
# 988 SCMP0858
# [{'InvOrder': 1, 'RangeText': 'Normal : 1.5 - 2.0Therapeutic range : 4.0 - 7.0', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0858', 'LabParameterHeaderId': 1976}, {'InvOrder': 1, 'RangeText': 'Normal : 1.5 - 2.0<br>Therapeutic range : 4.0 - 7.0', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0858', 'LabParameterHeaderId': 1976}]
# (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "."
# LINE 1: ...c range : 4.0 - 7.0', 'Days', 'Years', 'All', 13, '.', '.', ...
#                                                              ^
#
# [SQL: INSERT INTO "LabParameterDetail" ("InvOrder", "RangeText", "FromAgeType", "ToAgeType", "Gender", "UnitId", "MinValue", "MaxValue", "MinCriticalValue", "MaxCriticalValue", "SUBCOMPID", "LabParameterHeaderId") VALUES (%(InvOrder)s, %(RangeText)s, %(FromAgeType)s, %(ToAgeType)s, %(Gender)s, %(UnitId)s, %(MinValue)s, %(MaxValue)s, %(MinCriticalValue)s, %(MaxCriticalValue)s, %(SUBCOMPID)s, %(LabParameterHeaderId)s)]
# [parameters: ({'InvOrder': 1, 'RangeText': 'Normal : 1.5 - 2.0Therapeutic range : 4.0 - 7.0', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0858', 'LabParameterHeaderId': 1976}, {'InvOrder': 1, 'RangeText': 'Normal : 1.5 - 2.0<br>Therapeutic range : 4.0 - 7.0', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0858', 'LabParameterHeaderId': 1976})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# 989 SCMP0866
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '35.0', 'MaxValue': '45.0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0866', 'LabParameterHeaderId': 1978}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '35.0', 'MaxValue': '45.0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0866', 'LabParameterHeaderId': 1978}]
# 990 SCMP0880
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0880', 'LabParameterHeaderId': 2970}, {'InvOrder': 1, 'RangeText': ' Negative', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0880', 'LabParameterHeaderId': 2970}, {'InvOrder': 1, 'RangeText': 'Negative', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0880', 'LabParameterHeaderId': 2970}]
# 991 SCMP0886
# [{'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0886', 'LabParameterHeaderId': 1982}, {'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0886', 'LabParameterHeaderId': 1982}]
# (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "."
# LINE 1: ...Id") VALUES (1, 'NA', 'Days', 'Years', 'All', 13, '.', '.', ...
#                                                              ^
#
# [SQL: INSERT INTO "LabParameterDetail" ("InvOrder", "RangeText", "FromAgeType", "ToAgeType", "Gender", "UnitId", "MinValue", "MaxValue", "MinCriticalValue", "MaxCriticalValue", "SUBCOMPID", "LabParameterHeaderId") VALUES (%(InvOrder)s, %(RangeText)s, %(FromAgeType)s, %(ToAgeType)s, %(Gender)s, %(UnitId)s, %(MinValue)s, %(MaxValue)s, %(MinCriticalValue)s, %(MaxCriticalValue)s, %(SUBCOMPID)s, %(LabParameterHeaderId)s)]
# [parameters: ({'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0886', 'LabParameterHeaderId': 1982}, {'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0886', 'LabParameterHeaderId': 1982})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# 992 SCMP0887
# [{'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0887', 'LabParameterHeaderId': 1984}, {'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': nan, 'MaxCriticalValue': nan, 'SUBCOMPID': 'SCMP0887', 'LabParameterHeaderId': 1984}]
# (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "."
# LINE 1: ...Id") VALUES (1, 'NA', 'Days', 'Years', 'All', 13, '.', '.', ...
#                                                              ^
#
# [SQL: INSERT INTO "LabParameterDetail" ("InvOrder", "RangeText", "FromAgeType", "ToAgeType", "Gender", "UnitId", "MinValue", "MaxValue", "MinCriticalValue", "MaxCriticalValue", "SUBCOMPID", "LabParameterHeaderId") VALUES (%(InvOrder)s, %(RangeText)s, %(FromAgeType)s, %(ToAgeType)s, %(Gender)s, %(UnitId)s, %(MinValue)s, %(MaxValue)s, %(MinCriticalValue)s, %(MaxCriticalValue)s, %(SUBCOMPID)s, %(LabParameterHeaderId)s)]
# [parameters: ({'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0887', 'LabParameterHeaderId': 1984}, {'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': None, 'MaxCriticalValue': None, 'SUBCOMPID': 'SCMP0887', 'LabParameterHeaderId': 1984})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# 993 SCMP0893
# [{'InvOrder': 1, 'RangeText': '24 - 255', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '24', 'MaxValue': '255', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0893', 'LabParameterHeaderId': 993}]
# 994 SCMP0897
# [{'InvOrder': 2, 'RangeText': 'Adult: 4.3 - 22.4', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '4.3', 'MaxValue': '22.4', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0897', 'LabParameterHeaderId': 1988}, {'InvOrder': 1, 'RangeText': 'Children: 3 - 21', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '3', 'MaxValue': '21', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0897', 'LabParameterHeaderId': 1988}]
# 995 SCMP0916
# [{'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0916', 'LabParameterHeaderId': 1990}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0916', 'LabParameterHeaderId': 1990}]
# (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "."
# LINE 1: ...rId") VALUES (1, ' ', 'Days', 'Years', 'All', 13, '.', '.', ...
#                                                              ^
#
# [SQL: INSERT INTO "LabParameterDetail" ("InvOrder", "RangeText", "FromAgeType", "ToAgeType", "Gender", "UnitId", "MinValue", "MaxValue", "MinCriticalValue", "MaxCriticalValue", "SUBCOMPID", "LabParameterHeaderId") VALUES (%(InvOrder)s, %(RangeText)s, %(FromAgeType)s, %(ToAgeType)s, %(Gender)s, %(UnitId)s, %(MinValue)s, %(MaxValue)s, %(MinCriticalValue)s, %(MaxCriticalValue)s, %(SUBCOMPID)s, %(LabParameterHeaderId)s)]
# [parameters: ({'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0916', 'LabParameterHeaderId': 1990}, {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0916', 'LabParameterHeaderId': 1990})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# 996 SCMP0921
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0921', 'LabParameterHeaderId': 996}]
# 997 SCMP0922
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0922', 'LabParameterHeaderId': 997}]
# 998 SCMP0924
# [{'InvOrder': 1, 'RangeText': ' ', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0924', 'LabParameterHeaderId': 998}]
# 999 SCMP0930
# [{'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0930', 'LabParameterHeaderId': 1998}, {'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0930', 'LabParameterHeaderId': 1998}]
# (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "."
# LINE 1: ...Id") VALUES (1, 'NA', 'Days', 'Years', 'All', 13, '.', '.', ...
#                                                              ^
#
# [SQL: INSERT INTO "LabParameterDetail" ("InvOrder", "RangeText", "FromAgeType", "ToAgeType", "Gender", "UnitId", "MinValue", "MaxValue", "MinCriticalValue", "MaxCriticalValue", "SUBCOMPID", "LabParameterHeaderId") VALUES (%(InvOrder)s, %(RangeText)s, %(FromAgeType)s, %(ToAgeType)s, %(Gender)s, %(UnitId)s, %(MinValue)s, %(MaxValue)s, %(MinCriticalValue)s, %(MaxCriticalValue)s, %(SUBCOMPID)s, %(LabParameterHeaderId)s)]
# [parameters: ({'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0930', 'LabParameterHeaderId': 1998}, {'InvOrder': 1, 'RangeText': 'NA', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0930', 'LabParameterHeaderId': 1998})]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# 1000 SCMP0932
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0932', 'LabParameterHeaderId': 1000}]
# (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type numeric: "."
# LINE 1: ...Id") VALUES (1, NULL, 'Days', 'Years', 'All', 13, '.', '.', ...
#                                                              ^
#
# [SQL: INSERT INTO "LabParameterDetail" ("InvOrder", "RangeText", "FromAgeType", "ToAgeType", "Gender", "UnitId", "MinValue", "MaxValue", "MinCriticalValue", "MaxCriticalValue", "SUBCOMPID", "LabParameterHeaderId") VALUES (%(InvOrder)s, %(RangeText)s, %(FromAgeType)s, %(ToAgeType)s, %(Gender)s, %(UnitId)s, %(MinValue)s, %(MaxValue)s, %(MinCriticalValue)s, %(MaxCriticalValue)s, %(SUBCOMPID)s, %(LabParameterHeaderId)s)]
# [parameters: {'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '.', 'MaxValue': '.', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0932', 'LabParameterHeaderId': 1000}]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)
# 1001 SCMP0942
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0942', 'LabParameterHeaderId': 1001}]
# 1002 SCMP0940
# [{'InvOrder': 1, 'RangeText': None, 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0940', 'LabParameterHeaderId': 1002}]
# 1003 SCMP0943
# [{'InvOrder': 1, 'RangeText': '2 - 25', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '2', 'MaxValue': '25', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0943', 'LabParameterHeaderId': 1003}]
# 1004 SCMP0946
# [{'InvOrder': 1, 'RangeText': '&lt; 180', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '180', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0946', 'LabParameterHeaderId': 1004}]
# 1005 SCMP0948
# [{'InvOrder': 1, 'RangeText': '&lt; 140', 'FromAgeType': 'Years', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '140', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0948', 'LabParameterHeaderId': 1005}]
# 1006 SCMP0959
# [{'InvOrder': 1, 'RangeText': '100 - 140', 'FromAgeType': 'Days', 'ToAgeType': 'Years', 'Gender': 'All', 'UnitId': 13, 'MinValue': '0', 'MaxValue': '0', 'MinCriticalValue': 0.0, 'MaxCriticalValue': 0.0, 'SUBCOMPID': 'SCMP0959', 'LabParameterHeaderId': 1006}]

# %%
ids
# Out:
#      LabParameterHeaderId SUBCOMPID
# 0                      88  SCMP0387
# 1                      89  SCMP0395
# 2                      90  SCMP0414
# 3                      91  SCMP0419
# 4                      92  SCMP0432
# ..                    ...       ...
# 914                  1002  SCMP0940
# 915                  1003  SCMP0943
# 916                  1004  SCMP0946
# 917                  1005  SCMP0948
# 918                  1006  SCMP0959
#
# [919 rows x 2 columns]

# %%
#ScanTestMaster
'''
1) Get data from oracle db using below query: 

SELECT l.FKID scansubclassificationid,l.scanname scanname,l.SLNO ,s.SUBCLASSIFICATIONNAME ,s2.PKID scanclassificationid,l2.LOCNM ,
s2.LOCID scanclassificationlocation,s.LOCID scansubclassificationlocation,t.TESTNM ,t.TCODE  FROM admin.SCANSUBCLASSIFICATIONDTL l 
JOIN admin.SCANSUBCLASSIFICATION s ON l.FKID =s.PKID  
JOIN admin.SCANCLASSIFICATIONMASTER s2 ON s.SCANCLASSIFICATION = s2.pkid  
JOIN DIAGNOTECH.TESTMAST t ON t.TESTID = l.SCANNAME 
JOIN ip.LOCATIONMAST l2 ON l2.LOCID =s2.LOCID ;

2) Insert into pgadmin uisng below query

insert into "ScanTestMaster"("ScanClassificationId","Duration","ScanTestName","ScanTestCode","CreatedBy","CreatedDate")
select "ScanClassificationId",10,'AFI','AFI',6776,now() from "ScanClassification" where  
"ShivamScanClassificationId"='SC000006'

'''
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

conn1 = psycopg2.connect(
    database="Test_Shivam_Lab",
    user='postgres',
    password='emr123',
    host='192.168.8.98',
    port= '5432'
    )
oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()

postgresdb=create_engine(r'postgresql+psycopg2://postgres:emr123@192.168.8.98/Test_Shivam_Lab',echo=False)
postgresConn= postgresdb.connect()



oracleQuery=r'''

SELECT s.SUBCLASSIFICATIONNAME ,
s2.PKID scanclassificationid,t.DURATION, 
t.TESTNM scantestname,t.TCODE scantestcode,6776 createdby,current_date createddate
  FROM admin.SCANSUBCLASSIFICATIONDTL l 
JOIN admin.SCANSUBCLASSIFICATION s ON l.FKID =s.PKID  
JOIN admin.SCANCLASSIFICATIONMASTER s2 ON s.SCANCLASSIFICATION = s2.pkid  
JOIN DIAGNOTECH.TESTMAST t ON t.TESTID = l.SCANNAME 
JOIN ip.LOCATIONMAST l2 ON l2.LOCID =s2.LOCID  ORDER BY  t.testnm asc

'''

oracleRecords=pd.read_sql(oracleQuery.replace("\n",""),oracleConn)

oracleRecords
for i in oracleRecords.to_dict('records'):
    #print(i)
    scanClassificationid=i['scanclassificationid']
    duration=i['duration']
    scantestname=i['scantestname']
    scantestcode=i['scantestcode']
    createdby=i['createdby']
    #createddate=i['createdate']
    
    cursor=conn1.cursor()
    pgadminQuery=f'''  
    insert into "ScanTestMaster"("ScanClassificationId","Duration","ScanTestName","ScanTestCode","CreatedBy","CreatedDate")
    select "ScanClassificationId",{duration},'{scantestname}','{scantestcode}',6776,now() from "ScanClassification" where  
    "ShivamScanClassificationId"='{scanClassificationid}' returning "ScanTestMasterId"
    
    '''
    
    cursor.execute(pgadminQuery.replace("\n",""))
    data=cursor.fetchall()
    print(data)
    conn1.commit()
# Out:
# [(93,)]
# [(94,)]
# [(95,)]
# [(96,)]
# [(97,)]
# [(98,)]
# [(99,)]
# [(100,)]
# [(101,)]
# [(102,)]
# [(103,)]
# [(104,)]
# [(105,)]
# [(106,)]
# [(107,)]
# [(108,)]
# [(109,)]
# [(110,)]
# [(111,)]
# [(112,)]
# [(113,)]
# [(114,)]
# [(115,)]
# [(116,)]
# [(117,)]
# [(118,)]
# [(119,)]
# [(120,)]
# [(121,)]
# [(122,)]
# [(123,)]
# [(124,)]
# [(125,)]
# [(126,)]
# [(127,)]
# [(128,)]
# [(129,)]
# [(130,)]
# [(131,)]
# [(132,)]
# [(133,)]
# [(134,)]
# [(135,)]
# [(136,)]
# [(137,)]
# [(138,)]
# [(139,)]
# [(140,)]
# [(141,)]
# [(142,)]
# [(143,)]
# [(144,)]
# [(145,)]
# [(146,)]
# [(147,)]
# [(148,)]
# [(149,)]
# [(150,)]
# [(151,)]
# [(152,)]
# [(153,)]
# [(154,)]
# [(155,)]
# [(156,)]
# [(157,)]
# [(158,)]
# [(159,)]
# [(160,)]
# [(161,)]
# [(162,)]
# [(163,)]
# [(164,)]
# [(165,)]
# [(166,)]
# [(167,)]
# [(168,)]
# [(169,)]
# [(170,)]
# [(171,)]
# [(172,)]
# [(173,)]
# [(174,)]
# [(175,)]
# [(176,)]
# [(177,)]
# [(178,)]
# [(179,)]
# [(180,)]
