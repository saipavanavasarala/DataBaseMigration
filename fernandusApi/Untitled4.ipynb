# %%
from flask import Flask,jsonify
import pandas as pd
from sqlalchemy import create_engine

oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()

limit=10
offset=5
query=f'''SELECT * FROM 
     (SELECT o.*, ROW_NUMBER() OVER (ORDER BY 0) Row_Num FROM OTS1.SCANMEACHINE o)
     WHERE Row_Num BETWEEN {offset} and {limit+offset}'''

dataframe=pd.read_sql(query.replace("\n",""),oracleConn)
oracleConn.close()
x=dataframe.to_dict('records')

x
# Out:
# [{'machinetag': 23,
#   'machinename': 'VOLUSON-E6',
#   'machineid': 'M0000024',
#   'locid': None,
#   'locnm': 'JUBLIEE HILLS',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 5},
#  {'machinetag': 14,
#   'machinename': 'VOLUSON E8',
#   'machineid': 'M0000015',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 6},
#  {'machinetag': 16,
#   'machinename': 'VENUE 40 (HG)',
#   'machineid': 'M0000017',
#   'locid': 'Loc00004',
#   'locnm': 'HYDERGUDA',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 7},
#  {'machinetag': 18,
#   'machinename': 'VOLUSON S6',
#   'machineid': 'M0000019',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 8},
#  {'machinetag': 19,
#   'machinename': 'LOGIC-P3(HG)',
#   'machineid': 'M0000020',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 9},
#  {'machinetag': 20,
#   'machinename': 'K Room',
#   'machineid': 'M0000021',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 1.0,
#   'a': None,
#   'usernm': '1040LAL',
#   'userid': 'IU000386',
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': 'Cub00022',
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 10},
#  {'machinetag': 10,
#   'machinename': 'J Room',
#   'machineid': 'M0000011',
#   'locid': 'Loc00006',
#   'locnm': 'HYDERGUDA-UNIT4',
#   'active': 1.0,
#   'a': None,
#   'usernm': '1040LAL',
#   'userid': 'IU000386',
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': 'Cub00025',
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 11},
#  {'machinetag': 1,
#   'machinename': 'HP Trial',
#   'machineid': 'M0000001',
#   'locid': 'Loc00003',
#   'locnm': 'SUPERDELUX',
#   'active': 0.0,
#   'a': None,
#   'usernm': '1040LAL',
#   'userid': 'IU000386',
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 12},
#  {'machinetag': 2,
#   'machinename': 'VOLUSON 2',
#   'machineid': 'M0000002',
#   'locid': None,
#   'locnm': None,
#   'active': 0.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 13},
#  {'machinetag': 3,
#   'machinename': 'VOLUSON',
#   'machineid': 'M0000005',
#   'locid': 'Loc00003',
#   'locnm': 'SUPERDELUX',
#   'active': nan,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 14},
#  {'machinetag': 4,
#   'machinename': 'LOGIC ',
#   'machineid': 'M0000004',
#   'locid': 'Loc00001',
#   'locnm': 'BOGULKUNTA',
#   'active': 1.0,
#   'a': None,
#   'usernm': None,
#   'userid': None,
#   'wv': None,
#   'fromtime': None,
#   'totime': None,
#   'cubicleid': None,
#   'log_timer': None,
#   'dept_login': None,
#   'subdept_login': None,
#   'cubicle_login': None,
#   'row_num': 15}]

# %%
from flask import Flask,jsonify,request
#from flask_cors import CORS
import pandas as pd
from sqlalchemy import create_engine


app=Flask(__name__)




@app.route("/")
def home():
    return "running"


@app.route("/SCANMEACHINE",methods=["POST"])
def scan():
    print("received request")
    clientData=request.form.to_dict()
    oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
    oracleConn = oracledb.connect()

    limit=int(clientData['limit'])
    offset=int(clientData['offset'])
    
    query=f'''SELECT * FROM 
         (SELECT o.*, ROW_NUMBER() OVER (ORDER BY 0) Row_Num FROM OTS1.SCANMEACHINE o)
         WHERE Row_Num BETWEEN {offset} and {limit+offset}'''

    dataframe=pd.read_sql(query.replace("\n",""),oracleConn)
    oracleConn.close()
    x=dataframe.to_dict('records')
    print(len(x))
    return x
    



if __name__=="__main__":
    app.run(host="192.168.8.173")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://192.168.8.173:5000
# Press CTRL+C to quit
# received request
# [2023-01-30 15:59:36,458] ERROR in app: Exception on /SCANMEACHINE [POST]
# Traceback (most recent call last):
#   File "C:\Python311\Lib\site-packages\flask\app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\pavan\AppData\Local\Temp\ipykernel_5132\89442018.py", line 35, in scan
#     return jsonify(x)
#            ^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\json\__init__.py", line 342, in jsonify
#     return current_app.json.response(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\json\provider.py", line 309, in response
#     f"{self.dumps(obj, **dump_args)}\n", mimetype=mimetype
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\json\provider.py", line 230, in dumps
#     return json.dumps(obj, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\json\__init__.py", line 238, in dumps
#     **kw).encode(obj)
#           ^^^^^^^^^^^
#   File "C:\Python311\Lib\json\encoder.py", line 200, in encode
#     chunks = self.iterencode(o, _one_shot=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\json\encoder.py", line 258, in iterencode
#     return _iterencode(o, 0)
#            ^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\flask\json\provider.py", line 111, in _default
#     return http_date(o)
#            ^^^^^^^^^^^^
#   File "C:\Python311\Lib\site-packages\werkzeug\http.py", line 968, in http_date
#     return email.utils.format_datetime(timestamp, usegmt=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Python311\Lib\email\utils.py", line 162, in format_datetime
#     now = dt.timetuple()
#           ^^^^^^^^^^^^^^
#   File "pandas\_libs\tslibs\nattype.pyx", line 67, in pandas._libs.tslibs.nattype._make_error_func.f
# ValueError: NaTType does not support timetuple
# 192.168.8.173 - - [30/Jan/2023 15:59:36] "POST /SCANMEACHINE HTTP/1.1" 500 -
# 11

# %%
import pandas as pd
from sqlalchemy import create_engine

oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()

limit=10
offset=5
query=f'''SELECT DISTINCT t.DISPLAYPARAM ,t.SUBCOMPONENTNM ,t.SUBCOMPID,6776 AS Createdby ,
CASE WHEN (SELECT count(*) FROM DIAGNOTECH.MCDHNORMALVALUE1 v WHERE v.COMPID = t.SUBCOMPID) > 0 THEN 'numeric' ELSE 'text' END AS referenceoutput
 FROM DIAGNOTECH.TESTSUBCOMPONENTS t'''

dataframe=pd.read_sql(query.replace("\n",""),oracleConn)
oracleConn.close()
x=dataframe.to_dict('records')
x
# Out:
# [{'displayparam': 'Hb `F`',
#   'subcomponentnm': 'Hb `F`',
#   'subcompid': 'SCMP0387',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Appearance',
#   'subcomponentnm': 'Appearance - Fluid Analysis',
#   'subcompid': 'SCMP0395',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'WBC Count',
#   'subcomponentnm': 'WBC Count - Fluid',
#   'subcompid': 'SCMP0414',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'CD3%',
#   'subcomponentnm': 'CD3% - HIV Monitor',
#   'subcompid': 'SCMP0419',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Osmolality *',
#   'subcomponentnm': 'Blood for Osmolality *',
#   'subcompid': 'SCMP0432',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Digoxin',
#   'subcomponentnm': 'Digoxin',
#   'subcompid': 'SCMP0036',
#   'createdby': 6776,
#   'referenceoutput': 'text'},
#  {'displayparam': 'Cortisol (7 - 9 AM)',
#   'subcomponentnm': 'Cortisol (7 - 9 AM)',
#   'subcompid': 'SCMP0037',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Amphetamine',
#   'subcomponentnm': 'Amphetamine - Urine for Drug Screening',
#   'subcompid': 'SCMP0444',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'L E Cell',
#   'subcomponentnm': 'L E Cell',
#   'subcompid': 'SCMP0445',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'LACTATE  - PLASMA',
#   'subcomponentnm': 'LACTATE  - PLASMA',
#   'subcompid': 'SCMP0446',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Organism isolated',
#   'subcomponentnm': 'Culture Organism',
#   'subcompid': 'SCMP0448',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Zinc',
#   'subcomponentnm': 'Zinc',
#   'subcompid': 'SCMP0459',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Leptospirosis IgM',
#   'subcomponentnm': 'Leptospirosis IgM',
#   'subcompid': 'SCMP0462',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'GP 120',
#   'subcomponentnm': 'GP 120',
#   'subcompid': 'SCMP0467',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'P 66',
#   'subcomponentnm': 'P 66',
#   'subcompid': 'SCMP0469',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'P 31',
#   'subcomponentnm': 'P 31',
#   'subcompid': 'SCMP0470',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'P 24',
#   'subcomponentnm': 'P 24',
#   'subcompid': 'SCMP0472',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': '.',
#   'subcomponentnm': 'INTERPRETATION - HIV WESTERN BLOT',
#   'subcompid': 'SCMP0473',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Synovial Fluid for ADA',
#   'subcomponentnm': 'ADA - Synovial Fluid',
#   'subcompid': 'SCMP0474',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Quantity',
#   'subcomponentnm': 'Quantity - Synovial Fluid',
#   'subcompid': 'SCMP0475',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'SPECIMEN',
#   'subcomponentnm': 'Gram Stain',
#   'subcompid': 'SCMP0482',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Granulopoiesis',
#   'subcomponentnm': 'Granulopoiesis - Bone Marrow Aspiration',
#   'subcompid': 'SCMP0493',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'IMPRESSION',
#   'subcomponentnm': 'IMPRESSION - Bone Marrow Aspiration',
#   'subcompid': 'SCMP0501',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'SDRC.No.',
#   'subcomponentnm': 'SDRC.No. - Bone Marrow Aspiration',
#   'subcompid': 'SCMP0502',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Hepatitis C Virus Antibodies',
#   'subcomponentnm': 'HCV (Rapid)',
#   'subcompid': 'SCMP0503',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': '% CD3+/CD45+ (T - Cells)',
#   'subcomponentnm': '% CD3+/CD45+ ( T - Cells) - HIV Monitor',
#   'subcompid': 'SCMP0528',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Neural Tube Defect Screening',
#   'subcomponentnm': 'Neural Tube Defect Screening - Triple Marker Capsule',
#   'subcompid': 'SCMP0527',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Platelet Count',
#   'subcomponentnm': 'Platelet Count',
#   'subcompid': 'SCMP0026',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Eosinophils',
#   'subcomponentnm': 'Eosinophils',
#   'subcompid': 'SCMP0030',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Basophils',
#   'subcomponentnm': 'Basophils',
#   'subcompid': 'SCMP0031',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Specimen',
#   'subcomponentnm': 'Specimen - Smear for Fungal Elemets',
#   'subcompid': 'SCMP0539',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Specimen',
#   'subcomponentnm': 'Specimen - Nail Clipping for Fungal Elemetns',
#   'subcompid': 'SCMP0540',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Fungal Elements',
#   'subcomponentnm': 'Fungal Elements - Nail Clipping for Fungal Elements',
#   'subcompid': 'SCMP0541',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Specimen',
#   'subcomponentnm': 'Specimen - Skin Scrapping for Fungal Elements',
#   'subcompid': 'SCMP0542',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Trisomy 13/18 Screening with NT',
#   'subcomponentnm': 'Trisomy 13/18 Screening with NT - Double Marker Test',
#   'subcompid': 'SCMP0550',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'CRL Value',
#   'subcomponentnm': 'CRL Value - Double Market Test',
#   'subcompid': 'SCMP0552',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Quantity',
#   'subcomponentnm': 'Quantity - CSF for Analysis',
#   'subcompid': 'SCMP0555',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Chlorides',
#   'subcomponentnm': 'Chlorides',
#   'subcompid': 'SCMP0562',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cell Count',
#   'subcomponentnm': 'Cell Count - CSF for Analysis',
#   'subcompid': 'SCMP0563',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Neutrophils',
#   'subcomponentnm': 'Neutrophils - CSF for Analysis',
#   'subcompid': 'SCMP0564',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'PCV',
#   'subcomponentnm': 'PCV',
#   'subcompid': 'SCMP0021',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': None,
#   'subcomponentnm': 'Impression',
#   'subcompid': 'SCMP0019',
#   'createdby': 6776,
#   'referenceoutput': 'text'},
#  {'displayparam': 'MCV',
#   'subcomponentnm': 'MCV',
#   'subcompid': 'SCMP0022',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Neutrophils',
#   'subcomponentnm': 'Neutrophils',
#   'subcompid': 'SCMP0027',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Haemoglobin',
#   'subcomponentnm': 'Haemoglobin',
#   'subcompid': 'SCMP0016',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RBC',
#   'subcomponentnm': 'RBC on Smear',
#   'subcompid': 'SCMP0033',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Angiotensin Converting Enzyme (ACE)',
#   'subcomponentnm': 'Angiotensin Converting Enzyme (ACE)',
#   'subcompid': 'SCMP0038',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Thyroxine Free (FT4)',
#   'subcomponentnm': 'FT4',
#   'subcompid': 'SCMP0039',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': None,
#   'subcomponentnm': '17 -Alpha Hydroyxy progesterone',
#   'subcompid': 'SCMP0042',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'E.S.R. - I Hr. *',
#   'subcomponentnm': 'E.S.R. *',
#   'subcompid': 'SCMP0043',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Cholesterol',
#   'subcomponentnm': 'Total Cholesterol',
#   'subcompid': 'SCMP0045',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HDL',
#   'subcomponentnm': 'HDL',
#   'subcompid': 'SCMP0047',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Metamyelocytes',
#   'subcomponentnm': 'Metamyelocytes',
#   'subcompid': 'SCMP0056',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Band forms',
#   'subcomponentnm': 'Band forms',
#   'subcompid': 'SCMP0057',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': None,
#   'subcomponentnm': 'Monoblasts',
#   'subcompid': 'SCMP0058',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': None,
#   'subcomponentnm': 'Promonocytes',
#   'subcompid': 'SCMP0059',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': None,
#   'subcomponentnm': 'Lymphoblasts',
#   'subcompid': 'SCMP0060',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': None,
#   'subcomponentnm': 'Eosinophilic Myelocytes',
#   'subcompid': 'SCMP0055',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Color',
#   'subcomponentnm': 'Color',
#   'subcompid': 'SCMP0063',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Bilirubin',
#   'subcomponentnm': 'Bilirubin',
#   'subcompid': 'SCMP0066',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Control (APTT)',
#   'subcomponentnm': 'Control (APTT)',
#   'subcompid': 'SCMP0611',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cord TSH*',
#   'subcomponentnm': 'Cord TSH',
#   'subcompid': 'SCMP0637',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cord Total Bilirubin',
#   'subcomponentnm': 'Cord Total Bilirubin',
#   'subcompid': 'SCMP0638',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Result for Mycobacterium genus',
#   'subcomponentnm': 'Mycobacterium genus - TB PCR',
#   'subcompid': 'SCMP0207',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Result for Mycobacterium tuberculosis complex',
#   'subcomponentnm': 'Mycobacterium tuberculosis complex - TB PCR',
#   'subcompid': 'SCMP0208',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lipoprotein (a)',
#   'subcomponentnm': 'Lipoprotein (a)',
#   'subcompid': 'SCMP0213',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Protein C',
#   'subcomponentnm': 'Protein C',
#   'subcompid': 'SCMP0219',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Protein S',
#   'subcomponentnm': 'Protein S',
#   'subcompid': 'SCMP0220',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Sex Hormone Binding Globulin',
#   'subcomponentnm': 'Sex Hormone Binding Globulin',
#   'subcompid': 'SCMP0223',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'BT (BLEEDING TIME)',
#   'subcomponentnm': 'BT (BLEEDING TIME)',
#   'subcompid': 'SCMP0224',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Antithrombin Activity',
#   'subcomponentnm': 'Anti Thrombin III (AT-III)',
#   'subcompid': 'SCMP0228',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti Thyroglobulin Antibodies  ( ATG  )',
#   'subcomponentnm': 'Anti Thyroglobulin Antibodies  ( ATG  )',
#   'subcompid': 'SCMP0229',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'C4 Estimation',
#   'subcomponentnm': 'C4 Estimation',
#   'subcompid': 'SCMP0232',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'CA-125',
#   'subcomponentnm': 'CA-125',
#   'subcompid': 'SCMP0234',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Leucocyte count',
#   'subcomponentnm': 'CD4 Total Leucocyte count',
#   'subcompid': 'SCMP0238',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Absolute lymphocyte count',
#   'subcomponentnm': 'CD4 Absolute lymphocyte count',
#   'subcompid': 'SCMP0239',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Absolute CD4+  Lymphocyte Count',
#   'subcomponentnm': 'Absolute CD4+ Lymphocyte Count',
#   'subcompid': 'SCMP0240',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cortisol (3 - 5 PM)',
#   'subcomponentnm': 'Cortisol (3 - 5 PM)',
#   'subcompid': 'SCMP0241',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Prostatic Specific Antigen',
#   'subcomponentnm': 'PSA',
#   'subcompid': 'SCMP0251',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cutoff OD',
#   'subcomponentnm': 'HbeAg Cutoff OD',
#   'subcompid': 'SCMP0259',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Impression',
#   'subcomponentnm': 'HbeAg Impression',
#   'subcompid': 'SCMP0260',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Test Value',
#   'subcomponentnm': 'HCV Test Value',
#   'subcompid': 'SCMP0261',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Impression',
#   'subcomponentnm': 'HCV Impression',
#   'subcompid': 'SCMP0262',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Test Value',
#   'subcomponentnm': 'HEV IgM Test Value',
#   'subcompid': 'SCMP0263',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cutoff Value',
#   'subcomponentnm': 'HEV IgM Cutoff Value',
#   'subcompid': 'SCMP0264',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Impression',
#   'subcomponentnm': 'HEV IgM Impression',
#   'subcompid': 'SCMP0265',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Hb `A`',
#   'subcomponentnm': 'Hb `A`',
#   'subcompid': 'SCMP0271',
#   'createdby': 6776,
#   'referenceoutput': 'text'},
#  {'displayparam': 'Fungal Elements',
#   'subcomponentnm': 'Fungal Elements',
#   'subcompid': 'SCMP0272',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Appearance',
#   'subcomponentnm': 'Appearance - Stool',
#   'subcompid': 'SCMP0275',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Mucus',
#   'subcomponentnm': 'Mucus - Stool',
#   'subcompid': 'SCMP0276',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Blood',
#   'subcomponentnm': 'Blood - Stool',
#   'subcompid': 'SCMP0277',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Parasites',
#   'subcomponentnm': 'Parasites - Stool',
#   'subcompid': 'SCMP0278',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Quantity',
#   'subcomponentnm': 'Quantity - Fluid',
#   'subcompid': 'SCMP0280',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'WBC',
#   'subcomponentnm': 'WBC - Synovial Fluid',
#   'subcompid': 'SCMP0286',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Neutrophils',
#   'subcomponentnm': 'Neutrophils - Synovial Fluid',
#   'subcompid': 'SCMP0287',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Crystals',
#   'subcomponentnm': 'Crystals - Synovial Fluid',
#   'subcompid': 'SCMP0288',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Test',
#   'subcomponentnm': 'Thromboplastin Generation Test - Test Value',
#   'subcompid': 'SCMP0289',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Plasma Fibrinogen',
#   'subcomponentnm': 'Plasma Fibrinogen',
#   'subcompid': 'SCMP0291',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Organism isolated',
#   'subcomponentnm': 'Culture Organism Combo',
#   'subcompid': 'SCMP0341',
#   'createdby': 6776,
#   'referenceoutput': 'text'},
#  {'displayparam': 'Antibodies to HIV-I and HIV-II',
#   'subcomponentnm': 'HIV Antibodies (Rapid)',
#   'subcompid': 'SCMP0342',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'LDL',
#   'subcomponentnm': 'LDL',
#   'subcompid': 'SCMP0346',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total hCG in serum',
#   'subcomponentnm': 'Beta HCG Total - Serum',
#   'subcompid': 'SCMP0349',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Insulin',
#   'subcomponentnm': 'Insulin',
#   'subcompid': 'SCMP0351',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Antibodies to HIV 1 and 2',
#   'subcomponentnm': 'HIV Test Value (ELISA)',
#   'subcompid': 'SCMP0354',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Impression',
#   'subcomponentnm': 'HIV ELISA Impression',
#   'subcompid': 'SCMP0356',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Magnesium',
#   'subcomponentnm': 'Magnesium - Serum',
#   'subcompid': 'SCMP0357',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cotinine (Nicotine)',
#   'subcomponentnm': 'Cotinine - Urine',
#   'subcompid': 'SCMP0358',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Height',
#   'subcomponentnm': 'MER - Height',
#   'subcompid': 'SCMP0359',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Weight',
#   'subcomponentnm': 'MER - Weight',
#   'subcompid': 'SCMP0360',
#   'createdby': 6776,
#   'referenceoutput': 'text'},
#  {'displayparam': 'Cortisol',
#   'subcomponentnm': 'Cortisol',
#   'subcompid': 'SCMP0365',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'PPD',
#   'subcomponentnm': 'Mantoux PPD Adult',
#   'subcompid': 'SCMP0367',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Pus Cells',
#   'subcomponentnm': 'Pus Cells - Stool',
#   'subcompid': 'SCMP0372',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Parasites',
#   'subcomponentnm': 'Parasites - Stool Microscopic',
#   'subcompid': 'SCMP0377',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'S. Typhi "H"',
#   'subcomponentnm': 'S. Typhi "H"',
#   'subcompid': 'SCMP0383',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'S. Paratyphi "AH"',
#   'subcomponentnm': 'S. Paratyphi "AH"',
#   'subcompid': 'SCMP0384',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RDW',
#   'subcomponentnm': 'RDW',
#   'subcompid': 'SCMP0386',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Slow Moving Hb Band',
#   'subcomponentnm': 'Slow Moving Hb Band',
#   'subcompid': 'SCMP0389',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Fast Moving Hb Band',
#   'subcomponentnm': 'Fast Moving Hb Band',
#   'subcompid': 'SCMP0390',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lipase',
#   'subcomponentnm': 'Lipase - Serum',
#   'subcompid': 'SCMP0394',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Specific Gravity',
#   'subcomponentnm': 'Specific gravity - Fluid',
#   'subcompid': 'SCMP0396',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Mesothelial Cells',
#   'subcomponentnm': 'Mesothelial Cells - CSF for Analysis',
#   'subcompid': 'SCMP0566',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Urinary Volume',
#   'subcomponentnm': 'Total Urinary Volume - 24 hrs Urine',
#   'subcompid': 'SCMP0570',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Oxalate',
#   'subcomponentnm': 'Oxalate - 24 hrs Urine',
#   'subcompid': 'SCMP0571',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Chyle',
#   'subcomponentnm': 'Urine for Chyle',
#   'subcompid': 'SCMP0572',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Mycobacterial DNA PCR',
#   'subcomponentnm': 'Mycobacterial DNA PCR - Biopsy for TB PCR (Qualitative)',
#   'subcompid': 'SCMP0577',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Absolute Eosinophil Count (AEC)',
#   'subcomponentnm': 'Absolute Eosinophil Count (AEC)',
#   'subcompid': 'SCMP0579',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Fungal Elements',
#   'subcomponentnm': 'Throat Swab for Fungal Elements',
#   'subcompid': 'SCMP0580',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Colony Count',
#   'subcomponentnm': 'Colony Count',
#   'subcompid': 'SCMP0646',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Quantity',
#   'subcomponentnm': 'Quantity',
#   'subcompid': 'SCMP0588',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': '%  of Transferrin Saturation',
#   'subcomponentnm': '%  of Transferrin Saturation',
#   'subcompid': 'SCMP0593',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cord Blood Group',
#   'subcomponentnm': 'Cord Blood Group',
#   'subcompid': 'SCMP0603',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'PIH Creatinine',
#   'subcomponentnm': 'PIH Creatinine',
#   'subcompid': 'SCMP0612',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lymphocytes',
#   'subcomponentnm': 'Lymphocytes Fluid',
#   'subcompid': 'SCMP0643',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Result',
#   'subcomponentnm': 'Result',
#   'subcompid': 'SCMP0647',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Quantity',
#   'subcomponentnm': 'Quantity Semen',
#   'subcompid': 'SCMP0648',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Coagulum',
#   'subcomponentnm': 'Coagulum Senem',
#   'subcompid': 'SCMP0649',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Abnormal Cells',
#   'subcomponentnm': 'Abnormal Cells',
#   'subcompid': 'SCMP0656',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': '24 Hrs. Urine Protein',
#   'subcomponentnm': '24 Hrs. Urine Protein',
#   'subcompid': 'SCMP0661',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Epithelial Cells',
#   'subcomponentnm': 'Epithelial Cells - Stool',
#   'subcompid': 'SCMP0375',
#   'createdby': 6776,
#   'referenceoutput': 'text'},
#  {'displayparam': 'Proteins',
#   'subcomponentnm': 'Proteins',
#   'subcompid': 'SCMP0560',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lupus Anti coagulant  Confirm *',
#   'subcomponentnm': 'Lupus Anti coagulant  Confirm *',
#   'subcompid': 'SCMP0624',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Polymorphs',
#   'subcomponentnm': 'Polymorphs',
#   'subcompid': 'SCMP0642',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Abnormal Forms',
#   'subcomponentnm': 'Abnormal Forms Semen',
#   'subcompid': 'SCMP0651',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lymphocytes',
#   'subcomponentnm': 'Lymphocytes',
#   'subcompid': 'SCMP0028',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Monocytes',
#   'subcomponentnm': 'Monocytes',
#   'subcompid': 'SCMP0029',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'VLDL',
#   'subcomponentnm': 'VLDL',
#   'subcompid': 'SCMP0049',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Clarity',
#   'subcomponentnm': 'Clarity',
#   'subcompid': 'SCMP0064',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Protein',
#   'subcomponentnm': 'Protein',
#   'subcompid': 'SCMP0069',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Nitrite',
#   'subcomponentnm': 'Nitrite',
#   'subcompid': 'SCMP0070',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Leucocyte',
#   'subcomponentnm': 'Leucocyte in Urine',
#   'subcompid': 'SCMP0071',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Urobilinogen',
#   'subcomponentnm': 'Urobilinogen',
#   'subcompid': 'SCMP0074',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'PUS Cells',
#   'subcomponentnm': 'PUS cells',
#   'subcompid': 'SCMP0075',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Epithelial Cells',
#   'subcomponentnm': 'Epithelial Cells',
#   'subcompid': 'SCMP0076',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Casts',
#   'subcomponentnm': 'Casts in Urine',
#   'subcompid': 'SCMP0078',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Direct Bilirubin',
#   'subcomponentnm': 'Direct Bilirubin',
#   'subcompid': 'SCMP0086',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Serum Creatinine',
#   'subcomponentnm': 'Serum Creatinine',
#   'subcompid': 'SCMP0095',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Calcium',
#   'subcomponentnm': 'Calcium - Serum',
#   'subcompid': 'SCMP0096',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Plasma Sugar Post-Glucose',
#   'subcomponentnm': 'PGBS - Post Glucose Blood Glucose',
#   'subcompid': 'SCMP0116',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Eosinophils',
#   'subcomponentnm': 'Eosinophils - Urine',
#   'subcompid': 'SCMP0134',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Porphobilinogen',
#   'subcomponentnm': 'Porphobilinogen - Urine',
#   'subcompid': 'SCMP0143',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Urinary Proteins',
#   'subcomponentnm': 'Proteins - Urine /day',
#   'subcompid': 'SCMP0183',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Urinary 5-HIAA',
#   'subcomponentnm': '5-HIAA - Urine 24 hours',
#   'subcompid': 'SCMP0184',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cardiolipin IgM',
#   'subcomponentnm': 'Cardiolipin  IgM',
#   'subcompid': 'SCMP0185',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Human Growth Hormone',
#   'subcomponentnm': 'Human Growth Hormone',
#   'subcompid': 'SCMP0186',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Immunoglobulin G (IgG)',
#   'subcomponentnm': 'Immunoglobulin G (IgG)',
#   'subcompid': 'SCMP0188',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'PH',
#   'subcomponentnm': 'PH - Semen',
#   'subcompid': 'SCMP0192',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Color Semen',
#   'subcomponentnm': 'Color Semen',
#   'subcompid': 'SCMP0193',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Liquification Time',
#   'subcomponentnm': 'Liquification Time - Semen',
#   'subcompid': 'SCMP0194',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Sperm Count',
#   'subcomponentnm': 'Sperm Count',
#   'subcompid': 'SCMP0196',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Sluggish',
#   'subcomponentnm': 'Sluggish',
#   'subcompid': 'SCMP0198',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RBC',
#   'subcomponentnm': 'RBC - Semen',
#   'subcompid': 'SCMP0203',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Clumping',
#   'subcomponentnm': 'Clumping - Semen',
#   'subcompid': 'SCMP0205',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': '25 hydroxy D 2',
#   'subcomponentnm': '25 hydroxy D 2 Vitamin',
#   'subcompid': 'SCMP0209',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Varicella Zoster IgG',
#   'subcomponentnm': 'Varicella Zoster IgG',
#   'subcompid': 'SCMP0210',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Thyroglobulin',
#   'subcomponentnm': 'Thyroglobulin',
#   'subcompid': 'SCMP0222',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Valproic Acid (Na valporate)',
#   'subcomponentnm': 'Valproic Acid (Na valporate)',
#   'subcompid': 'SCMP0302',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RPR *',
#   'subcomponentnm': 'VDRL (RPR)',
#   'subcompid': 'SCMP0303',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Estimated Average Glucose (eAG)',
#   'subcomponentnm': 'Estimated Average Glucose',
#   'subcompid': 'SCMP0307',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'teting',
#   'subcomponentnm': 'testsagar',
#   'subcompid': 'SCMP0309',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'sagar',
#   'subcomponentnm': 'sagar',
#   'subcompid': 'SCMP0310',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Homocysteine',
#   'subcomponentnm': 'Homocysteine',
#   'subcompid': 'SCMP0312',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Impression',
#   'subcomponentnm': 'HIV Impression',
#   'subcompid': 'SCMP0314',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Test Value',
#   'subcomponentnm': 'HBsAg Test Value',
#   'subcompid': 'SCMP0315',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Impression',
#   'subcomponentnm': 'HBsAg Impression',
#   'subcompid': 'SCMP0316',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Glucose 1/2 Hour Post-Glucose',
#   'subcomponentnm': 'Glucose 1/2 Hour Post-Glucose',
#   'subcompid': 'SCMP0317',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Protein Creatinine Ratio',
#   'subcomponentnm': 'Protein Creatinine Ratio - Urine',
#   'subcompid': 'SCMP0326',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Spot Protein',
#   'subcomponentnm': 'Spot Proteins - Urine',
#   'subcompid': 'SCMP0327',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Dengue NS1 Antigen*',
#   'subcomponentnm': 'Dengue NS1 Antigen',
#   'subcompid': 'SCMP0329',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Dengue IgM',
#   'subcomponentnm': 'Dengue IgM Quantitative',
#   'subcompid': 'SCMP0333',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Herpes Simplex Virus 1 and 2 IgM (Combined)',
#   'subcomponentnm': 'HSV IgM',
#   'subcompid': 'SCMP0335',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Bicarbonate',
#   'subcomponentnm': 'Bicarbonate - Serum',
#   'subcompid': 'SCMP0336',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Sensitivity',
#   'subcomponentnm': 'Sensitivity',
#   'subcompid': 'SCMP0339',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'TIBC',
#   'subcomponentnm': 'TIBC',
#   'subcompid': 'SCMP0337',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Transferrin Saturation',
#   'subcomponentnm': 'Transferrin Saturation',
#   'subcompid': 'SCMP0338',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Specimen',
#   'subcomponentnm': 'Culture Specimen',
#   'subcompid': 'SCMP0340',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV Antibodies',
#   'subcomponentnm': 'HIV Antibodies (Determine)',
#   'subcompid': 'SCMP0343',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti Mullerian Hormone*',
#   'subcomponentnm': 'AMH',
#   'subcompid': 'SCMP0345',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Direct Coombs Test',
#   'subcomponentnm': 'Direct Coombs Test (DCT)',
#   'subcompid': 'SCMP0350',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'pH',
#   'subcomponentnm': 'pH - Fluid',
#   'subcompid': 'SCMP0397',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'I C T (Indirect coombs test)',
#   'subcomponentnm': 'I C T (Indirect coombs test)',
#   'subcompid': 'SCMP0399',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': '% Lysis',
#   'subcomponentnm': 'Osmatic Fragility - % Lysis',
#   'subcompid': 'SCMP0401',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Thyroid Stimulating Hormone (TSH)',
#   'subcomponentnm': 'TSH',
#   'subcompid': 'SCMP0089',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Mean Corpuscular Fragility (MCF)',
#   'subcomponentnm': 'Osmatic Fragility MCF',
#   'subcompid': 'SCMP0406',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Leukocyte Count',
#   'subcomponentnm': 'Total Leukocyte Count - HIV Monitor',
#   'subcompid': 'SCMP0417',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Test for Proteins',
#   'subcomponentnm': 'Test for Proteins - Fluid',
#   'subcompid': 'SCMP0411',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Test for Cholesterol',
#   'subcomponentnm': 'Test for Cholesterol - Fluid',
#   'subcompid': 'SCMP0413',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti CCP Antibodies',
#   'subcomponentnm': 'Anti CCP Antibodies',
#   'subcompid': 'SCMP0427',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Albumin',
#   'subcomponentnm': 'Microalbumin - 24 Hours Urine',
#   'subcompid': 'SCMP0434',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Infectious Mononucleosis (IM)',
#   'subcomponentnm': 'Infectious Mononucleosis (IM)',
#   'subcompid': 'SCMP0454',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Hepatitis A Virus IgM',
#   'subcomponentnm': 'Hepatitis A Virus IgM',
#   'subcompid': 'SCMP0455',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Varicella Zoster IgM',
#   'subcomponentnm': 'Varicella Zoster IgM',
#   'subcompid': 'SCMP0456',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lithium',
#   'subcomponentnm': 'Lithium',
#   'subcompid': 'SCMP0458',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Chikungunya  IgM Antibody',
#   'subcomponentnm': 'Chikungunya  IgM Antibody',
#   'subcompid': 'SCMP0460',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Stool for Rota Virus',
#   'subcomponentnm': 'Rota Virus',
#   'subcompid': 'SCMP0461',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Preliminary Report 2',
#   'subcomponentnm': 'Preliminary Report 2  - Culture and Sensitivity of Blood',
#   'subcompid': 'SCMP0464',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Final Report',
#   'subcomponentnm': 'Final Report  - Culture and Sensitivity of Blood',
#   'subcompid': 'SCMP0465',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'C Peptide',
#   'subcomponentnm': 'C Peptide',
#   'subcompid': 'SCMP0429',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV 1 VIRAL LOAD',
#   'subcomponentnm': 'HIV 1 VIRAL LOAD - HIV Monitor',
#   'subcompid': 'SCMP0430',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Viscosity',
#   'subcomponentnm': 'Viscosity - Synovial Fluid',
#   'subcompid': 'SCMP0477',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Fibrin Clot',
#   'subcomponentnm': 'Fibrin Clot - Synovial Fluid',
#   'subcompid': 'SCMP0479',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cell Count',
#   'subcomponentnm': 'Cell Count - Synovial Fluid',
#   'subcompid': 'SCMP0480',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'DHEA - S (Dehydroepiandrosterone-Sulphate)',
#   'subcomponentnm': 'DHEA - S',
#   'subcompid': 'SCMP0481',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Organism Isolated',
#   'subcomponentnm': 'Organism Isolated',
#   'subcompid': 'SCMP0487',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cellularity',
#   'subcomponentnm': 'Cellularity - Bone Marrow Aspiration',
#   'subcompid': 'SCMP0490',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Plasma Cells',
#   'subcomponentnm': 'Plasma Cells - Bone Marrow Aspiration',
#   'subcompid': 'SCMP0495',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Reticuloendothelial cells',
#   'subcomponentnm': 'Reticuloendothelial cells - Bone Marrow Aspiration',
#   'subcompid': 'SCMP0496',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Haemoparasites',
#   'subcomponentnm': 'Haemoparasites - Bone Marrow Aspiration',
#   'subcompid': 'SCMP0497',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lymphocytes',
#   'subcomponentnm': 'Lymphocytes - Bone Marrow Aspiration',
#   'subcompid': 'SCMP0500',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Heinz Bodies',
#   'subcomponentnm': 'Heinz Bodies Test',
#   'subcompid': 'SCMP0505',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'H/O IVF',
#   'subcomponentnm': 'H/O IVF - Triple Marker Capsule',
#   'subcompid': 'SCMP0511',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Ethnic Origin',
#   'subcomponentnm': 'Ethnic Origin - Triple Marker Capsule',
#   'subcompid': 'SCMP0512',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Method for Gestation Age Estimation',
#   'subcomponentnm': 'Method for Gestation Age Estimation - Triple Marker Capsule',
#   'subcompid': 'SCMP0516',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Foetus (Nos)',
#   'subcomponentnm': 'Foetus (Nos) - Triple Marker Capsule',
#   'subcompid': 'SCMP0517',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HCG',
#   'subcomponentnm': 'HCG - Triple Marker Capsule',
#   'subcompid': 'SCMP0520',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Unconjugated Estriol MOM',
#   'subcomponentnm': 'Unconjugated Estriol MOM - Triple Marker Capsule',
#   'subcompid': 'SCMP0524',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Trisomy 21 Screening',
#   'subcomponentnm': 'Trisomy 21 Screening - Triple Marker Capsule',
#   'subcompid': 'SCMP0525',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Trisomy 18 Screening',
#   'subcomponentnm': 'Trisomy 18 Screening - Triple Marker Capsule',
#   'subcompid': 'SCMP0526',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': '% CD3+/CD4+ (T - Helper Cells)',
#   'subcomponentnm': '% CD3+/CD4+ (T - Helper Cells) - HIV Monitor',
#   'subcompid': 'SCMP0529',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': '% CD3+/CD8+ (T - Suppressor Cells)',
#   'subcomponentnm': '% CD3+/CD8+ (T - Suppressor Cells) - HIV Monitor',
#   'subcompid': 'SCMP0530',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Absolute CD8+ Lymphocyte Count',
#   'subcomponentnm': 'Absolute CD8+ Lymphocyte Count - HIV Monitor',
#   'subcompid': 'SCMP0531',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Gamma Interferon',
#   'subcomponentnm': 'Gamma Interferon - Blood for Quantiferon TB Gold (QFT)',
#   'subcompid': 'SCMP0535',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Phadiatop US',
#   'subcomponentnm': ' Phadiatop US - Allergen - Phadiatop Adult',
#   'subcompid': 'SCMP0536',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Free Beta Human Chorionic Gonadotropin',
#   'subcomponentnm': 'Free Beta Human Chorionic Gonadotropin - Double Marker Test',
#   'subcompid': 'SCMP0544',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Free Beta HCG MOM',
#   'subcomponentnm': 'Free Beta HCG MOM - Double Marker Test',
#   'subcompid': 'SCMP0546',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Trisomy 21 Screening With NT',
#   'subcomponentnm': 'Trisomy 21 Screening With NT - Double Marker Test',
#   'subcompid': 'SCMP0549',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Appearance',
#   'subcomponentnm': 'Appearance - CSF for Analysis',
#   'subcompid': 'SCMP0556',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'pH',
#   'subcomponentnm': 'pH - CSF for Analysis',
#   'subcompid': 'SCMP0557',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Sugar',
#   'subcomponentnm': 'Sugar - CSF for Analysis',
#   'subcompid': 'SCMP0561',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Ferric Chloride',
#   'subcomponentnm': 'Urine for Ferric Chloride',
#   'subcompid': 'SCMP0573',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Methaemoglobin',
#   'subcomponentnm': 'Methaemoglobin',
#   'subcompid': 'SCMP0578',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Investigation',
#   'subcomponentnm': 'Investigation',
#   'subcompid': 'SCMP0581',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Urine for Albumin',
#   'subcomponentnm': 'Urine for Albumin',
#   'subcompid': 'SCMP0582',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Bilirubin',
#   'subcomponentnm': 'Total Bilirubin',
#   'subcompid': 'SCMP0584',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lot No',
#   'subcomponentnm': 'Lot No',
#   'subcompid': 'SCMP0587',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Leucocytes',
#   'subcomponentnm': 'Leucocytes',
#   'subcompid': 'SCMP0589',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Test (PT)',
#   'subcomponentnm': 'Test (PT)',
#   'subcompid': 'SCMP0594',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'ISI',
#   'subcomponentnm': 'ISI',
#   'subcompid': 'SCMP0657',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'P R',
#   'subcomponentnm': 'P R',
#   'subcompid': 'SCMP0597',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'I N R',
#   'subcomponentnm': 'I N R',
#   'subcompid': 'SCMP0598',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HBsAg (ELISA)',
#   'subcomponentnm': 'HBsAg (ELISA)',
#   'subcompid': 'SCMP0599',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Falci Vax',
#   'subcomponentnm': 'Falci Vax',
#   'subcompid': 'SCMP0635',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'FIBRINOGEN DEGRADATION PRODUCTS*',
#   'subcomponentnm': 'FDP',
#   'subcompid': 'SCMP0604',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'DDimer*',
#   'subcomponentnm': 'DDimer',
#   'subcompid': 'SCMP0605',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Plasma Glucose Ist hour',
#   'subcomponentnm': 'Plasma Glucose Ist hour',
#   'subcompid': 'SCMP0607',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Specimen',
#   'subcomponentnm': 'SPECIMEN',
#   'subcompid': 'SCMP0609',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Ova',
#   'subcomponentnm': 'Ova Stool',
#   'subcompid': 'SCMP0615',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Urine Creatinine',
#   'subcomponentnm': 'Fluid Creatinine',
#   'subcompid': 'SCMP0619',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti-Cardiolipin antibodies  (IgG) *',
#   'subcomponentnm': 'Anti-Cardiolipin antibodies  (IgG) *',
#   'subcompid': 'SCMP0627',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Micro biology report',
#   'subcomponentnm': 'Micro biology report',
#   'subcompid': 'SCMP0631',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Bile Acids',
#   'subcomponentnm': 'Total Bile Acids',
#   'subcompid': 'SCMP0632',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti HCV (TRI-DOT)',
#   'subcomponentnm': 'Anti HCV (Spot)',
#   'subcompid': 'SCMP0633',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti HCV (ELISA)',
#   'subcomponentnm': 'Anti HCV (ELISA)',
#   'subcompid': 'SCMP0634',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lot Number',
#   'subcomponentnm': 'Lot Number',
#   'subcompid': 'SCMP0636',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV I & II(ELISA)',
#   'subcomponentnm': 'HIV I  II(ELISA)',
#   'subcompid': 'SCMP0639',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Type of fluid',
#   'subcomponentnm': 'Type of fluid',
#   'subcompid': 'SCMP0640',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RBC',
#   'subcomponentnm': 'RBC Fluid',
#   'subcompid': 'SCMP0641',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Volume Of Urine',
#   'subcomponentnm': 'Total Volume Of Urine',
#   'subcompid': 'SCMP0662',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Min. Volume Of Urine',
#   'subcomponentnm': 'Min. Volume Of Urine',
#   'subcompid': 'SCMP0663',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Vitamin B12',
#   'subcomponentnm': 'Vitamin B12',
#   'subcompid': 'SCMP0083',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'CA 19.9',
#   'subcomponentnm': 'CA 19.9',
#   'subcompid': 'SCMP0236',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Estradiol - E2',
#   'subcomponentnm': 'Estradiol - E2',
#   'subcompid': 'SCMP0244',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Hepatitis A Virus IgM',
#   'subcomponentnm': 'HAV IgM',
#   'subcompid': 'SCMP0252',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Test Value',
#   'subcomponentnm': 'HBc Antigen - IgM - Test Value',
#   'subcompid': 'SCMP0254',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Coccaine',
#   'subcomponentnm': 'Coccaine in Urine',
#   'subcompid': 'SCMP0297',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Benzodiazepine',
#   'subcomponentnm': 'Benzodiazepine in Urine',
#   'subcompid': 'SCMP0298',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Barbiturate',
#   'subcomponentnm': 'Barbiturate in Urine',
#   'subcompid': 'SCMP0299',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Amphetamine',
#   'subcomponentnm': 'Amphetamine in Urine',
#   'subcompid': 'SCMP0300',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Glucose 1 Hour Post-Glucose',
#   'subcomponentnm': 'Glucose 1 Hour Post-Glucose',
#   'subcompid': 'SCMP0318',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Glucose 2 Hours Post-Glucose',
#   'subcomponentnm': 'Glucose 2 Hours Post-Glucose',
#   'subcompid': 'SCMP0319',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'eGFR',
#   'subcomponentnm': 'MDRD - eGFR',
#   'subcompid': 'SCMP0328',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'IgG Antibodies to Dengue Virus',
#   'subcomponentnm': 'Dengue IgG Qualitative',
#   'subcompid': 'SCMP0330',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti Nuclear Antibodies',
#   'subcomponentnm': 'ANA',
#   'subcompid': 'SCMP0344',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Total Urinary Creatinine',
#   'subcomponentnm': 'Urinary Creatinine - 24 Hours',
#   'subcompid': 'SCMP0347',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Creatinine Clearance',
#   'subcomponentnm': 'Creatinine Clearance - Urine',
#   'subcompid': 'SCMP0348',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Mantoux Test',
#   'subcomponentnm': 'Mantoux Test',
#   'subcompid': 'SCMP0366',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Reaction',
#   'subcomponentnm': 'Reaction - Stool',
#   'subcompid': 'SCMP0371',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RBCs',
#   'subcomponentnm': 'RBCs - Stool',
#   'subcompid': 'SCMP0373',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Random Urine for Creatinine',
#   'subcomponentnm': 'Random Urine for Creatinine',
#   'subcompid': 'SCMP0667',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
# ...
#   'subcompid': 'SCMP0513',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'CPK-MB',
#   'subcomponentnm': 'CPK-MB - Serum',
#   'subcompid': 'SCMP0113',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Chloride',
#   'subcomponentnm': 'Chloride - Urine for Electrolytes',
#   'subcompid': 'SCMP0133',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Normal Forms',
#   'subcomponentnm': 'Normal Forms - Semen',
#   'subcompid': 'SCMP0200',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Specific Gravity',
#   'subcomponentnm': 'Specific Gravity - CSF for Analysis',
#   'subcompid': 'SCMP0558',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Result',
#   'subcomponentnm': 'Result Gram Stain',
#   'subcompid': 'SCMP0664',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Organism Isolated',
#   'subcomponentnm': 'Organism Isolated (Double )',
#   'subcompid': 'SCMP0700',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Ionised calcium',
#   'subcomponentnm': 'Ionised calcium',
#   'subcompid': 'SCMP0697',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Urine for Bile Salts',
#   'subcomponentnm': 'Urine for Bile Salts',
#   'subcompid': 'SCMP0724',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Pus cells',
#   'subcomponentnm': 'Pus cells semen new',
#   'subcompid': 'SCMP0745',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Mc Crady`s Classification:',
#   'subcomponentnm': 'Mc Crady`s Classification:',
#   'subcompid': 'SCMP0761',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'PCV',
#   'subcomponentnm': 'PCV (Fluid)',
#   'subcompid': 'SCMP0763',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HbF',
#   'subcomponentnm': 'HbF (HPLC)',
#   'subcompid': 'SCMP0774',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Control (APTT) QC',
#   'subcomponentnm': 'Control (APTT) QC',
#   'subcompid': 'SCMP0781',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Triglycerides',
#   'subcomponentnm': 'Triglycerides - Fluid',
#   'subcompid': 'SCMP0792',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'MCV (VDC)',
#   'subcomponentnm': 'MCV (VDC)',
#   'subcompid': 'SCMP0802',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'CA24',
#   'subcomponentnm': 'CA24',
#   'subcompid': 'SCMP0817',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Ketone',
#   'subcomponentnm': 'Ketone CUE',
#   'subcompid': 'SCMP0874',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Bilirubin',
#   'subcomponentnm': 'CUE Bilirubin',
#   'subcompid': 'SCMP0875',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Blood',
#   'subcomponentnm': 'CUE Blood',
#   'subcompid': 'SCMP0877',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'pH',
#   'subcomponentnm': 'CUE pH',
#   'subcompid': 'SCMP0878',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Protein',
#   'subcomponentnm': 'CUE Protein',
#   'subcompid': 'SCMP0879',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Urine Volume',
#   'subcomponentnm': 'Urine Volume',
#   'subcompid': 'SCMP0882',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Semen Volume',
#   'subcomponentnm': 'Semen Volume',
#   'subcompid': 'SCMP0884',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Follicle-stimulating hormone (FSH)',
#   'subcomponentnm': 'FSH DAY 2',
#   'subcompid': 'SCMP0890',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Lymphocyte Cell Count Absolute',
#   'subcomponentnm': 'Lymphocyte Cell Count Absolute',
#   'subcompid': 'SCMP0895',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'CORTISOL STIMULATION BY ACTH',
#   'subcomponentnm': 'CORTISOL STIMULATION BY ACTH',
#   'subcompid': 'SCMP0896',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cortisol Post ACTH stimulation  (60 Minutes)',
#   'subcomponentnm': 'Cortisol Post ACTH stimulation (60 Minutes)',
#   'subcompid': 'SCMP0898',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Hb',
#   'subcomponentnm': 'Hb',
#   'subcompid': 'SCMP0902',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HCT',
#   'subcomponentnm': 'HCT (HPLC)',
#   'subcompid': 'SCMP0903',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'MCHC',
#   'subcomponentnm': 'MCHC (HPLC)',
#   'subcompid': 'SCMP0907',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RBC COUNT',
#   'subcomponentnm': 'RBC COUNT (HPLC)',
#   'subcompid': 'SCMP0908',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RBC Morphology',
#   'subcomponentnm': 'RBC Morphology',
#   'subcompid': 'SCMP0909',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Sickling Test',
#   'subcomponentnm': 'Sickling',
#   'subcompid': 'SCMP0910',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Chromatographic profile',
#   'subcomponentnm': 'Chromatographic profile',
#   'subcompid': 'SCMP0911',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Vitamin B12 *',
#   'subcomponentnm': 'Vitamin B12 *',
#   'subcompid': 'SCMP0913',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Vitamin D',
#   'subcomponentnm': 'Vitamin D',
#   'subcompid': 'SCMP0914',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Chromatogram findings  :-',
#   'subcomponentnm': 'Chromatogram findings  :-',
#   'subcompid': 'SCMP0919',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Others',
#   'subcomponentnm': 'Others(hplc1)',
#   'subcompid': 'SCMP0920',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'VITAMIN D TOTAL',
#   'subcomponentnm': 'VITAMIN D TOTAL',
#   'subcompid': 'SCMP0923',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Result (CLIA)',
#   'subcomponentnm': 'Result (CLIA)',
#   'subcompid': 'SCMP0926',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Dengue NS1 Spot',
#   'subcomponentnm': 'Dengue NS1 Spot',
#   'subcompid': 'SCMP0933',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Dengue NS1 Elisa',
#   'subcomponentnm': 'Dengue NS1 Elisa',
#   'subcompid': 'SCMP0934',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV I (Antibody)     (Immuno Chromatograpy)',
#   'subcomponentnm': 'HIV I (Antibody)    (Immuno Chromatograpy)',
#   'subcompid': 'SCMP0941',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Insulin 1st Hour',
#   'subcomponentnm': '1st Hour',
#   'subcompid': 'SCMP0945',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Insulin 2nd Hour',
#   'subcomponentnm': '2nd Hour',
#   'subcompid': 'SCMP0947',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Ascitic Albumin',
#   'subcomponentnm': 'Ascitic Albumin\t',
#   'subcompid': 'SCMP0950',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'COVID-19 RT PCR',
#   'subcomponentnm': 'COVID-19 RT PCR',
#   'subcompid': 'SCMP0954',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Oral Glucose Load',
#   'subcomponentnm': 'Oral Glucose Load',
#   'subcompid': 'SCMP0956',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Fasting  Glucose',
#   'subcomponentnm': 'Fasting  Glucose',
#   'subcompid': 'SCMP0957',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'OD Value',
#   'subcomponentnm': 'OD Value',
#   'subcompid': 'SCMP0870',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RH  Typing',
#   'subcomponentnm': 'RH  Typing.',
#   'subcompid': 'SCMP0872',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Protiens',
#   'subcomponentnm': 'Protiens CSF',
#   'subcompid': 'SCMP0892',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'MDR',
#   'subcomponentnm': 'MDR',
#   'subcompid': 'SCMP0900',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'MCH',
#   'subcomponentnm': 'MCH (HPLC)',
#   'subcompid': 'SCMP0906',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti Thyroid Peroxidase *',
#   'subcomponentnm': 'Anti Thyroid Peroxidase *',
#   'subcompid': 'SCMP0915',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HbAo %',
#   'subcomponentnm': 'HbAo percentage',
#   'subcompid': 'SCMP0917',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Serum Albumin',
#   'subcomponentnm': 'Serum Albumin',
#   'subcompid': 'SCMP0949',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV I & II(QUALPRO HIV)',
#   'subcomponentnm': 'HIV I & II(QUALPRO HIV)',
#   'subcompid': 'SCMP0855',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV II (Antibody)       (Immuno Chromatograpy)',
#   'subcomponentnm': 'HIV II ( Antibody )     ( Immuno Chromatograpy)',
#   'subcompid': 'SCMP0856',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'MCHC',
#   'subcomponentnm': 'M C H C',
#   'subcompid': 'SCMP0863',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Quantity',
#   'subcomponentnm': 'Quantity ',
#   'subcompid': 'SCMP0865',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Plasma Glucose 1 1/2 hour',
#   'subcomponentnm': 'Plasma Glucose 1 1/2 hour',
#   'subcompid': 'SCMP0868',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Plasma Glucose 2 1/2 hour',
#   'subcomponentnm': 'Plasma Glucose 2 1/2 hour',
#   'subcompid': 'SCMP0869',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Glucose',
#   'subcomponentnm': 'CUE   Glucose',
#   'subcompid': 'SCMP0873',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Semen Sperm concentration',
#   'subcomponentnm': 'Semen Sperm',
#   'subcompid': 'SCMP0885',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'TSH (ANC)',
#   'subcomponentnm': 'TSH (ANC)',
#   'subcompid': 'SCMP0891',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Magnesium',
#   'subcomponentnm': 'Urine Magnesium',
#   'subcompid': 'SCMP0894',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'RDW',
#   'subcomponentnm': 'RDW (HPLC)',
#   'subcompid': 'SCMP0904',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'MCV',
#   'subcomponentnm': 'MCV (HPLC)',
#   'subcompid': 'SCMP0905',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Comments',
#   'subcomponentnm': 'Comments',
#   'subcompid': 'SCMP0912',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Results (CLIA)',
#   'subcomponentnm': 'Results',
#   'subcompid': 'SCMP0927',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HBsAg ( spot )',
#   'subcomponentnm': 'HBsAg ( spot )',
#   'subcompid': 'SCMP0928',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'FLUID FOR GLUCOSE',
#   'subcomponentnm': 'FLUID FOR GLUCOSE',
#   'subcompid': 'SCMP0929',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Dengue IgM Elisa',
#   'subcomponentnm': 'Dengue IgM Elisa',
#   'subcompid': 'SCMP0936',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Dengue IgG Spot',
#   'subcomponentnm': 'Dengue IgG Spot',
#   'subcompid': 'SCMP0937',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Dengue IgG Elisa',
#   'subcomponentnm': 'Dengue IgG Elisa',
#   'subcompid': 'SCMP0938',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Glucose Fasting',
#   'subcomponentnm': 'Fasting Glucose',
#   'subcompid': 'SCMP0944',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'ctCO2(P)',
#   'subcomponentnm': 'ctCO2(P)',
#   'subcompid': 'SCMP0843',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'BO2',
#   'subcomponentnm': 'BO2',
#   'subcompid': 'SCMP0845',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HCa2+',
#   'subcomponentnm': 'HCa2+',
#   'subcompid': 'SCMP0847',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'AG',
#   'subcomponentnm': 'AG',
#   'subcompid': 'SCMP0848',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Hct(c)',
#   'subcomponentnm': 'Hct(c)',
#   'subcompid': 'SCMP0849',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cut Off Value',
#   'subcomponentnm': 'Cut Off Value',
#   'subcompid': 'SCMP0853',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Magnesium',
#   'subcomponentnm': 'Magnesium',
#   'subcompid': 'SCMP0858',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'PCO2',
#   'subcomponentnm': 'PCO 2',
#   'subcompid': 'SCMP0866',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Nitrite',
#   'subcomponentnm': 'CUE Nitrite',
#   'subcompid': 'SCMP0880',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti Dengue IgM Antibodies*',
#   'subcomponentnm': 'Anti Dengue IgM Antibodies',
#   'subcompid': 'SCMP0886',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Anti Dengue IgG Antibodies*',
#   'subcomponentnm': 'Anti Dengue IgG Antibodies',
#   'subcompid': 'SCMP0887',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Magnesium',
#   'subcomponentnm': 'Magnesium - Urine',
#   'subcompid': 'SCMP0893',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Cortisol, Basal',
#   'subcomponentnm': 'Cortisol, Basal',
#   'subcompid': 'SCMP0897',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HbF %',
#   'subcomponentnm': 'HbF percentage',
#   'subcompid': 'SCMP0916',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Others',
#   'subcomponentnm': 'Others(hplc2)',
#   'subcompid': 'SCMP0921',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Others',
#   'subcomponentnm': 'Others (hplc3)',
#   'subcompid': 'SCMP0922',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV I & II (Antibody) (C',
#   'subcomponentnm': 'HIV I & II (Antibody) (CLI',
#   'subcompid': 'SCMP0924',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'URINE FOR PREGNANCY (H.C.G)',
#   'subcomponentnm': 'URINE FOR PREGNANCY',
#   'subcompid': 'SCMP0930',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Result',
#   'subcomponentnm': 'smearresult',
#   'subcompid': 'SCMP0932',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV I & II (Antibody) (CLIA)',
#   'subcomponentnm': 'HIV I & II (Antibody) (CLIA)',
#   'subcompid': 'SCMP0942',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'HIV II (Antibody)      ( Tridot)',
#   'subcomponentnm': 'HIV II (Antibody) ( Tridot)',
#   'subcompid': 'SCMP0940',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Insulin Fasting',
#   'subcomponentnm': 'Fasting',
#   'subcompid': 'SCMP0943',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Glucose 1st Hour',
#   'subcomponentnm': '1st Hour .',
#   'subcompid': 'SCMP0946',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Glucose 2nd Hour',
#   'subcomponentnm': '2nd Hour .',
#   'subcompid': 'SCMP0948',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'},
#  {'displayparam': 'Glucose 2 hour',
#   'subcomponentnm': 'Glucose 2 hour',
#   'subcompid': 'SCMP0959',
#   'createdby': 6776,
#   'referenceoutput': 'numeric'}]

# %%
dataframe.rename(columns={"displayparam":"DisplayName","subcomponentnm":"ParameterName","referenceoutput":"ReferenceOutput","subcompid":"SUBCOMPID","createdby":"CreatedBy"}, inplace=True)

# %%
dataframe['Active']=[True]*len(dataframe)

# %%
dataframe
# Out:
#                           DisplayName                ParameterName SUBCOMPID  \
# 0                              Hb `F`                       Hb `F`  SCMP0387
# 1                          Appearance  Appearance - Fluid Analysis  SCMP0395
# 2                           WBC Count            WBC Count - Fluid  SCMP0414
# 3                                CD3%           CD3% - HIV Monitor  SCMP0419
# 4                        Osmolality *       Blood for Osmolality *  SCMP0432
# ..                                ...                          ...       ...
# 914  HIV II (Antibody)      ( Tridot)  HIV II (Antibody) ( Tridot)  SCMP0940
# 915                   Insulin Fasting                      Fasting  SCMP0943
# 916                  Glucose 1st Hour                   1st Hour .  SCMP0946
# 917                  Glucose 2nd Hour                   2nd Hour .  SCMP0948
# 918                    Glucose 2 hour               Glucose 2 hour  SCMP0959
#
#      CreatedBy ReferenceOutput  Active
# 0         6776         numeric    True
# 1         6776         numeric    True
# 2         6776         numeric    True
# 3         6776         numeric    True
# 4         6776         numeric    True
# ..         ...             ...     ...
# 914       6776         numeric    True
# 915       6776         numeric    True
# 916       6776         numeric    True
# 917       6776         numeric    True
# 918       6776         numeric    True
#
# [919 rows x 6 columns]

# %%
postgresdb=create_engine(r'postgresql+psycopg2://postgres:emr123@192.168.8.97/shivam_test_DB',echo=False)
postgresConn= postgresdb.connect()
dataframe.to_sql("LabParameterHeader",postgresConn,if_exists="append",index=False)
postgresConn.close()

# %%
import pandas as pd
from sqlalchemy import create_engine

oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()



postgresdb=create_engine(r'postgresql+psycopg2://postgres:emr123@192.168.8.97/shivam_test_DB',echo=False)
postgresConn= postgresdb.connect()

ids=pd.read_sql(f'select  "LabParameterHeaderId","SUBCOMPID" from "LabParameterHeader" where "SUBCOMPID" is not null ',postgresConn)
ids=ids.to_dict('records')

for i in ids:
    try:
       # print(i['LabParameterHeaderId'],i['SUBCOMPID'])

        records=pd.read_sql(f"SELECT DISTINCT INVORDER,TO_number(fromage) as fromage,TO_Number(toage) as toage,DESC_R ,tp1,tp2,SEX,13 AS UnitId,CASE WHEN REFRANGETO='.' THEN '0' ELSE REFRANGETO END AS REFRANGETO,CASE WHEN MAXRAFRANGE='.' THEN '0' ELSE MAXRAFRANGE END AS MAXRAFRANGE ,MINCRITVAL ,MAXCRITVAl,COMPID   FROM DIAGNOTECH.MCDHNORMALVALUE1 WHERE COMPID = '{i['SUBCOMPID']}' ",oracleConn)
        records['LabParameterHeaderId']=i['LabParameterHeaderId']*len(records)
        records.rename(columns={"desc_r":"RangeText","tp1":"FromAgeType","tp2":"ToAgeType",
                                "unitid":"UnitId","refrangeto":"MinValue","maxrafrange":"MaxValue",
                               "mincritval":"MinCriticalValue","maxcritval":"MaxCriticalValue",
                               "compid":"SUBCOMPID","invorder":"InvOrder","sex":"Gender","fromage":"FromAge","toage":"ToAge"
                               }, inplace=True)

        #print(records.to_dict('records'))
        
        records.to_sql("LabParameterDetail",postgresConn,index=False,if_exists="append")
    except Exception as e:
        #print(str(e))
        print(f"\n {i['SUBCOMPID']} ")
        pass
# Out:
#  SCMP0209
#
#  SCMP0175

# %%
ids
# Out:
#      LabParameterHeaderId SUBCOMPID
# 0                      88  SCMP0387
# 1                      89  SCMP0395
# 2                      90  SCMP0414
# 3                      91  SCMP0419
# 4                      92  SCMP0432
# ..                    ...       ...
# 914                  1002  SCMP0940
# 915                  1003  SCMP0943
# 916                  1004  SCMP0946
# 917                  1005  SCMP0948
# 918                  1006  SCMP0959
#
# [919 rows x 2 columns]

# %%
import pandas as pd
from sqlalchemy import create_engine

oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()

limit=10
offset=5
query=f''' SELECT COMPID ,COMPONENTNM ,COMPID AS shivamcomponentid,6776 AS createdby,CURRENT_DATE AS createddate   FROM DIAGNOTECH.TESTCOMPONENTS'''

dataframe=pd.read_sql(query.replace("\n",""),oracleConn)
oracleConn.close()
x=dataframe.to_dict('records')
x
# Out:
# [{'compid': 'COMP0066',
#   'componentnm': 'Post-process report',
#   'shivamcomponentid': 'COMP0066',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0068',
#   'componentnm': 'Motility Semen',
#   'shivamcomponentid': 'COMP0068',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0009',
#   'componentnm': 'BILIRUBIN',
#   'shivamcomponentid': 'COMP0009',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0011',
#   'componentnm': 'Semen Physical Examination',
#   'shivamcomponentid': 'COMP0011',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0014',
#   'componentnm': 'MOTILITY',
#   'shivamcomponentid': 'COMP0014',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0017',
#   'componentnm': 'PHYSICAL EXAMINATION',
#   'shivamcomponentid': 'COMP0017',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0018',
#   'componentnm': 'ELECTROLYTES',
#   'shivamcomponentid': 'COMP0018',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0019',
#   'componentnm': 'Estimated Glomerular Filtration Rate',
#   'shivamcomponentid': 'COMP0019',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0033',
#   'componentnm': 'INTERPRETATION',
#   'shivamcomponentid': 'COMP0033',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0034',
#   'componentnm': 'Cell Count',
#   'shivamcomponentid': 'COMP0034',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0039',
#   'componentnm': 'RISK CALCULATION',
#   'shivamcomponentid': 'COMP0039',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0040',
#   'componentnm': 'LYMPHOCYTE ENUMERATION',
#   'shivamcomponentid': 'COMP0040',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0041',
#   'componentnm': 'HIV VIRAL LOAD',
#   'shivamcomponentid': 'COMP0041',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0044',
#   'componentnm': 'ULTRASOUND DETAILS',
#   'shivamcomponentid': 'COMP0044',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0055',
#   'componentnm': 'Culture',
#   'shivamcomponentid': 'COMP0055',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0058',
#   'componentnm': 'DIFFERENTIAL COUNT:',
#   'shivamcomponentid': 'COMP0058',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0061',
#   'componentnm': 'CCT: / 24 Hrs. URINE PROTEIN.',
#   'shivamcomponentid': 'COMP0061',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0012',
#   'componentnm': 'Semen Chemical Examination',
#   'shivamcomponentid': 'COMP0012',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0020',
#   'componentnm': 'HIV Antibodies (ELISA)',
#   'shivamcomponentid': 'COMP0020',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0021',
#   'componentnm': 'HIV Antigen and Antibodies (CMIA)',
#   'shivamcomponentid': 'COMP0021',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0022',
#   'componentnm': 'PHYSICAL EXAMINATION.',
#   'shivamcomponentid': 'COMP0022',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0023',
#   'componentnm': 'MICROSCOPY.',
#   'shivamcomponentid': 'COMP0023',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0024',
#   'componentnm': 'RBC Indices',
#   'shivamcomponentid': 'COMP0024',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0025',
#   'componentnm': 'Hb Electrophoresis',
#   'shivamcomponentid': 'COMP0025',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0026',
#   'componentnm': 'Lysis started at',
#   'shivamcomponentid': 'COMP0026',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0042',
#   'componentnm': 'TBFERON DETECTION',
#   'shivamcomponentid': 'COMP0042',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0043',
#   'componentnm': 'DOUBLE MARKER',
#   'shivamcomponentid': 'COMP0043',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0005',
#   'componentnm': 'PERIPHERAL SMEAR',
#   'shivamcomponentid': 'COMP0005',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0004',
#   'componentnm': 'DIFFERENTIAL COUNT',
#   'shivamcomponentid': 'COMP0004',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0003',
#   'componentnm': 'PARAMETERS',
#   'shivamcomponentid': 'COMP0003',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0006',
#   'componentnm': 'MICROSCOPIC EXAMINATION',
#   'shivamcomponentid': 'COMP0006',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0007',
#   'componentnm': 'CHEMICAL EXAMINATION',
#   'shivamcomponentid': 'COMP0007',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0010',
#   'componentnm': 'PROTEINS',
#   'shivamcomponentid': 'COMP0010',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0013',
#   'componentnm': 'MICROSCOPY',
#   'shivamcomponentid': 'COMP0013',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0015',
#   'componentnm': 'Cells',
#   'shivamcomponentid': 'COMP0015',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0016',
#   'componentnm': 'iPTH',
#   'shivamcomponentid': 'COMP0016',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0027',
#   'componentnm': 'Lysis Ended at',
#   'shivamcomponentid': 'COMP0027',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0030',
#   'componentnm': '1. Envelope Antigens',
#   'shivamcomponentid': 'COMP0030',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0028',
#   'componentnm': 'HIV Antibodies (Determine)',
#   'shivamcomponentid': 'COMP0028',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0029',
#   'componentnm': 'HIV Antibodies (TRI-DOT)',
#   'shivamcomponentid': 'COMP0029',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0031',
#   'componentnm': '2. POL Antigens',
#   'shivamcomponentid': 'COMP0031',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0035',
#   'componentnm': 'PATIENT SPECIFICATIONS',
#   'shivamcomponentid': 'COMP0035',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0036',
#   'componentnm': 'ULTRA SOUND DETAILS',
#   'shivamcomponentid': 'COMP0036',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0045',
#   'componentnm': 'MULTIPLE  OF MEDIAN (MOM) VALUES',
#   'shivamcomponentid': 'COMP0045',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0046',
#   'componentnm': 'RISK  CALCULATION',
#   'shivamcomponentid': 'COMP0046',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0047',
#   'componentnm': 'PATIENT  SPECIFICATIONS',
#   'shivamcomponentid': 'COMP0047',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0048',
#   'componentnm': 'XPERT MTB/RIF - PULMONARY',
#   'shivamcomponentid': 'COMP0048',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0049',
#   'componentnm': 'TB - PCR',
#   'shivamcomponentid': 'COMP0049',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0050',
#   'componentnm': 'TB  - PCR',
#   'shivamcomponentid': 'COMP0050',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0051',
#   'componentnm': 'Electrophoresis',
#   'shivamcomponentid': 'COMP0051',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0056',
#   'componentnm': 'GROSS EXAMINATION',
#   'shivamcomponentid': 'COMP0056',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0057',
#   'componentnm': 'TOTAL CELL COUNT',
#   'shivamcomponentid': 'COMP0057',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0060',
#   'componentnm': 'Fever Pack',
#   'shivamcomponentid': 'COMP0060',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0052',
#   'componentnm': 'Microbiology Report',
#   'shivamcomponentid': 'COMP0052',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0054',
#   'componentnm': 'PIH PROFILE',
#   'shivamcomponentid': 'COMP0054',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0059',
#   'componentnm': 'MORPHOLOGY',
#   'shivamcomponentid': 'COMP0059',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0008',
#   'componentnm': 'Erythrocyte Sedimentation Rate (ESR)',
#   'shivamcomponentid': 'COMP0008',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0032',
#   'componentnm': '3. GAG Antigens',
#   'shivamcomponentid': 'COMP0032',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0037',
#   'componentnm': 'TRIPLE TEST',
#   'shivamcomponentid': 'COMP0037',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0038',
#   'componentnm': 'MULTIPLE OF MEDIAN (MOM) VALUES',
#   'shivamcomponentid': 'COMP0038',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0053',
#   'componentnm': 'Lipid Profile',
#   'shivamcomponentid': 'COMP0053',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0062',
#   'componentnm': 'Sample Information',
#   'shivamcomponentid': 'COMP0062',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0063',
#   'componentnm': 'Pre-process report',
#   'shivamcomponentid': 'COMP0063',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0064',
#   'componentnm': 'Motility:',
#   'shivamcomponentid': 'COMP0064',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0067',
#   'componentnm': 'GRADING OF AFB SMEARS',
#   'shivamcomponentid': 'COMP0067',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0065',
#   'componentnm': 'BD AFFIRM VPIII TEST FOR VAGINTITS',
#   'shivamcomponentid': 'COMP0065',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0069',
#   'componentnm': 'Bacteriological examination of water.',
#   'shivamcomponentid': 'COMP0069',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0070',
#   'componentnm': 'Presumptive test for coliform bacilli.',
#   'shivamcomponentid': 'COMP0070',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0071',
#   'componentnm': 'Other Cells',
#   'shivamcomponentid': 'COMP0071',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0072',
#   'componentnm': 'GROSS EXAMINATION SEMEN',
#   'shivamcomponentid': 'COMP0072',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0073',
#   'componentnm': 'Blood culture',
#   'shivamcomponentid': 'COMP0073',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0074',
#   'componentnm': 'Impression',
#   'shivamcomponentid': 'COMP0074',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0078',
#   'componentnm': 'PHYSICAL   EXAMINATION',
#   'shivamcomponentid': 'COMP0078',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0079',
#   'componentnm': 'CHEMICAL   EXAMINATION',
#   'shivamcomponentid': 'COMP0079',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0083',
#   'componentnm': 'Peritoneal fluid',
#   'shivamcomponentid': 'COMP0083',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0092',
#   'componentnm': 'RFT (Neonatal)',
#   'shivamcomponentid': 'COMP0092',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0096',
#   'componentnm': 'Glucose 2 Hour',
#   'shivamcomponentid': 'COMP0096',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0080',
#   'componentnm': 'MICROSCOPIC    EXAMINATION',
#   'shivamcomponentid': 'COMP0080',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0081',
#   'componentnm': 'PLATELET COUNT',
#   'shivamcomponentid': 'COMP0081',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0082',
#   'componentnm': 'ABG V',
#   'shivamcomponentid': 'COMP0082',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0088',
#   'componentnm': 'tests1',
#   'shivamcomponentid': 'COMP0088',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0090',
#   'componentnm': 'HIV II (ANTIBODY) (METHOD TRIDOT)',
#   'shivamcomponentid': 'COMP0090',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0075',
#   'componentnm': 'ELECTROLYTES FLUID',
#   'shivamcomponentid': 'COMP0075',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0085',
#   'componentnm': 'Tests',
#   'shivamcomponentid': 'COMP0085',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0089',
#   'componentnm': 'tests2',
#   'shivamcomponentid': 'COMP0089',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0091',
#   'componentnm': 'RFT',
#   'shivamcomponentid': 'COMP0091',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0093',
#   'componentnm': 'Oral Glucose Load',
#   'shivamcomponentid': 'COMP0093',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0076',
#   'componentnm': 'Test Name',
#   'shivamcomponentid': 'COMP0076',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0077',
#   'componentnm': 'ABG A',
#   'shivamcomponentid': 'COMP0077',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0084',
#   'componentnm': 'COVID-19 PCR',
#   'shivamcomponentid': 'COMP0084',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0086',
#   'componentnm': 'Dengue NS1 Elisa',
#   'shivamcomponentid': 'COMP0086',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0094',
#   'componentnm': 'Fasting Glucose',
#   'shivamcomponentid': 'COMP0094',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')},
#  {'compid': 'COMP0095',
#   'componentnm': 'Glucose 1 Hour',
#   'shivamcomponentid': 'COMP0095',
#   'createdby': 6776,
#   'createddate': Timestamp('2023-02-01 12:27:31')}]

# %%
dataframe['active']=[True]*len(dataframe)

# %%
dataframe.rename(columns={
    "compid":"ComponentId","componentnm":"ComponentName","shivamcomponentid":"ShivamComponentId",
    "createdby":"CreatedBy","createddate":"CreatedDate","active":"Active"
    },inplace=True)
dataframe
# Out:
#    ComponentId               ComponentName ShivamComponentId  CreatedBy  \
# 0     COMP0066         Post-process report          COMP0066       6776
# 1     COMP0068              Motility Semen          COMP0068       6776
# 2     COMP0009                   BILIRUBIN          COMP0009       6776
# 3     COMP0011  Semen Physical Examination          COMP0011       6776
# 4     COMP0014                    MOTILITY          COMP0014       6776
# ..         ...                         ...               ...        ...
# 88    COMP0077                       ABG A          COMP0077       6776
# 89    COMP0084                COVID-19 PCR          COMP0084       6776
# 90    COMP0086            Dengue NS1 Elisa          COMP0086       6776
# 91    COMP0094             Fasting Glucose          COMP0094       6776
# 92    COMP0095              Glucose 1 Hour          COMP0095       6776
#
#            CreatedDate  Active
# 0  2023-02-01 12:27:31    True
# 1  2023-02-01 12:27:31    True
# 2  2023-02-01 12:27:31    True
# 3  2023-02-01 12:27:31    True
# 4  2023-02-01 12:27:31    True
# ..                 ...     ...
# 88 2023-02-01 12:27:31    True
# 89 2023-02-01 12:27:31    True
# 90 2023-02-01 12:27:31    True
# 91 2023-02-01 12:27:31    True
# 92 2023-02-01 12:27:31    True
#
# [93 rows x 6 columns]

# %%
postgresdb=create_engine(r'postgresql+psycopg2://postgres:emr123@192.168.8.97/shivam_test_DB',echo=False)
postgresConn= postgresdb.connect()
dataframe.to_sql("LabComponentHeader",postgresConn,if_exists="append",index=False)
postgresConn.close()

# %%
import pandas as pd
from sqlalchemy import create_engine

oracledb = create_engine('oracle://admin:shivam@111.93.11.121:1521/neosoft', echo=False)
oracleConn = oracledb.connect()



postgresdb=create_engine(r'postgresql+psycopg2://postgres:emr123@192.168.8.97/shivam_test_DB',echo=False)
postgresConn= postgresdb.connect()

ids=pd.read_sql(f'select * from "LabComponentHeader" where "ShivamComponentId" is not null ',postgresConn)
ids=ids.to_dict('records')

for i in ids:
    try:
        componentId=i['ShivamComponentId']
        labComponentHeaderId=i['LabComponentHeaderId']
        print("The labcomponentheaderid is : ",labComponentHeaderId)
        records=pd.read_sql(f''' SELECT SNO,COMPONENTID,SUBCOMPONENTID FROM  DIAGNOTECH.ASSIGNSUBCOMPTOCOMP WHERE COMPONENTID = '{componentId}' ''',oracleConn)
        print(records.to_dict("records"))
        for j in records.to_dict("records"):
            priority=j['sno']
            
            subid=j['subcomponentid']
            id2=pd.read_sql(f''' select "LabParameterHeaderId" from "LabParameterHeader" where "SUBCOMPID"='{subid}'  ''',postgresConn)
            #print("The labParameterHeaderId is : ",id2.to_dict('records')[0]['LabParameterHeaderId'])
            dictt={
                "LabComponentHeaderId":labComponentHeaderId,
                "LabParameterHeaderId":id2.to_dict('records')[0]['LabParameterHeaderId'],
                "Priority":priority,
                "ShivamComponentId":componentId,
                "SUBCOMPID":subid
            }
            
            print(dictt)
            df=pd.DataFrame([dictt.values()],columns=dictt.keys())
            df.to_sql("LabComponentDetail",postgresConn,if_exists="append",index=False)
            
            
        print("\n")

    except Exception as e:
        print(str(e))
        #print(f"\n {i['SUBCOMPID']} ")
        pass
# Out:
# The labcomponentheaderid is :  56
# [{'sno': 1, 'componentid': 'COMP0066', 'subcomponentid': 'SCMP0689'}, {'sno': 2, 'componentid': 'COMP0066', 'subcomponentid': 'SCMP0690'}, {'sno': 3, 'componentid': 'COMP0066', 'subcomponentid': 'SCMP0731'}]
# {'LabComponentHeaderId': 56, 'LabParameterHeaderId': 681, 'Priority': 1, 'ShivamComponentId': 'COMP0066', 'SUBCOMPID': 'SCMP0689'}
# {'LabComponentHeaderId': 56, 'LabParameterHeaderId': 397, 'Priority': 2, 'ShivamComponentId': 'COMP0066', 'SUBCOMPID': 'SCMP0690'}
# {'LabComponentHeaderId': 56, 'LabParameterHeaderId': 727, 'Priority': 3, 'ShivamComponentId': 'COMP0066', 'SUBCOMPID': 'SCMP0731'}
#
#
# The labcomponentheaderid is :  57
# [{'sno': 1, 'componentid': 'COMP0068', 'subcomponentid': 'SCMP0739'}, {'sno': 2, 'componentid': 'COMP0068', 'subcomponentid': 'SCMP0740'}, {'sno': 3, 'componentid': 'COMP0068', 'subcomponentid': 'SCMP0741'}, {'sno': 4, 'componentid': 'COMP0068', 'subcomponentid': 'SCMP0742'}]
# {'LabComponentHeaderId': 57, 'LabParameterHeaderId': 713, 'Priority': 1, 'ShivamComponentId': 'COMP0068', 'SUBCOMPID': 'SCMP0739'}
# {'LabComponentHeaderId': 57, 'LabParameterHeaderId': 714, 'Priority': 2, 'ShivamComponentId': 'COMP0068', 'SUBCOMPID': 'SCMP0740'}
# {'LabComponentHeaderId': 57, 'LabParameterHeaderId': 715, 'Priority': 3, 'ShivamComponentId': 'COMP0068', 'SUBCOMPID': 'SCMP0741'}
# {'LabComponentHeaderId': 57, 'LabParameterHeaderId': 732, 'Priority': 4, 'ShivamComponentId': 'COMP0068', 'SUBCOMPID': 'SCMP0742'}
#
#
# The labcomponentheaderid is :  58
# [{'sno': 3, 'componentid': 'COMP0009', 'subcomponentid': 'SCMP0087'}, {'sno': 1, 'componentid': 'COMP0009', 'subcomponentid': 'SCMP0584'}, {'sno': 2, 'componentid': 'COMP0009', 'subcomponentid': 'SCMP0086'}]
# {'LabComponentHeaderId': 58, 'LabParameterHeaderId': 406, 'Priority': 3, 'ShivamComponentId': 'COMP0009', 'SUBCOMPID': 'SCMP0087'}
# {'LabComponentHeaderId': 58, 'LabParameterHeaderId': 340, 'Priority': 1, 'ShivamComponentId': 'COMP0009', 'SUBCOMPID': 'SCMP0584'}
# {'LabComponentHeaderId': 58, 'LabParameterHeaderId': 242, 'Priority': 2, 'ShivamComponentId': 'COMP0009', 'SUBCOMPID': 'SCMP0086'}
#
#
# The labcomponentheaderid is :  59
# [{'sno': 1, 'componentid': 'COMP0011', 'subcomponentid': 'SCMP0749'}, {'sno': 2, 'componentid': 'COMP0011', 'subcomponentid': 'SCMP0734'}, {'sno': 3, 'componentid': 'COMP0011', 'subcomponentid': 'SCMP0735'}, {'sno': 4, 'componentid': 'COMP0011', 'subcomponentid': 'SCMP0736'}, {'sno': 5, 'componentid': 'COMP0011', 'subcomponentid': 'SCMP0737'}]
# {'LabComponentHeaderId': 59, 'LabParameterHeaderId': 720, 'Priority': 1, 'ShivamComponentId': 'COMP0011', 'SUBCOMPID': 'SCMP0749'}
# {'LabComponentHeaderId': 59, 'LabParameterHeaderId': 710, 'Priority': 2, 'ShivamComponentId': 'COMP0011', 'SUBCOMPID': 'SCMP0734'}
# {'LabComponentHeaderId': 59, 'LabParameterHeaderId': 730, 'Priority': 3, 'ShivamComponentId': 'COMP0011', 'SUBCOMPID': 'SCMP0735'}
# {'LabComponentHeaderId': 59, 'LabParameterHeaderId': 711, 'Priority': 4, 'ShivamComponentId': 'COMP0011', 'SUBCOMPID': 'SCMP0736'}
# {'LabComponentHeaderId': 59, 'LabParameterHeaderId': 712, 'Priority': 5, 'ShivamComponentId': 'COMP0011', 'SUBCOMPID': 'SCMP0737'}
#
#
# The labcomponentheaderid is :  60
# [{'sno': 1, 'componentid': 'COMP0014', 'subcomponentid': 'SCMP0732'}, {'sno': 2, 'componentid': 'COMP0014', 'subcomponentid': 'SCMP0733'}, {'sno': 3, 'componentid': 'COMP0014', 'subcomponentid': 'SCMP0681'}]
# {'LabComponentHeaderId': 60, 'LabParameterHeaderId': 728, 'Priority': 1, 'ShivamComponentId': 'COMP0014', 'SUBCOMPID': 'SCMP0732'}
# {'LabComponentHeaderId': 60, 'LabParameterHeaderId': 729, 'Priority': 2, 'ShivamComponentId': 'COMP0014', 'SUBCOMPID': 'SCMP0733'}
# {'LabComponentHeaderId': 60, 'LabParameterHeaderId': 677, 'Priority': 3, 'ShivamComponentId': 'COMP0014', 'SUBCOMPID': 'SCMP0681'}
#
#
# The labcomponentheaderid is :  61
# [{'sno': 1, 'componentid': 'COMP0017', 'subcomponentid': 'SCMP0588'}, {'sno': 2, 'componentid': 'COMP0017', 'subcomponentid': 'SCMP0063'}, {'sno': 3, 'componentid': 'COMP0017', 'subcomponentid': 'SCMP0939'}]
# {'LabComponentHeaderId': 61, 'LabParameterHeaderId': 216, 'Priority': 1, 'ShivamComponentId': 'COMP0017', 'SUBCOMPID': 'SCMP0588'}
# {'LabComponentHeaderId': 61, 'LabParameterHeaderId': 146, 'Priority': 2, 'ShivamComponentId': 'COMP0017', 'SUBCOMPID': 'SCMP0063'}
# {'LabComponentHeaderId': 61, 'LabParameterHeaderId': 852, 'Priority': 3, 'ShivamComponentId': 'COMP0017', 'SUBCOMPID': 'SCMP0939'}
#
#
# The labcomponentheaderid is :  62
# [{'sno': 2, 'componentid': 'COMP0018', 'subcomponentid': 'SCMP0098'}, {'sno': 1, 'componentid': 'COMP0018', 'subcomponentid': 'SCMP0097'}, {'sno': 3, 'componentid': 'COMP0018', 'subcomponentid': 'SCMP0099'}]
# {'LabComponentHeaderId': 62, 'LabParameterHeaderId': 413, 'Priority': 2, 'ShivamComponentId': 'COMP0018', 'SUBCOMPID': 'SCMP0098'}
# {'LabComponentHeaderId': 62, 'LabParameterHeaderId': 412, 'Priority': 1, 'ShivamComponentId': 'COMP0018', 'SUBCOMPID': 'SCMP0097'}
# {'LabComponentHeaderId': 62, 'LabParameterHeaderId': 414, 'Priority': 3, 'ShivamComponentId': 'COMP0018', 'SUBCOMPID': 'SCMP0099'}
#
#
# The labcomponentheaderid is :  63
# [{'sno': 2, 'componentid': 'COMP0019', 'subcomponentid': 'SCMP0095'}, {'sno': 1, 'componentid': 'COMP0019', 'subcomponentid': 'SCMP0328'}]
# {'LabComponentHeaderId': 63, 'LabParameterHeaderId': 243, 'Priority': 2, 'ShivamComponentId': 'COMP0019', 'SUBCOMPID': 'SCMP0095'}
# {'LabComponentHeaderId': 63, 'LabParameterHeaderId': 377, 'Priority': 1, 'ShivamComponentId': 'COMP0019', 'SUBCOMPID': 'SCMP0328'}
#
#
# The labcomponentheaderid is :  64
# [{'sno': 1, 'componentid': 'COMP0033', 'subcomponentid': 'SCMP0473'}]
# {'LabComponentHeaderId': 64, 'LabParameterHeaderId': 105, 'Priority': 1, 'ShivamComponentId': 'COMP0033', 'SUBCOMPID': 'SCMP0473'}
#
#
# The labcomponentheaderid is :  65
# [{'sno': 1, 'componentid': 'COMP0034', 'subcomponentid': 'SCMP0286'}, {'sno': 2, 'componentid': 'COMP0034', 'subcomponentid': 'SCMP0287'}, {'sno': 3, 'componentid': 'COMP0034', 'subcomponentid': 'SCMP0288'}]
# {'LabComponentHeaderId': 65, 'LabParameterHeaderId': 181, 'Priority': 1, 'ShivamComponentId': 'COMP0034', 'SUBCOMPID': 'SCMP0286'}
# {'LabComponentHeaderId': 65, 'LabParameterHeaderId': 182, 'Priority': 2, 'ShivamComponentId': 'COMP0034', 'SUBCOMPID': 'SCMP0287'}
# {'LabComponentHeaderId': 65, 'LabParameterHeaderId': 183, 'Priority': 3, 'ShivamComponentId': 'COMP0034', 'SUBCOMPID': 'SCMP0288'}
#
#
# The labcomponentheaderid is :  66
# [{'sno': 1, 'componentid': 'COMP0039', 'subcomponentid': 'SCMP0525'}, {'sno': 2, 'componentid': 'COMP0039', 'subcomponentid': 'SCMP0526'}, {'sno': 3, 'componentid': 'COMP0039', 'subcomponentid': 'SCMP0527'}]
# {'LabComponentHeaderId': 66, 'LabParameterHeaderId': 323, 'Priority': 1, 'ShivamComponentId': 'COMP0039', 'SUBCOMPID': 'SCMP0525'}
# {'LabComponentHeaderId': 66, 'LabParameterHeaderId': 324, 'Priority': 2, 'ShivamComponentId': 'COMP0039', 'SUBCOMPID': 'SCMP0526'}
# {'LabComponentHeaderId': 66, 'LabParameterHeaderId': 114, 'Priority': 3, 'ShivamComponentId': 'COMP0039', 'SUBCOMPID': 'SCMP0527'}
#
#
# The labcomponentheaderid is :  67
# [{'sno': 1, 'componentid': 'COMP0040', 'subcomponentid': 'SCMP0528'}, {'sno': 2, 'componentid': 'COMP0040', 'subcomponentid': 'SCMP0418'}, {'sno': 4, 'componentid': 'COMP0040', 'subcomponentid': 'SCMP0240'}, {'sno': 3, 'componentid': 'COMP0040', 'subcomponentid': 'SCMP0529'}, {'sno': 5, 'componentid': 'COMP0040', 'subcomponentid': 'SCMP0530'}, {'sno': 6, 'componentid': 'COMP0040', 'subcomponentid': 'SCMP0531'}, {'sno': 7, 'componentid': 'COMP0040', 'subcomponentid': 'SCMP0424'}]
# {'LabComponentHeaderId': 67, 'LabParameterHeaderId': 113, 'Priority': 1, 'ShivamComponentId': 'COMP0040', 'SUBCOMPID': 'SCMP0528'}
# {'LabComponentHeaderId': 67, 'LabParameterHeaderId': 528, 'Priority': 2, 'ShivamComponentId': 'COMP0040', 'SUBCOMPID': 'SCMP0418'}
# {'LabComponentHeaderId': 67, 'LabParameterHeaderId': 164, 'Priority': 4, 'ShivamComponentId': 'COMP0040', 'SUBCOMPID': 'SCMP0240'}
# {'LabComponentHeaderId': 67, 'LabParameterHeaderId': 325, 'Priority': 3, 'ShivamComponentId': 'COMP0040', 'SUBCOMPID': 'SCMP0529'}
# {'LabComponentHeaderId': 67, 'LabParameterHeaderId': 326, 'Priority': 5, 'ShivamComponentId': 'COMP0040', 'SUBCOMPID': 'SCMP0530'}
# {'LabComponentHeaderId': 67, 'LabParameterHeaderId': 327, 'Priority': 6, 'ShivamComponentId': 'COMP0040', 'SUBCOMPID': 'SCMP0531'}
# {'LabComponentHeaderId': 67, 'LabParameterHeaderId': 534, 'Priority': 7, 'ShivamComponentId': 'COMP0040', 'SUBCOMPID': 'SCMP0424'}
#
#
# The labcomponentheaderid is :  68
# [{'sno': 1, 'componentid': 'COMP0041', 'subcomponentid': 'SCMP0430'}]
# {'LabComponentHeaderId': 68, 'LabParameterHeaderId': 305, 'Priority': 1, 'ShivamComponentId': 'COMP0041', 'SUBCOMPID': 'SCMP0430'}
#
#
# The labcomponentheaderid is :  69
# [{'sno': 1, 'componentid': 'COMP0044', 'subcomponentid': 'SCMP0515'}, {'sno': 2, 'componentid': 'COMP0044', 'subcomponentid': 'SCMP0516'}, {'sno': 3, 'componentid': 'COMP0044', 'subcomponentid': 'SCMP0551'}, {'sno': 4, 'componentid': 'COMP0044', 'subcomponentid': 'SCMP0517'}, {'sno': 5, 'componentid': 'COMP0044', 'subcomponentid': 'SCMP0554'}, {'sno': 6, 'componentid': 'COMP0044', 'subcomponentid': 'SCMP0552'}, {'sno': 7, 'componentid': 'COMP0044', 'subcomponentid': 'SCMP0553'}]
# {'LabComponentHeaderId': 69, 'LabParameterHeaderId': 824, 'Priority': 1, 'ShivamComponentId': 'COMP0044', 'SUBCOMPID': 'SCMP0515'}
# {'LabComponentHeaderId': 69, 'LabParameterHeaderId': 319, 'Priority': 2, 'ShivamComponentId': 'COMP0044', 'SUBCOMPID': 'SCMP0516'}
# {'LabComponentHeaderId': 69, 'LabParameterHeaderId': 859, 'Priority': 3, 'ShivamComponentId': 'COMP0044', 'SUBCOMPID': 'SCMP0551'}
# {'LabComponentHeaderId': 69, 'LabParameterHeaderId': 320, 'Priority': 4, 'ShivamComponentId': 'COMP0044', 'SUBCOMPID': 'SCMP0517'}
# {'LabComponentHeaderId': 69, 'LabParameterHeaderId': 630, 'Priority': 5, 'ShivamComponentId': 'COMP0044', 'SUBCOMPID': 'SCMP0554'}
# {'LabComponentHeaderId': 69, 'LabParameterHeaderId': 123, 'Priority': 6, 'ShivamComponentId': 'COMP0044', 'SUBCOMPID': 'SCMP0552'}
# {'LabComponentHeaderId': 69, 'LabParameterHeaderId': 629, 'Priority': 7, 'ShivamComponentId': 'COMP0044', 'SUBCOMPID': 'SCMP0553'}
#
#
# The labcomponentheaderid is :  70
# [{'sno': 1, 'componentid': 'COMP0055', 'subcomponentid': 'SCMP0629'}, {'sno': 2, 'componentid': 'COMP0055', 'subcomponentid': 'SCMP0646'}, {'sno': 3, 'componentid': 'COMP0055', 'subcomponentid': 'SCMP0487'}]
# {'LabComponentHeaderId': 70, 'LabParameterHeaderId': 659, 'Priority': 1, 'ShivamComponentId': 'COMP0055', 'SUBCOMPID': 'SCMP0629'}
# {'LabComponentHeaderId': 70, 'LabParameterHeaderId': 215, 'Priority': 2, 'ShivamComponentId': 'COMP0055', 'SUBCOMPID': 'SCMP0646'}
# {'LabComponentHeaderId': 70, 'LabParameterHeaderId': 310, 'Priority': 3, 'ShivamComponentId': 'COMP0055', 'SUBCOMPID': 'SCMP0487'}
#
#
# The labcomponentheaderid is :  71
# [{'sno': 2, 'componentid': 'COMP0058', 'subcomponentid': 'SCMP0643'}, {'sno': 1, 'componentid': 'COMP0058', 'subcomponentid': 'SCMP0642'}]
# {'LabComponentHeaderId': 71, 'LabParameterHeaderId': 220, 'Priority': 2, 'ShivamComponentId': 'COMP0058', 'SUBCOMPID': 'SCMP0643'}
# {'LabComponentHeaderId': 71, 'LabParameterHeaderId': 229, 'Priority': 1, 'ShivamComponentId': 'COMP0058', 'SUBCOMPID': 'SCMP0642'}
#
#
# The labcomponentheaderid is :  72
# [{'sno': 4, 'componentid': 'COMP0061', 'subcomponentid': 'SCMP0619'}, {'sno': 1, 'componentid': 'COMP0061', 'subcomponentid': 'SCMP0662'}, {'sno': 2, 'componentid': 'COMP0061', 'subcomponentid': 'SCMP0663'}, {'sno': 3, 'componentid': 'COMP0061', 'subcomponentid': 'SCMP0095'}, {'sno': 5, 'componentid': 'COMP0061', 'subcomponentid': 'SCMP0348'}]
# {'LabComponentHeaderId': 72, 'LabParameterHeaderId': 354, 'Priority': 4, 'ShivamComponentId': 'COMP0061', 'SUBCOMPID': 'SCMP0619'}
# {'LabComponentHeaderId': 72, 'LabParameterHeaderId': 364, 'Priority': 1, 'ShivamComponentId': 'COMP0061', 'SUBCOMPID': 'SCMP0662'}
# {'LabComponentHeaderId': 72, 'LabParameterHeaderId': 365, 'Priority': 2, 'ShivamComponentId': 'COMP0061', 'SUBCOMPID': 'SCMP0663'}
# {'LabComponentHeaderId': 72, 'LabParameterHeaderId': 243, 'Priority': 3, 'ShivamComponentId': 'COMP0061', 'SUBCOMPID': 'SCMP0095'}
# {'LabComponentHeaderId': 72, 'LabParameterHeaderId': 381, 'Priority': 5, 'ShivamComponentId': 'COMP0061', 'SUBCOMPID': 'SCMP0348'}
#
#
# The labcomponentheaderid is :  73
# [{'sno': 1, 'componentid': 'COMP0012', 'subcomponentid': 'SCMP0738'}]
# {'LabComponentHeaderId': 73, 'LabParameterHeaderId': 731, 'Priority': 1, 'ShivamComponentId': 'COMP0012', 'SUBCOMPID': 'SCMP0738'}
#
#
# The labcomponentheaderid is :  74
# [{'sno': 1, 'componentid': 'COMP0020', 'subcomponentid': 'SCMP0354'}, {'sno': 3, 'componentid': 'COMP0020', 'subcomponentid': 'SCMP0356'}, {'sno': 2, 'componentid': 'COMP0020', 'subcomponentid': 'SCMP0355'}]
# {'LabComponentHeaderId': 74, 'LabParameterHeaderId': 191, 'Priority': 1, 'ShivamComponentId': 'COMP0020', 'SUBCOMPID': 'SCMP0354'}
# {'LabComponentHeaderId': 74, 'LabParameterHeaderId': 192, 'Priority': 3, 'ShivamComponentId': 'COMP0020', 'SUBCOMPID': 'SCMP0356'}
# {'LabComponentHeaderId': 74, 'LabParameterHeaderId': 843, 'Priority': 2, 'ShivamComponentId': 'COMP0020', 'SUBCOMPID': 'SCMP0355'}
#
#
# The labcomponentheaderid is :  75
# [{'sno': 1, 'componentid': 'COMP0021', 'subcomponentid': 'SCMP0313'}, {'sno': 2, 'componentid': 'COMP0021', 'subcomponentid': 'SCMP0314'}]
# {'LabComponentHeaderId': 75, 'LabParameterHeaderId': 819, 'Priority': 1, 'ShivamComponentId': 'COMP0021', 'SUBCOMPID': 'SCMP0313'}
# {'LabComponentHeaderId': 75, 'LabParameterHeaderId': 269, 'Priority': 2, 'ShivamComponentId': 'COMP0021', 'SUBCOMPID': 'SCMP0314'}
#
#
# The labcomponentheaderid is :  76
# [{'sno': 1, 'componentid': 'COMP0022', 'subcomponentid': 'SCMP0274'}, {'sno': 2, 'componentid': 'COMP0022', 'subcomponentid': 'SCMP0275'}, {'sno': 3, 'componentid': 'COMP0022', 'subcomponentid': 'SCMP0276'}, {'sno': 4, 'componentid': 'COMP0022', 'subcomponentid': 'SCMP0129'}, {'sno': 5, 'componentid': 'COMP0022', 'subcomponentid': 'SCMP0277'}]
# {'LabComponentHeaderId': 76, 'LabParameterHeaderId': 863, 'Priority': 1, 'ShivamComponentId': 'COMP0022', 'SUBCOMPID': 'SCMP0274'}
# {'LabComponentHeaderId': 76, 'LabParameterHeaderId': 176, 'Priority': 2, 'ShivamComponentId': 'COMP0022', 'SUBCOMPID': 'SCMP0275'}
# {'LabComponentHeaderId': 76, 'LabParameterHeaderId': 177, 'Priority': 3, 'ShivamComponentId': 'COMP0022', 'SUBCOMPID': 'SCMP0276'}
# {'LabComponentHeaderId': 76, 'LabParameterHeaderId': 598, 'Priority': 4, 'ShivamComponentId': 'COMP0022', 'SUBCOMPID': 'SCMP0129'}
# {'LabComponentHeaderId': 76, 'LabParameterHeaderId': 178, 'Priority': 5, 'ShivamComponentId': 'COMP0022', 'SUBCOMPID': 'SCMP0277'}
#
#
# The labcomponentheaderid is :  77
# [{'sno': 3, 'componentid': 'COMP0023', 'subcomponentid': 'SCMP0616'}, {'sno': 1, 'componentid': 'COMP0023', 'subcomponentid': 'SCMP0278'}, {'sno': 2, 'componentid': 'COMP0023', 'subcomponentid': 'SCMP0615'}, {'sno': 4, 'componentid': 'COMP0023', 'subcomponentid': 'SCMP0372'}, {'sno': 5, 'componentid': 'COMP0023', 'subcomponentid': 'SCMP0373'}, {'sno': 6, 'componentid': 'COMP0023', 'subcomponentid': 'SCMP0376'}]
# {'LabComponentHeaderId': 77, 'LabParameterHeaderId': 878, 'Priority': 3, 'ShivamComponentId': 'COMP0023', 'SUBCOMPID': 'SCMP0616'}
# {'LabComponentHeaderId': 77, 'LabParameterHeaderId': 179, 'Priority': 1, 'ShivamComponentId': 'COMP0023', 'SUBCOMPID': 'SCMP0278'}
# {'LabComponentHeaderId': 77, 'LabParameterHeaderId': 353, 'Priority': 2, 'ShivamComponentId': 'COMP0023', 'SUBCOMPID': 'SCMP0615'}
# {'LabComponentHeaderId': 77, 'LabParameterHeaderId': 199, 'Priority': 4, 'ShivamComponentId': 'COMP0023', 'SUBCOMPID': 'SCMP0372'}
# {'LabComponentHeaderId': 77, 'LabParameterHeaderId': 384, 'Priority': 5, 'ShivamComponentId': 'COMP0023', 'SUBCOMPID': 'SCMP0373'}
# {'LabComponentHeaderId': 77, 'LabParameterHeaderId': 517, 'Priority': 6, 'ShivamComponentId': 'COMP0023', 'SUBCOMPID': 'SCMP0376'}
#
#
# The labcomponentheaderid is :  78
# [{'sno': 3, 'componentid': 'COMP0024', 'subcomponentid': 'SCMP0022'}, {'sno': 4, 'componentid': 'COMP0024', 'subcomponentid': 'SCMP0386'}, {'sno': 1, 'componentid': 'COMP0024', 'subcomponentid': 'SCMP0016'}, {'sno': 2, 'componentid': 'COMP0024', 'subcomponentid': 'SCMP0020'}, {'sno': 5, 'componentid': 'COMP0024', 'subcomponentid': 'SCMP0431'}]
# {'LabComponentHeaderId': 78, 'LabParameterHeaderId': 130, 'Priority': 3, 'ShivamComponentId': 'COMP0024', 'SUBCOMPID': 'SCMP0022'}
# {'LabComponentHeaderId': 78, 'LabParameterHeaderId': 203, 'Priority': 4, 'ShivamComponentId': 'COMP0024', 'SUBCOMPID': 'SCMP0386'}
# {'LabComponentHeaderId': 78, 'LabParameterHeaderId': 132, 'Priority': 1, 'ShivamComponentId': 'COMP0024', 'SUBCOMPID': 'SCMP0016'}
# {'LabComponentHeaderId': 78, 'LabParameterHeaderId': 815, 'Priority': 2, 'ShivamComponentId': 'COMP0024', 'SUBCOMPID': 'SCMP0020'}
# {'LabComponentHeaderId': 78, 'LabParameterHeaderId': 538, 'Priority': 5, 'ShivamComponentId': 'COMP0024', 'SUBCOMPID': 'SCMP0431'}
#
#
# The labcomponentheaderid is :  79
# [{'sno': 1, 'componentid': 'COMP0025', 'subcomponentid': 'SCMP0304'}, {'sno': 2, 'componentid': 'COMP0025', 'subcomponentid': 'SCMP0452'}, {'sno': 3, 'componentid': 'COMP0025', 'subcomponentid': 'SCMP0387'}, {'sno': 4, 'componentid': 'COMP0025', 'subcomponentid': 'SCMP0388'}]
# {'LabComponentHeaderId': 79, 'LabParameterHeaderId': 499, 'Priority': 1, 'ShivamComponentId': 'COMP0025', 'SUBCOMPID': 'SCMP0304'}
# {'LabComponentHeaderId': 79, 'LabParameterHeaderId': 551, 'Priority': 2, 'ShivamComponentId': 'COMP0025', 'SUBCOMPID': 'SCMP0452'}
# {'LabComponentHeaderId': 79, 'LabParameterHeaderId': 88, 'Priority': 3, 'ShivamComponentId': 'COMP0025', 'SUBCOMPID': 'SCMP0387'}
# {'LabComponentHeaderId': 79, 'LabParameterHeaderId': 846, 'Priority': 4, 'ShivamComponentId': 'COMP0025', 'SUBCOMPID': 'SCMP0388'}
#
#
# The labcomponentheaderid is :  80
# [{'sno': 1, 'componentid': 'COMP0026', 'subcomponentid': 'SCMP0400'}, {'sno': 2, 'componentid': 'COMP0026', 'subcomponentid': 'SCMP0401'}]
# {'LabComponentHeaderId': 80, 'LabParameterHeaderId': 818, 'Priority': 1, 'ShivamComponentId': 'COMP0026', 'SUBCOMPID': 'SCMP0400'}
# {'LabComponentHeaderId': 80, 'LabParameterHeaderId': 288, 'Priority': 2, 'ShivamComponentId': 'COMP0026', 'SUBCOMPID': 'SCMP0401'}
#
#
# The labcomponentheaderid is :  81
# [{'sno': 1, 'componentid': 'COMP0042', 'subcomponentid': 'SCMP0534'}, {'sno': 2, 'componentid': 'COMP0042', 'subcomponentid': 'SCMP0535'}]
# {'LabComponentHeaderId': 81, 'LabParameterHeaderId': 623, 'Priority': 1, 'ShivamComponentId': 'COMP0042', 'SUBCOMPID': 'SCMP0534'}
# {'LabComponentHeaderId': 81, 'LabParameterHeaderId': 328, 'Priority': 2, 'ShivamComponentId': 'COMP0042', 'SUBCOMPID': 'SCMP0535'}
#
#
# The labcomponentheaderid is :  82
# [{'sno': 1, 'componentid': 'COMP0043', 'subcomponentid': 'SCMP0544'}, {'sno': 2, 'componentid': 'COMP0043', 'subcomponentid': 'SCMP0545'}]
# {'LabComponentHeaderId': 82, 'LabParameterHeaderId': 330, 'Priority': 1, 'ShivamComponentId': 'COMP0043', 'SUBCOMPID': 'SCMP0544'}
# {'LabComponentHeaderId': 82, 'LabParameterHeaderId': 877, 'Priority': 2, 'ShivamComponentId': 'COMP0043', 'SUBCOMPID': 'SCMP0545'}
#
#
# The labcomponentheaderid is :  83
# [{'sno': 1, 'componentid': 'COMP0005', 'subcomponentid': 'SCMP0033'}, {'sno': 2, 'componentid': 'COMP0005', 'subcomponentid': 'SCMP0034'}, {'sno': 3, 'componentid': 'COMP0005', 'subcomponentid': 'SCMP0035'}]
# {'LabComponentHeaderId': 83, 'LabParameterHeaderId': 133, 'Priority': 1, 'ShivamComponentId': 'COMP0005', 'SUBCOMPID': 'SCMP0033'}
# {'LabComponentHeaderId': 83, 'LabParameterHeaderId': 572, 'Priority': 2, 'ShivamComponentId': 'COMP0005', 'SUBCOMPID': 'SCMP0034'}
# {'LabComponentHeaderId': 83, 'LabParameterHeaderId': 573, 'Priority': 3, 'ShivamComponentId': 'COMP0005', 'SUBCOMPID': 'SCMP0035'}
#
#
# The labcomponentheaderid is :  84
# [{'sno': 1, 'componentid': 'COMP0004', 'subcomponentid': 'SCMP0027'}, {'sno': 2, 'componentid': 'COMP0004', 'subcomponentid': 'SCMP0028'}, {'sno': 3, 'componentid': 'COMP0004', 'subcomponentid': 'SCMP0030'}, {'sno': 4, 'componentid': 'COMP0004', 'subcomponentid': 'SCMP0029'}, {'sno': 5, 'componentid': 'COMP0004', 'subcomponentid': 'SCMP0031'}, {'sno': 6, 'componentid': 'COMP0004', 'subcomponentid': 'SCMP0057'}, {'sno': 7, 'componentid': 'COMP0004', 'subcomponentid': 'SCMP0056'}, {'sno': 8, 'componentid': 'COMP0004', 'subcomponentid': 'SCMP0062'}]
# {'LabComponentHeaderId': 84, 'LabParameterHeaderId': 131, 'Priority': 1, 'ShivamComponentId': 'COMP0004', 'SUBCOMPID': 'SCMP0027'}
# {'LabComponentHeaderId': 84, 'LabParameterHeaderId': 231, 'Priority': 2, 'ShivamComponentId': 'COMP0004', 'SUBCOMPID': 'SCMP0028'}
# {'LabComponentHeaderId': 84, 'LabParameterHeaderId': 116, 'Priority': 3, 'ShivamComponentId': 'COMP0004', 'SUBCOMPID': 'SCMP0030'}
# {'LabComponentHeaderId': 84, 'LabParameterHeaderId': 232, 'Priority': 4, 'ShivamComponentId': 'COMP0004', 'SUBCOMPID': 'SCMP0029'}
# {'LabComponentHeaderId': 84, 'LabParameterHeaderId': 117, 'Priority': 5, 'ShivamComponentId': 'COMP0004', 'SUBCOMPID': 'SCMP0031'}
# {'LabComponentHeaderId': 84, 'LabParameterHeaderId': 141, 'Priority': 6, 'ShivamComponentId': 'COMP0004', 'SUBCOMPID': 'SCMP0057'}
# {'LabComponentHeaderId': 84, 'LabParameterHeaderId': 140, 'Priority': 7, 'ShivamComponentId': 'COMP0004', 'SUBCOMPID': 'SCMP0056'}
# {'LabComponentHeaderId': 84, 'LabParameterHeaderId': 869, 'Priority': 8, 'ShivamComponentId': 'COMP0004', 'SUBCOMPID': 'SCMP0062'}
#
#
# The labcomponentheaderid is :  85
# [{'sno': 1, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0016'}, {'sno': 2, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0021'}, {'sno': 3, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0020'}, {'sno': 4, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0022'}, {'sno': 5, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0023'}, {'sno': 6, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0024'}, {'sno': 7, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0811'}, {'sno': 8, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0386'}, {'sno': 9, 'componentid': 'COMP0003', 'subcomponentid': 'SCMP0025'}]
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 132, 'Priority': 1, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0016'}
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 128, 'Priority': 2, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0021'}
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 815, 'Priority': 3, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0020'}
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 130, 'Priority': 4, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0022'}
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 592, 'Priority': 5, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0023'}
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 570, 'Priority': 6, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0024'}
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 784, 'Priority': 7, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0811'}
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 203, 'Priority': 8, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0386'}
# {'LabComponentHeaderId': 85, 'LabParameterHeaderId': 620, 'Priority': 9, 'ShivamComponentId': 'COMP0003', 'SUBCOMPID': 'SCMP0025'}
#
#
# The labcomponentheaderid is :  86
# [{'sno': 3, 'componentid': 'COMP0006', 'subcomponentid': 'SCMP0076'}, {'sno': 4, 'componentid': 'COMP0006', 'subcomponentid': 'SCMP0079'}, {'sno': 5, 'componentid': 'COMP0006', 'subcomponentid': 'SCMP0078'}, {'sno': 1, 'componentid': 'COMP0006', 'subcomponentid': 'SCMP0075'}, {'sno': 2, 'componentid': 'COMP0006', 'subcomponentid': 'SCMP0077'}, {'sno': 6, 'componentid': 'COMP0006', 'subcomponentid': 'SCMP0308'}]
# {'LabComponentHeaderId': 86, 'LabParameterHeaderId': 240, 'Priority': 3, 'ShivamComponentId': 'COMP0006', 'SUBCOMPID': 'SCMP0076'}
# {'LabComponentHeaderId': 86, 'LabParameterHeaderId': 883, 'Priority': 4, 'ShivamComponentId': 'COMP0006', 'SUBCOMPID': 'SCMP0079'}
# {'LabComponentHeaderId': 86, 'LabParameterHeaderId': 241, 'Priority': 5, 'ShivamComponentId': 'COMP0006', 'SUBCOMPID': 'SCMP0078'}
# {'LabComponentHeaderId': 86, 'LabParameterHeaderId': 239, 'Priority': 1, 'ShivamComponentId': 'COMP0006', 'SUBCOMPID': 'SCMP0075'}
# {'LabComponentHeaderId': 86, 'LabParameterHeaderId': 405, 'Priority': 2, 'ShivamComponentId': 'COMP0006', 'SUBCOMPID': 'SCMP0077'}
# {'LabComponentHeaderId': 86, 'LabParameterHeaderId': 502, 'Priority': 6, 'ShivamComponentId': 'COMP0006', 'SUBCOMPID': 'SCMP0308'}
#
#
# The labcomponentheaderid is :  87
# [{'sno': 1, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0065'}, {'sno': 2, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0873'}, {'sno': 3, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0067'}, {'sno': 4, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0874'}, {'sno': 5, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0066'}, {'sno': 6, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0875'}, {'sno': 7, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0072'}, {'sno': 8, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0068'}, {'sno': 9, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0877'}, {'sno': 10, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0073'}, {'sno': 11, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0069'}, {'sno': 12, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0879'}, {'sno': 13, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0070'}, {'sno': 14, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0880'}, {'sno': 15, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0589'}, {'sno': 16, 'componentid': 'COMP0007', 'subcomponentid': 'SCMP0881'}]
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 581, 'Priority': 1, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0065'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 968, 'Priority': 2, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0873'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 582, 'Priority': 3, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0067'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 921, 'Priority': 4, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0874'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 147, 'Priority': 5, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0066'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 922, 'Priority': 6, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0875'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 404, 'Priority': 7, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0072'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 403, 'Priority': 8, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0068'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 923, 'Priority': 9, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0877'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 583, 'Priority': 10, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0073'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 235, 'Priority': 11, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0069'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 925, 'Priority': 12, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0879'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 236, 'Priority': 13, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0070'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 990, 'Priority': 14, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0880'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 342, 'Priority': 15, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0589'}
# {'LabComponentHeaderId': 87, 'LabParameterHeaderId': 831, 'Priority': 16, 'ShivamComponentId': 'COMP0007', 'SUBCOMPID': 'SCMP0881'}
#
#
# The labcomponentheaderid is :  88
# [{'sno': 1, 'componentid': 'COMP0010', 'subcomponentid': 'SCMP0592'}, {'sno': 2, 'componentid': 'COMP0010', 'subcomponentid': 'SCMP0104'}, {'sno': 3, 'componentid': 'COMP0010', 'subcomponentid': 'SCMP0105'}, {'sno': 4, 'componentid': 'COMP0010', 'subcomponentid': 'SCMP0106'}]
# {'LabComponentHeaderId': 88, 'LabParameterHeaderId': 640, 'Priority': 1, 'ShivamComponentId': 'COMP0010', 'SUBCOMPID': 'SCMP0592'}
# {'LabComponentHeaderId': 88, 'LabParameterHeaderId': 419, 'Priority': 2, 'ShivamComponentId': 'COMP0010', 'SUBCOMPID': 'SCMP0104'}
# {'LabComponentHeaderId': 88, 'LabParameterHeaderId': 420, 'Priority': 3, 'ShivamComponentId': 'COMP0010', 'SUBCOMPID': 'SCMP0105'}
# {'LabComponentHeaderId': 88, 'LabParameterHeaderId': 421, 'Priority': 4, 'ShivamComponentId': 'COMP0010', 'SUBCOMPID': 'SCMP0106'}
#
#
# The labcomponentheaderid is :  89
# [{'sno': 1, 'componentid': 'COMP0013', 'subcomponentid': 'SCMP0196'}]
# {'LabComponentHeaderId': 89, 'LabParameterHeaderId': 256, 'Priority': 1, 'ShivamComponentId': 'COMP0013', 'SUBCOMPID': 'SCMP0196'}
#
#
# The labcomponentheaderid is :  90
# [{'sno': 1, 'componentid': 'COMP0015', 'subcomponentid': 'SCMP0201'}, {'sno': 4, 'componentid': 'COMP0015', 'subcomponentid': 'SCMP0204'}, {'sno': 5, 'componentid': 'COMP0015', 'subcomponentid': 'SCMP0205'}, {'sno': 3, 'componentid': 'COMP0015', 'subcomponentid': 'SCMP0203'}, {'sno': 2, 'componentid': 'COMP0015', 'subcomponentid': 'SCMP0202'}]
# {'LabComponentHeaderId': 90, 'LabParameterHeaderId': 895, 'Priority': 1, 'ShivamComponentId': 'COMP0015', 'SUBCOMPID': 'SCMP0201'}
# {'LabComponentHeaderId': 90, 'LabParameterHeaderId': 879, 'Priority': 4, 'ShivamComponentId': 'COMP0015', 'SUBCOMPID': 'SCMP0204'}
# {'LabComponentHeaderId': 90, 'LabParameterHeaderId': 259, 'Priority': 5, 'ShivamComponentId': 'COMP0015', 'SUBCOMPID': 'SCMP0205'}
# {'LabComponentHeaderId': 90, 'LabParameterHeaderId': 258, 'Priority': 3, 'ShivamComponentId': 'COMP0015', 'SUBCOMPID': 'SCMP0203'}
# {'LabComponentHeaderId': 90, 'LabParameterHeaderId': 614, 'Priority': 2, 'ShivamComponentId': 'COMP0015', 'SUBCOMPID': 'SCMP0202'}
#
#
# The labcomponentheaderid is :  91
# [{'sno': 1, 'componentid': 'COMP0016', 'subcomponentid': 'SCMP0217'}, {'sno': 2, 'componentid': 'COMP0016', 'subcomponentid': 'SCMP0096'}]
# {'LabComponentHeaderId': 91, 'LabParameterHeaderId': 468, 'Priority': 1, 'ShivamComponentId': 'COMP0016', 'SUBCOMPID': 'SCMP0217'}
# {'LabComponentHeaderId': 91, 'LabParameterHeaderId': 244, 'Priority': 2, 'ShivamComponentId': 'COMP0016', 'SUBCOMPID': 'SCMP0096'}
#
#
# The labcomponentheaderid is :  92
# [{'sno': 1, 'componentid': 'COMP0027', 'subcomponentid': 'SCMP0403'}, {'sno': 2, 'componentid': 'COMP0027', 'subcomponentid': 'SCMP0404'}]
# {'LabComponentHeaderId': 92, 'LabParameterHeaderId': 866, 'Priority': 1, 'ShivamComponentId': 'COMP0027', 'SUBCOMPID': 'SCMP0403'}
# {'LabComponentHeaderId': 92, 'LabParameterHeaderId': 525, 'Priority': 2, 'ShivamComponentId': 'COMP0027', 'SUBCOMPID': 'SCMP0404'}
#
#
# The labcomponentheaderid is :  93
# [{'sno': 3, 'componentid': 'COMP0030', 'subcomponentid': 'SCMP0468'}, {'sno': 1, 'componentid': 'COMP0030', 'subcomponentid': 'SCMP0466'}, {'sno': 2, 'componentid': 'COMP0030', 'subcomponentid': 'SCMP0467'}]
# {'LabComponentHeaderId': 93, 'LabParameterHeaderId': 897, 'Priority': 3, 'ShivamComponentId': 'COMP0030', 'SUBCOMPID': 'SCMP0468'}
# {'LabComponentHeaderId': 93, 'LabParameterHeaderId': 554, 'Priority': 1, 'ShivamComponentId': 'COMP0030', 'SUBCOMPID': 'SCMP0466'}
# {'LabComponentHeaderId': 93, 'LabParameterHeaderId': 101, 'Priority': 2, 'ShivamComponentId': 'COMP0030', 'SUBCOMPID': 'SCMP0467'}
#
#
# The labcomponentheaderid is :  94
# [{'sno': 1, 'componentid': 'COMP0028', 'subcomponentid': 'SCMP0343'}]
# {'LabComponentHeaderId': 94, 'LabParameterHeaderId': 283, 'Priority': 1, 'ShivamComponentId': 'COMP0028', 'SUBCOMPID': 'SCMP0343'}
#
#
# The labcomponentheaderid is :  95
# [{'sno': 1, 'componentid': 'COMP0029', 'subcomponentid': 'SCMP0342'}]
# {'LabComponentHeaderId': 95, 'LabParameterHeaderId': 187, 'Priority': 1, 'ShivamComponentId': 'COMP0029', 'SUBCOMPID': 'SCMP0342'}
#
#
# The labcomponentheaderid is :  96
# [{'sno': 1, 'componentid': 'COMP0031', 'subcomponentid': 'SCMP0469'}, {'sno': 2, 'componentid': 'COMP0031', 'subcomponentid': 'SCMP0470'}, {'sno': 3, 'componentid': 'COMP0031', 'subcomponentid': 'SCMP0471'}]
# {'LabComponentHeaderId': 96, 'LabParameterHeaderId': 102, 'Priority': 1, 'ShivamComponentId': 'COMP0031', 'SUBCOMPID': 'SCMP0469'}
# {'LabComponentHeaderId': 96, 'LabParameterHeaderId': 103, 'Priority': 2, 'ShivamComponentId': 'COMP0031', 'SUBCOMPID': 'SCMP0470'}
# {'LabComponentHeaderId': 96, 'LabParameterHeaderId': 555, 'Priority': 3, 'ShivamComponentId': 'COMP0031', 'SUBCOMPID': 'SCMP0471'}
#
#
# The labcomponentheaderid is :  97
# [{'sno': 3, 'componentid': 'COMP0035', 'subcomponentid': 'SCMP0510'}, {'sno': 4, 'componentid': 'COMP0035', 'subcomponentid': 'SCMP0511'}, {'sno': 7, 'componentid': 'COMP0035', 'subcomponentid': 'SCMP0514'}, {'sno': 1, 'componentid': 'COMP0035', 'subcomponentid': 'SCMP0508'}, {'sno': 2, 'componentid': 'COMP0035', 'subcomponentid': 'SCMP0509'}, {'sno': 5, 'componentid': 'COMP0035', 'subcomponentid': 'SCMP0512'}, {'sno': 6, 'componentid': 'COMP0035', 'subcomponentid': 'SCMP0513'}]
# {'LabComponentHeaderId': 97, 'LabParameterHeaderId': 569, 'Priority': 3, 'ShivamComponentId': 'COMP0035', 'SUBCOMPID': 'SCMP0510'}
# {'LabComponentHeaderId': 97, 'LabParameterHeaderId': 317, 'Priority': 4, 'ShivamComponentId': 'COMP0035', 'SUBCOMPID': 'SCMP0511'}
# {'LabComponentHeaderId': 97, 'LabParameterHeaderId': 615, 'Priority': 7, 'ShivamComponentId': 'COMP0035', 'SUBCOMPID': 'SCMP0514'}
# {'LabComponentHeaderId': 97, 'LabParameterHeaderId': 567, 'Priority': 1, 'ShivamComponentId': 'COMP0035', 'SUBCOMPID': 'SCMP0508'}
# {'LabComponentHeaderId': 97, 'LabParameterHeaderId': 568, 'Priority': 2, 'ShivamComponentId': 'COMP0035', 'SUBCOMPID': 'SCMP0509'}
# {'LabComponentHeaderId': 97, 'LabParameterHeaderId': 318, 'Priority': 5, 'ShivamComponentId': 'COMP0035', 'SUBCOMPID': 'SCMP0512'}
# {'LabComponentHeaderId': 97, 'LabParameterHeaderId': 904, 'Priority': 6, 'ShivamComponentId': 'COMP0035', 'SUBCOMPID': 'SCMP0513'}
#
#
# The labcomponentheaderid is :  98
# [{'sno': 3, 'componentid': 'COMP0036', 'subcomponentid': 'SCMP0517'}, {'sno': 4, 'componentid': 'COMP0036', 'subcomponentid': 'SCMP0518'}, {'sno': 1, 'componentid': 'COMP0036', 'subcomponentid': 'SCMP0515'}, {'sno': 2, 'componentid': 'COMP0036', 'subcomponentid': 'SCMP0516'}]
# {'LabComponentHeaderId': 98, 'LabParameterHeaderId': 320, 'Priority': 3, 'ShivamComponentId': 'COMP0036', 'SUBCOMPID': 'SCMP0517'}
# {'LabComponentHeaderId': 98, 'LabParameterHeaderId': 616, 'Priority': 4, 'ShivamComponentId': 'COMP0036', 'SUBCOMPID': 'SCMP0518'}
# {'LabComponentHeaderId': 98, 'LabParameterHeaderId': 824, 'Priority': 1, 'ShivamComponentId': 'COMP0036', 'SUBCOMPID': 'SCMP0515'}
# {'LabComponentHeaderId': 98, 'LabParameterHeaderId': 319, 'Priority': 2, 'ShivamComponentId': 'COMP0036', 'SUBCOMPID': 'SCMP0516'}
#
#
# The labcomponentheaderid is :  99
# [{'sno': 1, 'componentid': 'COMP0045', 'subcomponentid': 'SCMP0546'}, {'sno': 2, 'componentid': 'COMP0045', 'subcomponentid': 'SCMP0547'}, {'sno': 3, 'componentid': 'COMP0045', 'subcomponentid': 'SCMP0548'}]
# {'LabComponentHeaderId': 99, 'LabParameterHeaderId': 331, 'Priority': 1, 'ShivamComponentId': 'COMP0045', 'SUBCOMPID': 'SCMP0546'}
# {'LabComponentHeaderId': 99, 'LabParameterHeaderId': 627, 'Priority': 2, 'ShivamComponentId': 'COMP0045', 'SUBCOMPID': 'SCMP0547'}
# {'LabComponentHeaderId': 99, 'LabParameterHeaderId': 628, 'Priority': 3, 'ShivamComponentId': 'COMP0045', 'SUBCOMPID': 'SCMP0548'}
#
#
# The labcomponentheaderid is :  100
# [{'sno': 1, 'componentid': 'COMP0046', 'subcomponentid': 'SCMP0549'}, {'sno': 2, 'componentid': 'COMP0046', 'subcomponentid': 'SCMP0550'}]
# {'LabComponentHeaderId': 100, 'LabParameterHeaderId': 332, 'Priority': 1, 'ShivamComponentId': 'COMP0046', 'SUBCOMPID': 'SCMP0549'}
# {'LabComponentHeaderId': 100, 'LabParameterHeaderId': 122, 'Priority': 2, 'ShivamComponentId': 'COMP0046', 'SUBCOMPID': 'SCMP0550'}
#
#
# The labcomponentheaderid is :  101
# [{'sno': 5, 'componentid': 'COMP0047', 'subcomponentid': 'SCMP0512'}, {'sno': 1, 'componentid': 'COMP0047', 'subcomponentid': 'SCMP0508'}, {'sno': 2, 'componentid': 'COMP0047', 'subcomponentid': 'SCMP0509'}, {'sno': 6, 'componentid': 'COMP0047', 'subcomponentid': 'SCMP0513'}, {'sno': 7, 'componentid': 'COMP0047', 'subcomponentid': 'SCMP0514'}, {'sno': 3, 'componentid': 'COMP0047', 'subcomponentid': 'SCMP0510'}, {'sno': 4, 'componentid': 'COMP0047', 'subcomponentid': 'SCMP0511'}]
# {'LabComponentHeaderId': 101, 'LabParameterHeaderId': 318, 'Priority': 5, 'ShivamComponentId': 'COMP0047', 'SUBCOMPID': 'SCMP0512'}
# {'LabComponentHeaderId': 101, 'LabParameterHeaderId': 567, 'Priority': 1, 'ShivamComponentId': 'COMP0047', 'SUBCOMPID': 'SCMP0508'}
# {'LabComponentHeaderId': 101, 'LabParameterHeaderId': 568, 'Priority': 2, 'ShivamComponentId': 'COMP0047', 'SUBCOMPID': 'SCMP0509'}
# {'LabComponentHeaderId': 101, 'LabParameterHeaderId': 904, 'Priority': 6, 'ShivamComponentId': 'COMP0047', 'SUBCOMPID': 'SCMP0513'}
# {'LabComponentHeaderId': 101, 'LabParameterHeaderId': 615, 'Priority': 7, 'ShivamComponentId': 'COMP0047', 'SUBCOMPID': 'SCMP0514'}
# {'LabComponentHeaderId': 101, 'LabParameterHeaderId': 569, 'Priority': 3, 'ShivamComponentId': 'COMP0047', 'SUBCOMPID': 'SCMP0510'}
# {'LabComponentHeaderId': 101, 'LabParameterHeaderId': 317, 'Priority': 4, 'ShivamComponentId': 'COMP0047', 'SUBCOMPID': 'SCMP0511'}
#
#
# The labcomponentheaderid is :  102
# [{'sno': 2, 'componentid': 'COMP0048', 'subcomponentid': 'SCMP0575'}, {'sno': 1, 'componentid': 'COMP0048', 'subcomponentid': 'SCMP0486'}, {'sno': 3, 'componentid': 'COMP0048', 'subcomponentid': 'SCMP0576'}]
# {'LabComponentHeaderId': 102, 'LabParameterHeaderId': 635, 'Priority': 2, 'ShivamComponentId': 'COMP0048', 'SUBCOMPID': 'SCMP0575'}
# {'LabComponentHeaderId': 102, 'LabParameterHeaderId': 558, 'Priority': 1, 'ShivamComponentId': 'COMP0048', 'SUBCOMPID': 'SCMP0486'}
# {'LabComponentHeaderId': 102, 'LabParameterHeaderId': 636, 'Priority': 3, 'ShivamComponentId': 'COMP0048', 'SUBCOMPID': 'SCMP0576'}
#
#
# The labcomponentheaderid is :  103
# [{'sno': 2, 'componentid': 'COMP0049', 'subcomponentid': 'SCMP0577'}, {'sno': 1, 'componentid': 'COMP0049', 'subcomponentid': 'SCMP0486'}]
# {'LabComponentHeaderId': 103, 'LabParameterHeaderId': 212, 'Priority': 2, 'ShivamComponentId': 'COMP0049', 'SUBCOMPID': 'SCMP0577'}
# {'LabComponentHeaderId': 103, 'LabParameterHeaderId': 558, 'Priority': 1, 'ShivamComponentId': 'COMP0049', 'SUBCOMPID': 'SCMP0486'}
#
#
# The labcomponentheaderid is :  104
# [{'sno': 1, 'componentid': 'COMP0050', 'subcomponentid': 'SCMP0539'}, {'sno': 2, 'componentid': 'COMP0050', 'subcomponentid': 'SCMP0577'}]
# {'LabComponentHeaderId': 104, 'LabParameterHeaderId': 118, 'Priority': 1, 'ShivamComponentId': 'COMP0050', 'SUBCOMPID': 'SCMP0539'}
# {'LabComponentHeaderId': 104, 'LabParameterHeaderId': 212, 'Priority': 2, 'ShivamComponentId': 'COMP0050', 'SUBCOMPID': 'SCMP0577'}
#
#
# The labcomponentheaderid is :  105
# [{'sno': 1, 'componentid': 'COMP0051', 'subcomponentid': 'SCMP0267'}, {'sno': 2, 'componentid': 'COMP0051', 'subcomponentid': 'SCMP0268'}]
# {'LabComponentHeaderId': 105, 'LabParameterHeaderId': 485, 'Priority': 1, 'ShivamComponentId': 'COMP0051', 'SUBCOMPID': 'SCMP0267'}
# {'LabComponentHeaderId': 105, 'LabParameterHeaderId': 488, 'Priority': 2, 'ShivamComponentId': 'COMP0051', 'SUBCOMPID': 'SCMP0268'}
#
#
# The labcomponentheaderid is :  106
# [{'sno': 3, 'componentid': 'COMP0056', 'subcomponentid': 'SCMP0281'}, {'sno': 1, 'componentid': 'COMP0056', 'subcomponentid': 'SCMP0280'}, {'sno': 2, 'componentid': 'COMP0056', 'subcomponentid': 'SCMP0644'}]
# {'LabComponentHeaderId': 106, 'LabParameterHeaderId': 492, 'Priority': 3, 'ShivamComponentId': 'COMP0056', 'SUBCOMPID': 'SCMP0281'}
# {'LabComponentHeaderId': 106, 'LabParameterHeaderId': 180, 'Priority': 1, 'ShivamComponentId': 'COMP0056', 'SUBCOMPID': 'SCMP0280'}
# {'LabComponentHeaderId': 106, 'LabParameterHeaderId': 638, 'Priority': 2, 'ShivamComponentId': 'COMP0056', 'SUBCOMPID': 'SCMP0644'}
#
#
# The labcomponentheaderid is :  107
# [{'sno': 2, 'componentid': 'COMP0057', 'subcomponentid': 'SCMP0641'}, {'sno': 1, 'componentid': 'COMP0057', 'subcomponentid': 'SCMP0414'}]
# {'LabComponentHeaderId': 107, 'LabParameterHeaderId': 363, 'Priority': 2, 'ShivamComponentId': 'COMP0057', 'SUBCOMPID': 'SCMP0641'}
# {'LabComponentHeaderId': 107, 'LabParameterHeaderId': 90, 'Priority': 1, 'ShivamComponentId': 'COMP0057', 'SUBCOMPID': 'SCMP0414'}
#
#
# The labcomponentheaderid is :  108
# []
#
#
# The labcomponentheaderid is :  109
# [{'sno': 1, 'componentid': 'COMP0052', 'subcomponentid': 'SCMP0482'}, {'sno': 3, 'componentid': 'COMP0052', 'subcomponentid': 'SCMP0664'}, {'sno': 2, 'componentid': 'COMP0052', 'subcomponentid': 'SCMP0581'}]
# {'LabComponentHeaderId': 109, 'LabParameterHeaderId': 108, 'Priority': 1, 'ShivamComponentId': 'COMP0052', 'SUBCOMPID': 'SCMP0482'}
# {'LabComponentHeaderId': 109, 'LabParameterHeaderId': 909, 'Priority': 3, 'ShivamComponentId': 'COMP0052', 'SUBCOMPID': 'SCMP0664'}
# {'LabComponentHeaderId': 109, 'LabParameterHeaderId': 338, 'Priority': 2, 'ShivamComponentId': 'COMP0052', 'SUBCOMPID': 'SCMP0581'}
#
#
# The labcomponentheaderid is :  110
# []
#
#
# The labcomponentheaderid is :  111
# [{'sno': 1, 'componentid': 'COMP0059', 'subcomponentid': 'SCMP0743'}, {'sno': 2, 'componentid': 'COMP0059', 'subcomponentid': 'SCMP0744'}]
# {'LabComponentHeaderId': 111, 'LabParameterHeaderId': 733, 'Priority': 1, 'ShivamComponentId': 'COMP0059', 'SUBCOMPID': 'SCMP0743'}
# {'LabComponentHeaderId': 111, 'LabParameterHeaderId': 716, 'Priority': 2, 'ShivamComponentId': 'COMP0059', 'SUBCOMPID': 'SCMP0744'}
#
#
# The labcomponentheaderid is :  112
# [{'sno': 2, 'componentid': 'COMP0008', 'subcomponentid': 'SCMP0091'}, {'sno': 1, 'componentid': 'COMP0008', 'subcomponentid': 'SCMP0043'}]
# {'LabComponentHeaderId': 112, 'LabParameterHeaderId': 844, 'Priority': 2, 'ShivamComponentId': 'COMP0008', 'SUBCOMPID': 'SCMP0091'}
# {'LabComponentHeaderId': 112, 'LabParameterHeaderId': 137, 'Priority': 1, 'ShivamComponentId': 'COMP0008', 'SUBCOMPID': 'SCMP0043'}
#
#
# The labcomponentheaderid is :  113
# [{'sno': 1, 'componentid': 'COMP0032', 'subcomponentid': 'SCMP0472'}]
# {'LabComponentHeaderId': 113, 'LabParameterHeaderId': 104, 'Priority': 1, 'ShivamComponentId': 'COMP0032', 'SUBCOMPID': 'SCMP0472'}
#
#
# The labcomponentheaderid is :  114
# [{'sno': 2, 'componentid': 'COMP0037', 'subcomponentid': 'SCMP0520'}, {'sno': 1, 'componentid': 'COMP0037', 'subcomponentid': 'SCMP0519'}, {'sno': 3, 'componentid': 'COMP0037', 'subcomponentid': 'SCMP0521'}]
# {'LabComponentHeaderId': 114, 'LabParameterHeaderId': 321, 'Priority': 2, 'ShivamComponentId': 'COMP0037', 'SUBCOMPID': 'SCMP0520'}
# {'LabComponentHeaderId': 114, 'LabParameterHeaderId': 617, 'Priority': 1, 'ShivamComponentId': 'COMP0037', 'SUBCOMPID': 'SCMP0519'}
# {'LabComponentHeaderId': 114, 'LabParameterHeaderId': 876, 'Priority': 3, 'ShivamComponentId': 'COMP0037', 'SUBCOMPID': 'SCMP0521'}
#
#
# The labcomponentheaderid is :  115
# [{'sno': 2, 'componentid': 'COMP0038', 'subcomponentid': 'SCMP0523'}, {'sno': 3, 'componentid': 'COMP0038', 'subcomponentid': 'SCMP0524'}, {'sno': 1, 'componentid': 'COMP0038', 'subcomponentid': 'SCMP0522'}]
# {'LabComponentHeaderId': 115, 'LabParameterHeaderId': 619, 'Priority': 2, 'ShivamComponentId': 'COMP0038', 'SUBCOMPID': 'SCMP0523'}
# {'LabComponentHeaderId': 115, 'LabParameterHeaderId': 322, 'Priority': 3, 'ShivamComponentId': 'COMP0038', 'SUBCOMPID': 'SCMP0524'}
# {'LabComponentHeaderId': 115, 'LabParameterHeaderId': 618, 'Priority': 1, 'ShivamComponentId': 'COMP0038', 'SUBCOMPID': 'SCMP0522'}
#
#
# The labcomponentheaderid is :  116
# [{'sno': 6, 'componentid': 'COMP0053', 'subcomponentid': 'SCMP0051'}, {'sno': 3, 'componentid': 'COMP0053', 'subcomponentid': 'SCMP0346'}, {'sno': 5, 'componentid': 'COMP0053', 'subcomponentid': 'SCMP0046'}, {'sno': 2, 'componentid': 'COMP0053', 'subcomponentid': 'SCMP0047'}, {'sno': 1, 'componentid': 'COMP0053', 'subcomponentid': 'SCMP0045'}, {'sno': 4, 'componentid': 'COMP0053', 'subcomponentid': 'SCMP0049'}]
# {'LabComponentHeaderId': 116, 'LabParameterHeaderId': 578, 'Priority': 6, 'ShivamComponentId': 'COMP0053', 'SUBCOMPID': 'SCMP0051'}
# {'LabComponentHeaderId': 116, 'LabParameterHeaderId': 188, 'Priority': 3, 'ShivamComponentId': 'COMP0053', 'SUBCOMPID': 'SCMP0346'}
# {'LabComponentHeaderId': 116, 'LabParameterHeaderId': 814, 'Priority': 5, 'ShivamComponentId': 'COMP0053', 'SUBCOMPID': 'SCMP0046'}
# {'LabComponentHeaderId': 116, 'LabParameterHeaderId': 139, 'Priority': 2, 'ShivamComponentId': 'COMP0053', 'SUBCOMPID': 'SCMP0047'}
# {'LabComponentHeaderId': 116, 'LabParameterHeaderId': 138, 'Priority': 1, 'ShivamComponentId': 'COMP0053', 'SUBCOMPID': 'SCMP0045'}
# {'LabComponentHeaderId': 116, 'LabParameterHeaderId': 233, 'Priority': 4, 'ShivamComponentId': 'COMP0053', 'SUBCOMPID': 'SCMP0049'}
#
#
# The labcomponentheaderid is :  117
# [{'sno': 1, 'componentid': 'COMP0062', 'subcomponentid': 'SCMP0671'}, {'sno': 2, 'componentid': 'COMP0062', 'subcomponentid': 'SCMP0672'}, {'sno': 3, 'componentid': 'COMP0062', 'subcomponentid': 'SCMP0673'}]
# {'LabComponentHeaderId': 117, 'LabParameterHeaderId': 672, 'Priority': 1, 'ShivamComponentId': 'COMP0062', 'SUBCOMPID': 'SCMP0671'}
# {'LabComponentHeaderId': 117, 'LabParameterHeaderId': 673, 'Priority': 2, 'ShivamComponentId': 'COMP0062', 'SUBCOMPID': 'SCMP0672'}
# {'LabComponentHeaderId': 117, 'LabParameterHeaderId': 395, 'Priority': 3, 'ShivamComponentId': 'COMP0062', 'SUBCOMPID': 'SCMP0673'}
#
#
# The labcomponentheaderid is :  118
# [{'sno': 2, 'componentid': 'COMP0063', 'subcomponentid': 'SCMP0675'}, {'sno': 3, 'componentid': 'COMP0063', 'subcomponentid': 'SCMP0735'}, {'sno': 4, 'componentid': 'COMP0063', 'subcomponentid': 'SCMP0677'}, {'sno': 5, 'componentid': 'COMP0063', 'subcomponentid': 'SCMP0678'}, {'sno': 1, 'componentid': 'COMP0063', 'subcomponentid': 'SCMP0674'}]
# {'LabComponentHeaderId': 118, 'LabParameterHeaderId': 386, 'Priority': 2, 'ShivamComponentId': 'COMP0063', 'SUBCOMPID': 'SCMP0675'}
# {'LabComponentHeaderId': 118, 'LabParameterHeaderId': 730, 'Priority': 3, 'ShivamComponentId': 'COMP0063', 'SUBCOMPID': 'SCMP0735'}
# {'LabComponentHeaderId': 118, 'LabParameterHeaderId': 675, 'Priority': 4, 'ShivamComponentId': 'COMP0063', 'SUBCOMPID': 'SCMP0677'}
# {'LabComponentHeaderId': 118, 'LabParameterHeaderId': 695, 'Priority': 5, 'ShivamComponentId': 'COMP0063', 'SUBCOMPID': 'SCMP0678'}
# {'LabComponentHeaderId': 118, 'LabParameterHeaderId': 881, 'Priority': 1, 'ShivamComponentId': 'COMP0063', 'SUBCOMPID': 'SCMP0674'}
#
#
# The labcomponentheaderid is :  119
# [{'sno': 1, 'componentid': 'COMP0064', 'subcomponentid': 'SCMP0732'}, {'sno': 2, 'componentid': 'COMP0064', 'subcomponentid': 'SCMP0733'}, {'sno': 3, 'componentid': 'COMP0064', 'subcomponentid': 'SCMP0681'}, {'sno': 4, 'componentid': 'COMP0064', 'subcomponentid': 'SCMP0745'}, {'sno': 5, 'componentid': 'COMP0064', 'subcomponentid': 'SCMP0746'}, {'sno': 6, 'componentid': 'COMP0064', 'subcomponentid': 'SCMP0747'}, {'sno': 7, 'componentid': 'COMP0064', 'subcomponentid': 'SCMP0717'}]
# {'LabComponentHeaderId': 119, 'LabParameterHeaderId': 728, 'Priority': 1, 'ShivamComponentId': 'COMP0064', 'SUBCOMPID': 'SCMP0732'}
# {'LabComponentHeaderId': 119, 'LabParameterHeaderId': 729, 'Priority': 2, 'ShivamComponentId': 'COMP0064', 'SUBCOMPID': 'SCMP0733'}
# {'LabComponentHeaderId': 119, 'LabParameterHeaderId': 677, 'Priority': 3, 'ShivamComponentId': 'COMP0064', 'SUBCOMPID': 'SCMP0681'}
# {'LabComponentHeaderId': 119, 'LabParameterHeaderId': 913, 'Priority': 4, 'ShivamComponentId': 'COMP0064', 'SUBCOMPID': 'SCMP0745'}
# {'LabComponentHeaderId': 119, 'LabParameterHeaderId': 717, 'Priority': 5, 'ShivamComponentId': 'COMP0064', 'SUBCOMPID': 'SCMP0746'}
# {'LabComponentHeaderId': 119, 'LabParameterHeaderId': 718, 'Priority': 6, 'ShivamComponentId': 'COMP0064', 'SUBCOMPID': 'SCMP0747'}
# {'LabComponentHeaderId': 119, 'LabParameterHeaderId': 694, 'Priority': 7, 'ShivamComponentId': 'COMP0064', 'SUBCOMPID': 'SCMP0717'}
#
#
# The labcomponentheaderid is :  120
# [{'sno': 1, 'componentid': 'COMP0067', 'subcomponentid': 'SCMP0698'}]
# {'LabComponentHeaderId': 120, 'LabParameterHeaderId': 399, 'Priority': 1, 'ShivamComponentId': 'COMP0067', 'SUBCOMPID': 'SCMP0698'}
#
#
# The labcomponentheaderid is :  121
# ...
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 806, 'Priority': 30, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0839'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 807, 'Priority': 31, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0840'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 855, 'Priority': 32, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0861'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 840, 'Priority': 33, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0842'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 982, 'Priority': 34, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0843'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 808, 'Priority': 35, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0844'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 983, 'Priority': 36, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0845'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 809, 'Priority': 37, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0846'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 902, 'Priority': 38, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0862'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 985, 'Priority': 39, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0848'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 986, 'Priority': 40, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0849'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 964, 'Priority': 41, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0863'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 899, 'Priority': 42, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0850'}
# {'LabComponentHeaderId': 135, 'LabParameterHeaderId': 900, 'Priority': 43, 'ShivamComponentId': 'COMP0082', 'SUBCOMPID': 'SCMP0851'}
#
#
# The labcomponentheaderid is :  136
# [{'sno': 2, 'componentid': 'COMP0088', 'subcomponentid': 'SCMP0936'}, {'sno': 3, 'componentid': 'COMP0088', 'subcomponentid': 'SCMP0857'}, {'sno': 1, 'componentid': 'COMP0088', 'subcomponentid': 'SCMP0935'}]
# {'LabComponentHeaderId': 136, 'LabParameterHeaderId': 978, 'Priority': 2, 'ShivamComponentId': 'COMP0088', 'SUBCOMPID': 'SCMP0936'}
# {'LabComponentHeaderId': 136, 'LabParameterHeaderId': 901, 'Priority': 3, 'ShivamComponentId': 'COMP0088', 'SUBCOMPID': 'SCMP0857'}
# {'LabComponentHeaderId': 136, 'LabParameterHeaderId': 835, 'Priority': 1, 'ShivamComponentId': 'COMP0088', 'SUBCOMPID': 'SCMP0935'}
#
#
# The labcomponentheaderid is :  137
# []
#
#
# The labcomponentheaderid is :  138
# [{'sno': 1, 'componentid': 'COMP0075', 'subcomponentid': 'SCMP0789'}, {'sno': 2, 'componentid': 'COMP0075', 'subcomponentid': 'SCMP0790'}, {'sno': 3, 'componentid': 'COMP0075', 'subcomponentid': 'SCMP0707'}]
# {'LabComponentHeaderId': 138, 'LabParameterHeaderId': 764, 'Priority': 1, 'ShivamComponentId': 'COMP0075', 'SUBCOMPID': 'SCMP0789'}
# {'LabComponentHeaderId': 138, 'LabParameterHeaderId': 765, 'Priority': 2, 'ShivamComponentId': 'COMP0075', 'SUBCOMPID': 'SCMP0790'}
# {'LabComponentHeaderId': 138, 'LabParameterHeaderId': 688, 'Priority': 3, 'ShivamComponentId': 'COMP0075', 'SUBCOMPID': 'SCMP0707'}
#
#
# The labcomponentheaderid is :  139
# [{'sno': 1, 'componentid': 'COMP0085', 'subcomponentid': 'SCMP0933'}, {'sno': 2, 'componentid': 'COMP0085', 'subcomponentid': 'SCMP0934'}, {'sno': 3, 'componentid': 'COMP0085', 'subcomponentid': 'SCMP0857'}]
# {'LabComponentHeaderId': 139, 'LabParameterHeaderId': 945, 'Priority': 1, 'ShivamComponentId': 'COMP0085', 'SUBCOMPID': 'SCMP0933'}
# {'LabComponentHeaderId': 139, 'LabParameterHeaderId': 946, 'Priority': 2, 'ShivamComponentId': 'COMP0085', 'SUBCOMPID': 'SCMP0934'}
# {'LabComponentHeaderId': 139, 'LabParameterHeaderId': 901, 'Priority': 3, 'ShivamComponentId': 'COMP0085', 'SUBCOMPID': 'SCMP0857'}
#
#
# The labcomponentheaderid is :  140
# [{'sno': 1, 'componentid': 'COMP0089', 'subcomponentid': 'SCMP0937'}, {'sno': 2, 'componentid': 'COMP0089', 'subcomponentid': 'SCMP0938'}, {'sno': 3, 'componentid': 'COMP0089', 'subcomponentid': 'SCMP0857'}]
# {'LabComponentHeaderId': 140, 'LabParameterHeaderId': 979, 'Priority': 1, 'ShivamComponentId': 'COMP0089', 'SUBCOMPID': 'SCMP0937'}
# {'LabComponentHeaderId': 140, 'LabParameterHeaderId': 980, 'Priority': 2, 'ShivamComponentId': 'COMP0089', 'SUBCOMPID': 'SCMP0938'}
# {'LabComponentHeaderId': 140, 'LabParameterHeaderId': 901, 'Priority': 3, 'ShivamComponentId': 'COMP0089', 'SUBCOMPID': 'SCMP0857'}
#
#
# The labcomponentheaderid is :  141
# [{'sno': 2, 'componentid': 'COMP0091', 'subcomponentid': 'SCMP0655'}, {'sno': 1, 'componentid': 'COMP0091', 'subcomponentid': 'SCMP0095'}, {'sno': 3, 'componentid': 'COMP0091', 'subcomponentid': 'SCMP0161'}, {'sno': 4, 'componentid': 'COMP0091', 'subcomponentid': 'SCMP0162'}]
# {'LabComponentHeaderId': 141, 'LabParameterHeaderId': 664, 'Priority': 2, 'ShivamComponentId': 'COMP0091', 'SUBCOMPID': 'SCMP0655'}
# {'LabComponentHeaderId': 141, 'LabParameterHeaderId': 243, 'Priority': 1, 'ShivamComponentId': 'COMP0091', 'SUBCOMPID': 'SCMP0095'}
# {'LabComponentHeaderId': 141, 'LabParameterHeaderId': 449, 'Priority': 3, 'ShivamComponentId': 'COMP0091', 'SUBCOMPID': 'SCMP0161'}
# {'LabComponentHeaderId': 141, 'LabParameterHeaderId': 450, 'Priority': 4, 'ShivamComponentId': 'COMP0091', 'SUBCOMPID': 'SCMP0162'}
#
#
# The labcomponentheaderid is :  142
# []
#
#
# The labcomponentheaderid is :  143
# [{'sno': 1, 'componentid': 'COMP0076', 'subcomponentid': 'SCMP0799'}, {'sno': 2, 'componentid': 'COMP0076', 'subcomponentid': 'SCMP0800'}, {'sno': 3, 'componentid': 'COMP0076', 'subcomponentid': 'SCMP0801'}, {'sno': 4, 'componentid': 'COMP0076', 'subcomponentid': 'SCMP0802'}, {'sno': 5, 'componentid': 'COMP0076', 'subcomponentid': 'SCMP0803'}, {'sno': 6, 'componentid': 'COMP0076', 'subcomponentid': 'SCMP0804'}, {'sno': 7, 'componentid': 'COMP0076', 'subcomponentid': 'SCMP0805'}]
# {'LabComponentHeaderId': 143, 'LabParameterHeaderId': 773, 'Priority': 1, 'ShivamComponentId': 'COMP0076', 'SUBCOMPID': 'SCMP0799'}
# {'LabComponentHeaderId': 143, 'LabParameterHeaderId': 774, 'Priority': 2, 'ShivamComponentId': 'COMP0076', 'SUBCOMPID': 'SCMP0800'}
# {'LabComponentHeaderId': 143, 'LabParameterHeaderId': 775, 'Priority': 3, 'ShivamComponentId': 'COMP0076', 'SUBCOMPID': 'SCMP0801'}
# {'LabComponentHeaderId': 143, 'LabParameterHeaderId': 919, 'Priority': 4, 'ShivamComponentId': 'COMP0076', 'SUBCOMPID': 'SCMP0802'}
# {'LabComponentHeaderId': 143, 'LabParameterHeaderId': 776, 'Priority': 5, 'ShivamComponentId': 'COMP0076', 'SUBCOMPID': 'SCMP0803'}
# {'LabComponentHeaderId': 143, 'LabParameterHeaderId': 777, 'Priority': 6, 'ShivamComponentId': 'COMP0076', 'SUBCOMPID': 'SCMP0804'}
# {'LabComponentHeaderId': 143, 'LabParameterHeaderId': 778, 'Priority': 7, 'ShivamComponentId': 'COMP0076', 'SUBCOMPID': 'SCMP0805'}
#
#
# The labcomponentheaderid is :  144
# [{'sno': 1, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0812'}, {'sno': 2, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0859'}, {'sno': 3, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0864'}, {'sno': 4, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0814'}, {'sno': 5, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0815'}, {'sno': 6, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0816'}, {'sno': 7, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0860'}, {'sno': 8, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0818'}, {'sno': 9, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0819'}, {'sno': 10, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0820'}, {'sno': 11, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0821'}, {'sno': 12, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0822'}, {'sno': 13, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0823'}, {'sno': 14, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0824'}, {'sno': 15, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0825'}, {'sno': 16, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0826'}, {'sno': 17, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0827'}, {'sno': 18, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0828'}, {'sno': 19, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0829'}, {'sno': 20, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0830'}, {'sno': 21, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0831'}, {'sno': 22, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0832'}, {'sno': 23, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0833'}, {'sno': 24, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0834'}, {'sno': 25, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0835'}, {'sno': 26, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0836'}, {'sno': 27, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0852'}, {'sno': 28, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0837'}, {'sno': 29, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0838'}, {'sno': 30, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0839'}, {'sno': 31, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0840'}, {'sno': 32, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0861'}, {'sno': 33, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0842'}, {'sno': 34, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0843'}, {'sno': 35, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0844'}, {'sno': 36, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0845'}, {'sno': 37, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0846'}, {'sno': 38, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0862'}, {'sno': 39, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0848'}, {'sno': 40, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0849'}, {'sno': 41, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0863'}, {'sno': 42, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0850'}, {'sno': 43, 'componentid': 'COMP0077', 'subcomponentid': 'SCMP0851'}]
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 785, 'Priority': 1, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0812'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 811, 'Priority': 2, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0859'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 842, 'Priority': 3, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0864'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 787, 'Priority': 4, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0814'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 788, 'Priority': 5, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0815'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 789, 'Priority': 6, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0816'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 812, 'Priority': 7, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0860'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 825, 'Priority': 8, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0818'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 790, 'Priority': 9, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0819'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 791, 'Priority': 10, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0820'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 792, 'Priority': 11, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0821'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 793, 'Priority': 12, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0822'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 826, 'Priority': 13, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0823'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 794, 'Priority': 14, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0824'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 795, 'Priority': 15, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0825'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 796, 'Priority': 16, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0826'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 797, 'Priority': 17, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0827'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 827, 'Priority': 18, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0828'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 798, 'Priority': 19, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0829'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 799, 'Priority': 20, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0830'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 800, 'Priority': 21, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0831'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 801, 'Priority': 22, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0832'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 828, 'Priority': 23, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0833'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 802, 'Priority': 24, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0834'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 803, 'Priority': 25, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0835'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 804, 'Priority': 26, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0836'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 841, 'Priority': 27, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0852'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 805, 'Priority': 28, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0837'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 829, 'Priority': 29, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0838'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 806, 'Priority': 30, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0839'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 807, 'Priority': 31, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0840'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 855, 'Priority': 32, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0861'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 840, 'Priority': 33, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0842'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 982, 'Priority': 34, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0843'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 808, 'Priority': 35, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0844'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 983, 'Priority': 36, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0845'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 809, 'Priority': 37, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0846'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 902, 'Priority': 38, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0862'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 985, 'Priority': 39, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0848'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 986, 'Priority': 40, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0849'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 964, 'Priority': 41, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0863'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 899, 'Priority': 42, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0850'}
# {'LabComponentHeaderId': 144, 'LabParameterHeaderId': 900, 'Priority': 43, 'ShivamComponentId': 'COMP0077', 'SUBCOMPID': 'SCMP0851'}
#
#
# The labcomponentheaderid is :  145
# []
#
#
# The labcomponentheaderid is :  146
# [{'sno': 1, 'componentid': 'COMP0086', 'subcomponentid': 'SCMP0934'}]
# {'LabComponentHeaderId': 146, 'LabParameterHeaderId': 946, 'Priority': 1, 'ShivamComponentId': 'COMP0086', 'SUBCOMPID': 'SCMP0934'}
#
#
# The labcomponentheaderid is :  147
# []
#
#
# The labcomponentheaderid is :  148
# []
